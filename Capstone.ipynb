# %% [markdown]
# ## Setup

# %%
import numpy as np
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats._qmc import Sobol
from scipy.stats import norm
from scipy.optimize import minimize
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern
from sklearn.model_selection import GridSearchCV

from dataloading_utils import (combineInitialDataAndSubmissionsToDate, sortByLargestOutputDescending)


import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma


def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
from sklearn.gaussian_process.kernels import WhiteKernel


def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }

def findTunedGaussianProcessRegressor(X_samples, y_samples):
    n_dims = X_samples.shape[1]

    base_kernels = [
        ConstantKernel(1.0) * RBF(length_scale=np.ones(n_dims)),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=0.5),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=1.5),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=2.5),
    ]
    kernels = [k + WhiteKernel() for k in base_kernels]

    param_grid = {
        'kernel': kernels,
        'n_restarts_optimizer': [10]
    }

    gp = GaussianProcessRegressor(normalize_y=True)

    grid_search = GridSearchCV(gp, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_




# def findTunedGaussianProcessRegressor(X_samples, y_samples):
#     n_dims = X_samples.shape[1]
#
#     # ARD kernels (vector length_scale)
#     rbf_ard = RBF(length_scale=np.ones(n_dims),
#                   length_scale_bounds=(1e-2, 1e2))
#     rbf_ardC = RBF(length_scale=np.ones(n_dims),
#                   length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#
#     matern_05 = Matern(length_scale=np.ones(n_dims), nu=0.5,
#                        length_scale_bounds=(1e-2, 1e2))
#     matern_15 = Matern(length_scale=np.ones(n_dims), nu=1.5,
#                        length_scale_bounds=(1e-2, 1e2))
#     matern_25 = Matern(length_scale=np.ones(n_dims), nu=2.5,
#                        length_scale_bounds=(1e-2, 1e2))
#
#     matern_05C = Matern(length_scale=np.ones(n_dims), nu=0.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#     matern_15C = Matern(length_scale=np.ones(n_dims), nu=1.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#     matern_25C = Matern(length_scale=np.ones(n_dims), nu=2.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#
#     param_grid = {
#         'kernel': [
#             rbf_ard,
#             rbf_ardC,
#             matern_05, matern_15, matern_25,
#             matern_05C, matern_15C, matern_25C,
#         ],
#         'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
#         'n_restarts_optimizer': [5, 10, 20]
#     }
#
#     gp = GaussianProcessRegressor(normalize_y=True)
#
#     grid_search = GridSearchCV(gp, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
#     grid_search.fit(X_samples, y_samples)
#
#     return grid_search.best_estimator_, grid_search.best_params_


def penaltyWeightAndScaleForDimension(d):
    #Curse of dimensionality means this needs to be much tighter at higher dimensions
    #This is intended to reduce the acquisition function's information gain by 10% if the point has a Euclidean distance of 1/20th or 1/50th of a boundary.
    if d <= 5:
        return 0.1, 0.05
    else:
        return 0.1, 0.02


def get_length_scale(kernel):
    if hasattr(kernel, "length_scale"):
        return kernel.length_scale
    elif hasattr(kernel, "k1"):
        return get_length_scale(kernel.k1)
    elif hasattr(kernel, "k2"):
        return get_length_scale(kernel.k2)
    return None



def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None,
        excludeDuplicates = True):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims

    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]
    penaltyWeight, penalityScale = penaltyWeightAndScaleForDimension(n_dims)

    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process - or assume one has been fitted
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )
        gp.fit(X_samples, y_samples)
        print(f"Fitted default GaussianProcessRegressor since one not provided")

    # -----------------------------
    # 2. Acquisition function
    # -----------------------------

    # -----------------------------
    # 2.1 Boundary Penalty.
    # GP tends to hug the boundary, so add a penalty if a suggested point is close to boundary.
    # Scale controls how far from the boundary the penalty reaches. At scale=0.05, a point at x=0.05 gets a penalty of exp(-1) ≈ 0.37, meaning the penalty is significant only within the last ~5% of the search space.
    # Weight controls how strongly that penalty suppresses the acquisition value. At weight=0.1, the maximum possible suppression is 10% of the acquisition value.
    #
    # -----------------------------
    def boundary_penalty(X, weight=0.1, scale=0.05):
        X = np.atleast_2d(X)
        d = np.minimum(X, 1.0 - X)    #Find point closest to boundary at 0 or 1 in any dimension.
        penalty = np.mean(np.exp(-d / scale), axis=1)   #exp(-small) tends towards 1, exp(-large) tends towards 0. Mean takes into account other dimensions.
        return weight * penalty


    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        penalty = boundary_penalty(X, weight=penaltyWeight, scale=penalityScale)
        return val * (1 - penalty)


    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Filter out duplicate candidates, based on Eucledian distance because acquisition functions can suggest previous points.
    def is_duplicate(x, X_samples, tol=1e-5):
        return np.any(np.linalg.norm(X_samples - x, axis=1) < tol)

    if (excludeDuplicates):
        mask = np.array([not is_duplicate(x, X_samples) for x in X_candidates])
        X_candidates = X_candidates[mask]
        acq_vals = acq_vals[mask]


    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{ len(X_candidates) } Sobol candidates, best { len(X_start) } to be minimised in local search")
    print(f"\tInitial acquisition function stats { summary_stats(acq_vals) }")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition

    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun

        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val, X_start

# %%
def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')


def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)

    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem initially is ${bestParams}")
    print()

    #Fit GaussianProcesses to samples provided
    gpr.fit(f_Inputs, f_Outputs)
    gpKernels[functionName] = gpr.kernel_   #Get the kernel after it has been fitted.


    lengthScale = get_length_scale(gpr.kernel_)
    if lengthScale is not None:
        print(f"Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is {lengthScale}")


    functionProposedPoints = {}
    count = -1

    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.00787  0.037348] , Max:  [0.88388983 0.990426  ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  2.6752879910742468e-09
#
# [[ 5.000000e-001  5.000000e-001  2.675288e-009]
#  [ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 7.870000e-003  9.904260e-001  0.000000e+000]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 2.386200e-001  4.997890e-001 -1.652362e-028]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 16 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1], nu=2.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00029715, 'mean': 0.00014362, 'std': 0.00010199, 'q1': 4.786e-05, 'median': 0.00013633, 'q3': 0.00024516}
# 	Local search 1/64, x=[0.54064848 0.20768194], val=0.0002971464185211272, best=0.0002971464
# 	Local search 13/64, x=[0.48370114 0.2075543 ], val=0.0002971476463362662, best=0.0002971476
# 	Local search 31/64, x=[0.50525746 0.20755522], val=0.000297147831535259, best=0.0002971478
# 	Local search 38/64, x=[0.50151041 0.20756369], val=0.000297147881595464, best=0.0002971479
#
# 	Proposed next point to try: 0.501510-0.207564
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00362895, 'max': 0.00020682, 'mean': -0.00024042, 'std': 0.00076269, 'q1': -2.884e-05, 'median': 4.74e-06, 'q3': 1.884e-05}
# 	Local search 1/64, x=[0.41550769 0.74499216], val=0.00020682267283068587, best=0.0002068227
# 	Local search 2/64, x=[0.55055252 0.74499216], val=0.0002068239268465971, best=0.0002068239
# 	Local search 6/64, x=[0.48630778 0.74499245], val=0.0002068245999562298, best=0.0002068246
#
# 	Proposed next point to try: 0.486308-0.744992
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00358623, 'max': 0.0044584, 'mean': 0.00199194, 'std': 0.00156606, 'q1': 0.0007918, 'median': 0.0019843, 'q3': 0.00332146}
# 	Local search 1/64, x=[0.45709292 0.33406687], val=0.0044584055748784586, best=0.0044584056
# 	Local search 2/64, x=[0.50261946 0.33404359], val=0.0044584189756067105, best=0.0044584190
#
# 	Proposed next point to try: 0.502619-0.334044
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00356643, 'max': 0.00906874, 'mean': 0.00426987, 'std': 0.00286228, 'q1': 0.00185702, 'median': 0.0041335, 'q3': 0.00680954}
# 	Local search 1/64, x=[0.50261949 0.33407078], val=0.009068768463142488, best=0.0090687685
# 	Local search 28/64, x=[0.49772858 0.33407306], val=0.009068768609731397, best=0.0090687686
# 	Local search 44/64, x=[0.49949343 0.33406586], val=0.009068769342369207, best=0.0090687693
# 	Local search 56/64, x=[0.49991939 0.33407362], val=0.00906876953116353, best=0.0090687695
#
# 	Proposed next point to try: 0.499919-0.334074
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00352683, 'max': 0.01828942, 'mean': 0.00882571, 'std': 0.00559305, 'q1': 0.00393118, 'median': 0.00843771, 'q3': 0.01394563}
# 	Local search 1/64, x=[0.50261978 0.33408309], val=0.01828946820195922, best=0.0182894682
# 	Local search 19/64, x=[0.4999953  0.33406308], val=0.01828946980213007, best=0.0182894698
# 	Local search 29/64, x=[0.49999274 0.33410072], val=0.01828946994074279, best=0.0182894699
# 	Local search 44/64, x=[0.50006442 0.33409432], val=0.018289470183893264, best=0.0182894702
# 	Local search 58/64, x=[0.50000001 0.33407411], val=0.01828947030854715, best=0.0182894703
# 	Local search 62/64, x=[0.50000192 0.33407636], val=0.01828947036258617, best=0.0182894704
#
# 	Proposed next point to try: 0.500002-0.334076

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.092501   0.02869772] , Max:  [0.996055 0.970764]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
#
# [[ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.600000  0.500000  0.144121]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.996055  0.236836 -0.006793]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.092501  0.897042 -0.043957]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 16 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1], nu=2.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01605994, 'mean': 0.00039755, 'std': 0.00207446, 'q1': 0.0, 'median': 0.0, 'q3': 3.83e-06}
# 	Local search 1/64, x=[0.69195779 0.58098036], val=0.016060248792286697, best=0.0160602488
# 	Local search 4/64, x=[0.69195778 0.49549703], val=0.01606039306310685, best=0.0160603931
# 	Local search 14/64, x=[0.69195779 0.50058215], val=0.016060396072187285, best=0.0160603961
# 	Local search 34/64, x=[0.69195616 0.49981978], val=0.01606039616773836, best=0.0160603962
# 	Local search 43/64, x=[0.69195652 0.50002701], val=0.016060396358941815, best=0.0160603964
# 	Local search 51/64, x=[0.69195908 0.49998721], val=0.01606039636427731, best=0.0160603964
#
# 	Proposed next point to try: 0.691959-0.499987
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 9.309e-05, 'mean': 2.01e-06, 'std': 8.33e-06, 'q1': 0.0, 'median': 0.0, 'q3': 1e-08}
# 	Local search 1/64, x=[0.         0.70217049], val=9.321393749283993e-05, best=0.0000932139
# 	Local search 4/64, x=[0.         0.35013898], val=9.322217761669411e-05, best=0.0000932222
# 	Local search 5/64, x=[0.         0.56665876], val=9.322579454232995e-05, best=0.0000932258
# 	Local search 6/64, x=[0.         0.48222788], val=9.322632165572123e-05, best=0.0000932263
# 	Local search 36/64, x=[0.         0.49684904], val=9.322640224303454e-05, best=0.0000932264
#
# 	Proposed next point to try: 0.000000-0.496849
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 2e-08, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[2.59103253e-05 7.02170740e-01], val=1.680302639466481e-08, best=0.0000000168
#
# 	Proposed next point to try: 2.591033e-05-7.021707e-01
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.06476977, 'max': 0.61955773, 'mean': 0.156106, 'std': 0.17580171, 'q1': 0.01729047, 'median': 0.10515264, 'q3': 0.24683614}
# 	Local search 1/64, x=[0.69278714 0.50000005], val=0.6195609190256439, best=0.6195609190
# 	Local search 9/64, x=[0.69278685 0.49999999], val=0.6195609190351278, best=0.6195609190
#
# 	Proposed next point to try: 0.692787-0.500000
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.08880717, 'max': 1.07328637, 'mean': 0.5337583, 'std': 0.24557834, 'q1': 0.34468624, 'median': 0.53695684, 'q3': 0.71778237}
# 	Local search 1/64, x=[0.         0.49999994], val=1.0735032961878843, best=1.0735032962
# 	Local search 6/64, x=[0.         0.49999994], val=1.07350329618795, best=1.0735032962
# 	Local search 8/64, x=[0.         0.49999997], val=1.073503296189433, best=1.0735032962
# 	Local search 9/64, x=[0.         0.50000003], val=1.0735032961894708, best=1.0735032962
# 	Local search 11/64, x=[0.         0.49999999], val=1.0735032961908966, best=1.0735032962
# 	Local search 33/64, x=[0.  0.5], val=1.0735032961911266, best=1.0735032962
#
# 	Proposed next point to try: 0.000000-0.500000
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.23943966, 'max': 2.0351655, 'mean': 0.9191178, 'std': 0.46145977, 'q1': 0.55532648, 'median': 0.85277928, 'q3': 1.21790885}
# 	Local search 1/64, x=[0.         0.50000001], val=2.035559485494231, best=2.0355594855
# 	Local search 8/64, x=[0.  0.5], val=2.0355594854950088, best=2.0355594855
# 	Local search 54/64, x=[0.  0.5], val=2.035559485495077, best=2.0355594855
#
# 	Proposed next point to try: 0.000000-0.500000
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.51542451, 'max': 3.95892376, 'mean': 1.68983678, 'std': 0.94331103, 'q1': 0.94499462, 'median': 1.30917871, 'q3': 2.35016239}
# 	Local search 1/64, x=[0.        0.4999999], val=3.95967186408506, best=3.9596718641
# 	Local search 2/64, x=[0.         0.49999994], val=3.959671864091596, best=3.9596718641
# 	Local search 4/64, x=[0.         0.49999995], val=3.9596718640935147, best=3.9596718641
# 	Local search 6/64, x=[0.         0.49999995], val=3.9596718640944006, best=3.9596718641
# 	Local search 8/64, x=[0.         0.50000001], val=3.959671864101618, best=3.9596718641
# 	Local search 9/64, x=[0.         0.50000001], val=3.9596718641016992, best=3.9596718641
# 	Local search 10/64, x=[0.  0.5], val=3.9596718641025213, best=3.9596718641
# 	Local search 12/64, x=[0.  0.5], val=3.9596718641025634, best=3.9596718641
# 	Local search 23/64, x=[0.  0.5], val=3.9596718641025896, best=3.9596718641
# 	Local search 24/64, x=[0.  0.5], val=3.959671864102593, best=3.9596718641
# 	Local search 31/64, x=[0.  0.5], val=3.959671864103007, best=3.9596718641
#
# 	Proposed next point to try: 0.000000-0.500000

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.600097  0.725136  0.066089 -0.036378]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.500003  0.500001  0.656244 -0.092565]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.431029  0.814368  0.806413 -0.098068]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965337  0.047492  0.944587 -0.273443]
#  [ 0.151837  0.439991  0.990882 -0.398926]]
#
# Starting 3D Bayes Optimisation from 21 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1, 1], nu=1.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01833951, 'mean': 0.0039951, 'std': 0.00501677, 'q1': 1.22e-06, 'median': 0.00167871, 'q3': 0.00658444}
# 	Local search 1/96, x=[0.51025377 0.50768745 0.50213764], val=0.01833951952262902, best=0.0183395195
# 	Local search 31/96, x=[0.48846522 0.50017302 0.50213717], val=0.018339523150227438, best=0.0183395232
#
# 	Proposed next point to try: 0.488465-0.500173-0.502137
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00151307, 'mean': 0.00011091, 'std': 0.00025094, 'q1': 0.0, 'median': 9e-08, 'q3': 4.894e-05}
# 	Local search 1/96, x=[0.73098758 0.24050921 0.        ], val=0.0015133592103615038, best=0.0015133592
# 	Local search 2/96, x=[0.5874954  0.53354384 0.        ], val=0.0015140067425379125, best=0.0015140067
# 	Local search 25/96, x=[0.47140106 0.46695525 0.        ], val=0.0015140162276885377, best=0.0015140162
# 	Local search 69/96, x=[0.50464414 0.52744071 0.        ], val=0.0015140183128094335, best=0.0015140183
#
# 	Proposed next point to try: 0.504644-0.527441-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[7.30992394e-01 2.40500702e-01 1.51982531e-05], val=5.144070094568373e-12, best=0.0000000000
#
# 	Proposed next point to try: 7.309924e-01-2.405007e-01-1.519825e-05
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.38068275, 'max': -0.01907104, 'mean': -0.09221102, 'std': 0.07508779, 'q1': -0.11153492, 'median': -0.06426021, 'q3': -0.04586843}
# 	Local search 1/96, x=[1.         0.         0.48194682], val=-0.018827291317507776, best=-0.0188272913
# 	Local search 2/96, x=[1.        1.        0.4819469], val=-0.018827290415457307, best=-0.0188272904
# 	Local search 58/96, x=[1.         1.         0.48194689], val=-0.018827290415457252, best=-0.0188272904
# 	Local search 79/96, x=[1.         1.         0.48194689], val=-0.018827290415457137, best=-0.0188272904
#
# 	Proposed next point to try: 1.000000-1.000000-0.481947
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.27676804, 'max': 0.36648974, 'mean': 0.10326749, 'std': 0.12921481, 'q1': 0.01908802, 'median': 0.11097819, 'q3': 0.19896897}
# 	Local search 1/96, x=[0.50084114 0.50000093 0.        ], val=0.36665814095474303, best=0.3666581410
# 	Local search 3/96, x=[0.50043231 0.49966998 0.        ], val=0.3666581419178991, best=0.3666581419
# 	Local search 4/96, x=[0.50056811 0.49993875 0.        ], val=0.36665814344085207, best=0.3666581434
# 	Local search 5/96, x=[0.50000246 0.50000066 0.        ], val=0.36665815066793367, best=0.3666581507
#
# 	Proposed next point to try: 0.500002-0.500001-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.17075959, 'max': 0.80260735, 'mean': 0.30273536, 'std': 0.20435131, 'q1': 0.14357687, 'median': 0.29643662, 'q3': 0.45565692}
# 	Local search 1/96, x=[0.50000007 0.49865173 0.        ], val=0.8029975095755676, best=0.8029975096
# 	Local search 3/96, x=[0.49992127 0.5        0.        ], val=0.8029975419552217, best=0.8029975420
# 	Local search 5/96, x=[0.50000073 0.50007367 0.        ], val=0.8029975420642189, best=0.8029975421
# 	Local search 7/96, x=[0.50003823 0.50000669 0.        ], val=0.8029975428064452, best=0.8029975428
# 	Local search 10/96, x=[0.50000905 0.50000003 0.        ], val=0.8029975437079783, best=0.8029975437
# 	Local search 19/96, x=[0.50000128 0.50000005 0.        ], val=0.802997543902767, best=0.8029975439
#
# 	Proposed next point to try: 0.500001-0.500000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.03932127, 'max': 1.67484258, 'mean': 0.7016711, 'std': 0.36556811, 'q1': 0.37252473, 'median': 0.66449105, 'q3': 0.99777005}
# 	Local search 1/96, x=[0.5        0.49849157 0.        ], val=1.675676250054976, best=1.6756762501
# 	Local search 2/96, x=[0.50006831 0.49878471 0.        ], val=1.6756762622734045, best=1.6756762623
# 	Local search 3/96, x=[0.49998717 0.50000001 0.        ], val=1.675676329727667, best=1.6756763297
# 	Local search 12/96, x=[0.50000021 0.5000044  0.        ], val=1.6756763301592696, best=1.6756763302
# 	Local search 33/96, x=[0.50000378 0.50000025 0.        ], val=1.6756763301902406, best=1.6756763302
# 	Local search 57/96, x=[0.49999999 0.49999949 0.        ], val=1.6756763303742637, best=1.6756763304
#
# 	Proposed next point to try: 0.500000-0.499999-0.000000

# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -41.47155372, 'max': 0.43047833, 'mean': -17.26023648, 'std': 6.97838639, 'q1': -22.09311056, 'median': -17.20095309, 'q3': -12.09946765}
# 	Local search 1/128, x=[0.41521323 0.41316125 0.38027761 0.4300959 ], val=0.5897094450662808, best=0.5897094451
# 	Local search 2/128, x=[0.41521405 0.41316106 0.38027338 0.43009507], val=0.5897094460137293, best=0.5897094460
# 	Local search 3/128, x=[0.41521454 0.41316238 0.38027423 0.4300939 ], val=0.5897094461384174, best=0.5897094461
# 	Local search 13/128, x=[0.41521358 0.41316268 0.38027422 0.43009448], val=0.5897094462818073, best=0.5897094463
#
# 	Proposed next point to try: 0.415214-0.413163-0.380274-0.430094
#
# Using UCB Acquisition function with Kappa = 5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -31.97111992, 'max': 3.4568727, 'mean': -9.07840946, 'std': 6.01363425, 'q1': -13.11191842, 'median': -8.76232603, 'q3': -4.54133725}
# 	Local search 1/128, x=[0.43707624 0.47893913 0.18081384 0.43949396], val=3.5716647640178305, best=3.5716647640
# 	Local search 2/128, x=[0.43707121 0.47893478 0.18080249 0.43949568], val=3.571664768488286, best=3.5716647685
# 	Local search 14/128, x=[0.43707449 0.47893274 0.18080611 0.43949522], val=3.5716647684891827, best=3.5716647685
#
# 	Proposed next point to try: 0.437074-0.478933-0.180806-0.439495
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -30.1300753, 'max': 23.93023478, 'mean': -0.72960637, 'std': 6.47800595, 'q1': -4.86589486, 'median': -0.02677001, 'q3': 3.8779167}
# 	Local search 1/128, x=[1. 0. 0. 0.], val=28.575357881296362, best=28.5753578813
#
# 	Proposed next point to try: 1.000000-0.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -27.04939483, 'max': 73.9413298, 'mean': 15.96799979, 'std': 10.48338525, 'q1': 9.07679771, 'median': 15.99578837, 'q3': 22.26838215}
# 	Local search 1/128, x=[1. 0. 1. 1.], val=78.62758949513167, best=78.6275894951
# 	Local search 2/128, x=[1. 0. 0. 0.], val=81.97755095194624, best=81.9775509519
#
# 	Proposed next point to try: 1.000000-0.000000-0.000000-0.000000

# %%
f5_Inputs, f5_Outputs = combineInitialDataAndSubmissionsToDate(5)
findNextGuess('F5', f5_Inputs, f5_Outputs)
# Out:
# ********************
# F5  -  4 D
# ********************
#  Inputs -   Min: [0.013737   0.03819337 0.08894684 0.07288048] , Max:  [0.924901   0.86254031 1.         1.        ]
#  Output -   Min: 0.1129397953712203 , Max (Best):  2263.948440073915
#
# [[3.251100e-01 8.389740e-01 1.000000e+00 9.341090e-01 2.263948e+03]
#  [3.251100e-01 8.389740e-01 1.000000e+00 9.341090e-01 2.263948e+03]
#  [2.983980e-01 8.408080e-01 9.794320e-01 9.188810e-01 1.959096e+03]
#  [5.792990e-01 2.734650e-01 9.003050e-01 1.000000e+00 1.193843e+03]
#  [2.241890e-01 8.464805e-01 8.794842e-01 8.785157e-01 1.088860e+03]
#  [1.198792e-01 8.625403e-01 6.433313e-01 8.498038e-01 4.316128e+02]
#  [4.389334e-01 7.740918e-01 3.781671e-01 9.336962e-01 3.558068e+02]
#  [8.364780e-01 1.936096e-01 6.638927e-01 7.856489e-01 2.583705e+02]
#  [4.634423e-01 6.300245e-01 1.079065e-01 9.576439e-01 2.332236e+02]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 107.46646317, 'mean': 0.00426011, 'std': 0.51629307, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.50000011 1.         1.         1.        ], val=122.22541238003842, best=122.2254123800
# 	Local search 3/128, x=[0.50000004 1.         1.         1.        ], val=122.2254123802357, best=122.2254123802
# 	Local search 5/128, x=[0.49999997 1.         1.         1.        ], val=122.22541238025154, best=122.2254123803
# 	Local search 12/128, x=[0.50000002 1.         1.         1.        ], val=122.22541238030826, best=122.2254123803
# 	Local search 15/128, x=[0.49999999 1.         1.         1.        ], val=122.22541238031671, best=122.2254123803
# 	Local search 18/128, x=[0.5 1.  1.  1. ], val=122.22541238034347, best=122.2254123803
# 	Local search 23/128, x=[0.5 1.  1.  1. ], val=122.22541238034937, best=122.2254123803
# 	Local search 103/128, x=[0.5 1.  1.  1. ], val=122.22541238035276, best=122.2254123804
#
# 	Proposed next point to try: 0.500000-1.000000-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -128.79448858, 'max': 2257.79572464, 'mean': 216.26883538, 'std': 310.0983257, 'q1': 44.22184035, 'median': 97.61954324, 'q3': 273.36117376}
# 	Local search 1/128, x=[0.50017958 0.94304371 1.         1.        ], val=2260.061886488395, best=2260.0618864884
# 	Local search 2/128, x=[0.50000001 0.94308998 1.         1.        ], val=2260.0619034838487, best=2260.0619034838
# 	Local search 3/128, x=[0.49999999 0.94308926 1.         1.        ], val=2260.061903501275, best=2260.0619035013
# 	Local search 15/128, x=[0.49999968 0.94308584 1.         1.        ], val=2260.0619035101354, best=2260.0619035101
# 	Local search 32/128, x=[0.49999988 0.94308705 1.         1.        ], val=2260.0619035225714, best=2260.0619035226
# 	Local search 35/128, x=[0.49999988 0.94308632 1.         1.        ], val=2260.0619035230857, best=2260.0619035231
# 	Local search 39/128, x=[0.49999991 0.94308681 1.         1.        ], val=2260.0619035247028, best=2260.0619035247
# 	Local search 47/128, x=[0.50000004 0.94308655 1.         1.        ], val=2260.061903527275, best=2260.0619035273
# 	Local search 100/128, x=[0.5        0.94308701 1.         1.        ], val=2260.061903528822, best=2260.0619035288
# 	Local search 111/128, x=[0.49999999 0.94308651 1.         1.        ], val=2260.0619035289374, best=2260.0619035289
#
# 	Proposed next point to try: 0.500000-0.943087-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 153.71555154, 'max': 2982.99455945, 'mean': 628.50692908, 'std': 482.45389295, 'q1': 302.36933911, 'median': 447.2971278, 'q3': 774.77476627}
# 	Local search 1/128, x=[0.50000001 0.90828419 1.         0.        ], val=3002.482821579622, best=3002.4828215796
# 	Local search 3/128, x=[0.49999996 0.90828492 1.         0.        ], val=3002.4828215853463, best=3002.4828215853
# 	Local search 13/128, x=[0.49999999 0.90828801 1.         0.        ], val=3002.4828215884536, best=3002.4828215885
# 	Local search 14/128, x=[0.50000004 0.90828562 1.         0.        ], val=3002.4828215893426, best=3002.4828215893
# 	Local search 43/128, x=[0.5      0.908286 1.       0.      ], val=3002.4828215934003, best=3002.4828215934
# 	Local search 98/128, x=[0.5        0.90828634 1.         0.        ], val=3002.482821594347, best=3002.4828215943
#
# 	Proposed next point to try: 0.500000-0.908286-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 358.40473779, 'max': 5400.94812596, 'mean': 1049.1580451, 'std': 753.7059032, 'q1': 554.77636623, 'median': 773.74915024, 'q3': 1252.20918245}
# 	Local search 1/128, x=[0.50007822 0.90116795 1.         0.        ], val=5442.642001611942, best=5442.6420016119
# 	Local search 2/128, x=[0.49999996 0.9012737  1.         0.        ], val=5442.64206278616, best=5442.6420627862
# 	Local search 4/128, x=[0.49999965 0.90129169 1.         0.        ], val=5442.642062899831, best=5442.6420628998
# 	Local search 7/128, x=[0.50000068 0.90128747 1.         0.        ], val=5442.642063042941, best=5442.6420630429
# 	Local search 8/128, x=[0.50000016 0.90127914 1.         0.        ], val=5442.642063078059, best=5442.6420630781
# 	Local search 11/128, x=[0.50000003 0.90128519 1.         0.        ], val=5442.642063172004, best=5442.6420631720
# 	Local search 31/128, x=[0.50000002 0.90128435 1.         0.        ], val=5442.642063178901, best=5442.6420631789
# 	Local search 66/128, x=[0.50000001 0.90128381 1.         0.        ], val=5442.642063181971, best=5442.6420631820
#
# 	Proposed next point to try: 0.500000-0.901284-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 728.55696321, 'max': 10236.85525897, 'mean': 1890.46027713, 'std': 1353.66099906, 'q1': 1059.78262934, 'median': 1400.73181053, 'q3': 2152.30722832}
# 	Local search 1/128, x=[0.50000037 0.8966178  1.         0.        ], val=10323.337578584802, best=10323.3375785848
# 	Local search 3/128, x=[0.50000034 0.89662629 1.         0.        ], val=10323.33757909069, best=10323.3375790907
# 	Local search 9/128, x=[0.49999989 0.89662703 1.         0.        ], val=10323.337579148003, best=10323.3375791480
# 	Local search 13/128, x=[0.49999999 0.89662555 1.         0.        ], val=10323.33757916759, best=10323.3375791676
# 	Local search 19/128, x=[0.49999999 0.89662668 1.         0.        ], val=10323.337579172212, best=10323.3375791722
#
# 	Proposed next point to try: 0.500000-0.896627-1.000000-0.000000

# %%
f6_Inputs, f6_Outputs = combineInitialDataAndSubmissionsToDate(6)
findNextGuess('F6', f6_Inputs, f6_Outputs)
# Out:
# ********************
# F6  -  5 D
# ********************
#  Inputs -   Min: [0.0088    0.076503  0.0165229 0.042143  0.003667 ] , Max:  [0.95773967 0.93187122 0.989507   0.992791   0.89281919]
#  Output -   Min: -2.5711696316081234 , Max (Best):  -0.2776577094327388
#
# [[ 0.400740  0.365117  0.465329  0.765461  0.143118 -0.277658]
#  [ 0.728186  0.154693  0.732552  0.693997  0.056401 -0.714265]
#  [ 0.618812  0.331802  0.187288  0.756238  0.328835 -0.829237]
#  [ 0.585939  0.538496  0.989507  0.863517  0.003667 -0.897936]
#  [ 0.782880  0.536336  0.443284  0.859700  0.010326 -0.935757]
#  [ 0.536797  0.308781  0.411879  0.388225  0.522528 -1.144785]
#  [ 0.242384  0.844100  0.577809  0.679021  0.501953 -1.209955]
#  [ 0.145111  0.896685  0.896322  0.726272  0.236272 -1.233786]
#  [ 0.784958  0.910682  0.708120  0.959225  0.004911 -1.247049]
 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.37021606 0.         0.60000243 1.         0.        ], val=0.011362842800490732, best=0.0113628428
# 	Local search 2/160, x=[0.3702255  0.         0.59998375 1.         0.        ], val=0.011362842866632443, best=0.0113628429
# 	Local search 15/160, x=[0.37022584 0.         0.59998376 1.         0.        ], val=0.011362842866814792, best=0.0113628429
# 	Local search 19/160, x=[0.37022646 0.         0.59998369 1.         0.        ], val=0.011362842866919257, best=0.0113628429
# 	Local search 26/160, x=[0.37022638 0.         0.59998329 1.         0.        ], val=0.011362842866966646, best=0.0113628429
# 	Local search 59/160, x=[0.37022638 0.         0.59998286 1.         0.        ], val=0.011362842866967733, best=0.0113628429
# 	Local search 64/160, x=[0.37022641 0.         0.59998294 1.         0.        ], val=0.011362842866972684, best=0.0113628429
# 	Local search 78/160, x=[0.37022641 0.         0.59998297 1.         0.        ], val=0.011362842866974362, best=0.0113628429
#
# 	Proposed next point to try: 0.370226-0.000000-0.599983-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.23475196 0.22543532 0.47382277 0.01451689 0.9914135 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.234752-0.225435-0.473823-0.014517-0.991413
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.7129615, 'max': -0.11112484, 'mean': -1.44080483, 'std': 0.43545422, 'q1': -1.75734057, 'median': -1.45818535, 'q3': -1.13991556}
# 	Local search 1/160, x=[0.40965614 0.         0.55206011 1.         0.        ], val=-0.07182936134755383, best=-0.0718293613
# 	Local search 2/160, x=[0.40965587 0.         0.55205957 1.         0.        ], val=-0.0718293613447442, best=-0.0718293613
# 	Local search 3/160, x=[0.40965551 0.         0.55205912 1.         0.        ], val=-0.07182936134381386, best=-0.0718293613
# 	Local search 33/160, x=[0.40965544 0.         0.55205928 1.         0.        ], val=-0.0718293613438116, best=-0.0718293613
# 	Local search 58/160, x=[0.40965549 0.         0.55205921 1.         0.        ], val=-0.0718293613437904, best=-0.0718293613
#
# 	Proposed next point to try: 0.409655-0.000000-0.552059-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.83395445, 'max': 1.16758177, 'mean': -0.43382579, 'std': 0.44049683, 'q1': -0.74813046, 'median': -0.46566236, 'q3': -0.149411}
# 	Local search 1/160, x=[0.19866757 0.         0.96322072 1.         0.        ], val=1.2289923732635388, best=1.2289923733
# 	Local search 2/160, x=[0.19866783 0.         0.96322029 1.         0.        ], val=1.2289923732635841, best=1.2289923733
# 	Local search 3/160, x=[0.1986681  0.         0.96322035 1.         0.        ], val=1.2289923732636487, best=1.2289923733
# 	Local search 8/160, x=[0.1986678  0.         0.96322069 1.         0.        ], val=1.2289923732637793, best=1.2289923733
# 	Local search 11/160, x=[0.1986679  0.         0.96322056 1.         0.        ], val=1.2289923732638046, best=1.2289923733
# 	Local search 20/160, x=[0.1986679  0.         0.96322059 1.         0.        ], val=1.228992373263811, best=1.2289923733
# 	Local search 90/160, x=[0.19866788 0.         0.96322056 1.         0.        ], val=1.228992373263813, best=1.2289923733
# 	Local search 152/160, x=[0.1986679  0.         0.96322061 1.         0.        ], val=1.228992373263816, best=1.2289923733
#
# 	Proposed next point to try: 0.198668-0.000000-0.963221-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min':
# 	Local search 34/192, x=[0.04291905 0.53604906 0.39322237 0.1571483  0.35477194 0.72850919], val=1.6347743462133524, best=1.6347743462
# 	Local search 119/192, x=[0.04291816 0.4791675  0.3921734  0.15714818 0.35477193 0.72850921], val=1.6347743463718698, best=1.6347743464
# 	Local search 142/192, x=[0.04291804 0.49490088 0.3824536  0.15714749 0.35477231 0.72850892], val=1.6347743463853635, best=1.6347743464
#
# 	Proposed next point to try: 0.042918-0.494901-0.382454-0.157147-0.354772-0.728509
#
# Using UCB Acquisition function with Kappa = 5
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.12017293, 'max': 2.31501851, 'mean': 1.35632495, 'std': 0.31581758, 'q1': 1.14952318, 'median': 1.36068066, 'q3': 1.573302}
# 	Local search 1/192, x=[0.05117799 0.57180788 0.55083496 0.03703952 0.33274171 0.60855417], val=2.327091926857681, best=2.3270919269
#
# 	Proposed next point to try: 0.051178-0.571808-0.550835-0.037040-0.332742-0.608554
#
# Using UCB Acquisition function with Kappa = 10
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.22192711, 'max': 3.56094939, 'mean': 2.44397806, 'std': 0.5043284, 'q1': 2.11866786, 'median': 2.47868403, 'q3': 2.83126919}
# 	Local search 1/192, x=[0.05264202 0.66443    0.31777615 0.03061843 0.33925616 0.51973023], val=3.5817505723543093, best=3.5817505724
# 	Local search 2/192, x=[0.0526421  0.31571157 0.56553051 0.03061853 0.3392563  0.51973033], val=3.581750575509144, best=3.5817505755
# 	Local search 4/192, x=[0.05265873 0.52722977 0.33926927 0.03062391 0.33925923 0.51972921], val=3.5817505783070267, best=3.5817505783
# 	Local search 8/192, x=[0.05264188 0.48226803 0.41795168 0.03061775 0.339255   0.51973126], val=3.5817505830697396, best=3.5817505831
# 	Local search 11/192, x=[0.05264322 0.54530785 0.64725053 0.0306183  0.33925631 0.51972998], val=3.581750583099201, best=3.5817505831
# 	Local search 28/192, x=[0.05264224 0.56354969 0.58459534 0.03061835 0.33925498 0.51973108], val=3.5817505839042267, best=3.5817505839
#
# 	Proposed next point to try: 0.052642-0.563550-0.584595-0.030618-0.339255-0.519731
#
# Using UCB Acquisition function with Kappa = 20
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.42543548, 'max': 6.5761332, 'mean': 4.61928428, 'std': 0.9384668, 'q1': 4.02612895, 'median': 4.68035089, 'q3': 5.32318594}
# 	Local search 1/192, x=[0.0756806  0.66665819 0.71021498 0.04263072 0.95999377 0.03559794], val=6.59369351810991, best=6.5936935181
# 	Local search 5/192, x=[0.07566988 0.32066581 0.35083451 0.04263223 0.96000002 0.0356084 ], val=6.593693569532183, best=6.5936935695
# 	Local search 10/192, x=[0.07568371 0.56901375 0.66385874 0.0426258  0.95999932 0.03561278], val=6.5936935809182895, best=6.5936935809
# 	Local search 13/192, x=[0.0756832  0.63209539 0.38990673 0.04262492 0.95999896 0.03561245], val=6.5936935848009375, best=6.5936935848
# 	Local search 38/192, x=[0.07568304 0.44085655 0.53175171 0.0426248  0.95999896 0.03561246], val=6.593693586210502, best=6.5936935862
# 	Local search 52/192, x=[0.0756827  0.52121387 0.52034472 0.04262453 0.95999925 0.03561243], val=6.593693586264516, best=6.5936935863
 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.0880104  0.11729079 0.18832612 0.01888423 1.         0.49684145
#  0.21758514 0.84530992], val=0.05638185453061289, best=0.0563818545
# 	Local search 2/256, x=[0.08787655 0.11741074 0.1882501  0.01879875 1.         0.49689172
#  0.21755632 0.74019361], val=0.05638223568591665, best=0.0563822357
# 	Local search 4/256, x=[0.08779936 0.11737989 0.18824172 0.01875196 1.         0.496977
#  0.21760333 0.71968125], val=0.056382237555735626, best=0.0563822376
# 	Local search 17/256, x=[0.08779382 0.11727053 0.18825258 0.018717   1.         0.49679763
#  0.21758092 0.75890434], val=0.05638224335212293, best=0.0563822434
# 	Local search 29/256, x=[0.08777921 0.11733187 0.1882767  0.01875332 1.         0.49688767
#  0.21749205 0.73165373], val=0.0563822448358714, best=0.0563822448
# 	Local search 48/256, x=[0.08773976 0.11739173 0.18825844 0.01873914 1.         0.49688913
#  0.21756105 0.71685644], val=0.05638225033612607, best=0.0563822503
# 	Local search 49/256, x=[0.08776624 0.11733983 0.18825913 0.0187166  1.         0.49688542
#  0.21757544 0.7677698 ], val=0.05638225035450961, best=0.0563822504
# 	Local search 149/256, x=[0.08776554 0.11734643 0.18823108 0.0187458  1.         0.49683867
#  0.21757284 0.76154787], val=0.05638225290306938, best=0.0563822529
#
# 	Proposed next point to try: 0.087766-0.117346-0.188231-0.018746-1.000000-0.496839-0.217573-0.761548
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.01634455 0.09361664 0.19497038 0.04930575 0.81764523 0.65291518
#  0.03039205 0.23122174], val=1.7324152698268625e-09, best=0.0000000017
#
# 	Proposed next point to try: 0.016345-0.093617-0.194970-0.049306-0.817645-0.652915-0.030392-0.231222
#
# Using Expected Improvement Acquisition function with xi = 20
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.27895135 0.84542138 0.15656386 0.78704339 0.71068144 0.98448546
#  0.60857508 0.5464531 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.278951-0.845421-0.156564-0.787043-0.710681-0.984485-0.608575-0.546453
#
# Using UCB Acquisition function with Kappa = 0.1
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.04857936, 'max': 9.926532, 'mean': 7.90886346, 'std': 0.94936575, 'q1': 7.27529896, 'median': 8.00271039, 'q3': 8.63660036}
# 	Local search 1/256, x=[0.10668103 0.12719252 0.18693481 0.08339248 0.92946599 0.48913579
#  0.21812878 0.45558458], val=9.974540809686305, best=9.9745408097
# 	Local search 5/256, x=[0.10666918 0.12731962 0.18694832 0.08343961 0.92947187 0.48906867
#  0.21810221 0.57793382], val=9.97454084628664, best=9.9745408463
# 	Local search 14/256, x=[0.1066997  0.12723497 0.18695982 0.08345476 0.92945356 0.48904402
#  0.2181074  0.60363563], val=9.974540850224294, best=9.9745408502
# 	Local search 27/256, x=[0.10670215 0.12730757 0.1869247  0.08344988 0.92946226 0.48910362
#  0.21815865 0.64527059], val=9.974540851068467, best=9.9745408511
# 	Local search 68/256, x=[0.10668888 0.12726971 0.18694532 0.08344749 0.92945639 0.48908946
#  0.21810335 0.63174684], val=9.97454085811237, best=9.9745408581
#
# 	Proposed next point to try: 0.106689-0.127270-0.186945-0.083447-0.929456-0.489089-0.218103-0.631747
#
# Using UCB Acquisition function with Kappa = 5
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.72072444, 'max': 10.2235085, 'mean': 8.26353303, 'std': 0.92331629, 'q1': 7.6264918, 'median': 8.34939349, 'q3': 8.98264197}
# 	Local search 1/256, x=[0.04568218 0.05910094 0.3020326  0.05376053 0.93282323 0.65454724
#  0.05478588 0.23131026], val=10.312092400770682, best=10.3120924008
# 	Local search 2/256, x=[0.04569227 0.05912786 0.30192505 0.05376846 0.93284932 0.6548244
#  0.05479542 0.57790858], val=10.312093413844428, best=10.3120934138
# 	Local search 3/256, x=[0.0456817  0.05911905 0.3019434  0.05376561 0.93283372 0.65462952
#  0.05477975 0.30570735], val=10.312093558160239, best=10.3120935582
# 	Local search 104/256, x=[0.04568633 0.05911008 0.30197595 0.05378165 0.93283685 0.65466124
#  0.05478966 0.31501433], val=10.312093559756292, best=10.3120935598
#
# 	Proposed next point to try: 0.045686-0.059110-0.301976-0.053782-0.932837-0.654661-0.054790-0.315014
#
# Using UCB Acquisition function with Kappa = 10
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.33057343, 'max': 10.80409795, 'mean': 8.62544076, 'std': 0.92066093, 'q1': 7.97119932, 'median': 8.69279326, 'q3': 9.34532353}
# 	Local search 1/256, x=[0.4824297  0.04043899 0.03429917 0.03407985 0.06516176 0.93934046
#  0.02455961 0.48300862], val=10.852769419487684, best=10.8527694195
# 	Local search 3/256, x=[0.02713976 0.06785677 0.0296725  0.95712841 0.95775876 0.03730138
#  0.03909303 0.74100003], val=10.900433229627863, best=10.9004332296
# 	Local search 4/256, x=[0.02758592 0.04203387 0.36773248 0.03599077 0.94032125 0.93389104
#  0.02672424 0.32589027], val=10.914497254970213, best=10.9144972550
# 	Local search 8/256, x=[0.94402857 0.02909473 0.02553807 0.02777614 0.94583361 0.03474186
#  0.02825453 0.32530155], val=10.947980459185635, best=10.9479804592
# 	Local search 22/256, x=[0.94400067 0.02909382 0.0255342  0.02779146 0.94586019 0.03474802
#  0.02826678 0.7309618 ], val=10.947980527844749, best=10.9479805278
# 	Local search 46/256, x=[0.9440133  0.0290985  0.02553377 0.02777715 0.94586772 0.03475165
#  0.02826947 0.55867248], val=10.94798061106643, best=10.9479806111
# 	Local search 79/256, x=[0.9439991  0.02909565 0.02553452 0.02778078 0.94584038 0.03474806
#  0.02826193 0.5851247 ], val=10.947980633497123, best=10.9479806335
# 	Local search 177/256, x=[0.9440082  0.02909719 0.02553419 0.02778202 0.94583787 0.03474394
#  0.02826219 0.63274843], val=10.947980664037777, best=10.9479806640
#
# 	Proposed next point to try: 0.944008-0.029097-0.025534-0.027782-0.945838-0.034744-0.028262-0.632748
#
# Using UCB Acquisition function with Kappa = 20
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.90971963, 'max': 12.83624227, 'mean': 9.34925621, 'std': 0.9868274, 'q1': 8.63012407, 'median': 9.36228557, 'q3': 10.08846455}
# 	Local search 1/256, x=[0.97461403 0.02236944 0.01333981 0.01649506 0.04791677 0.96677292
#  0.00869215 0.70867197], val=13.579238619473614, best=13.5792386195
# 	Local search 2/256, x=[0.97461231 0.02237378 0.01335403 0.01650291 0.04790565 0.96676891
#  0.0086862  0.32863215], val=13.579239188011949, best=13.5792391880
# 	Local search 15/256, x=[0.98158355 0.01762179 0.0131125  0.01403472 0.04772163 0.02588759
#  0.01695517 0.53781876], val=13.603339967627475, best=13.6033399676
# 	Local search 17/256, x=[0.98158039 0.01762545 0.01311561 0.01402634 0.04771034 0.0258899
#  0.01695007 0.58010553], val=13.603340017551233, best=13.6033400176
# 	Local search 79/256, x=[0.98158559 0.01762662 0.01310947 0.01403198 0.04772748 0.02588688
#  0.01695634 0.63121173], val=13.603340074300155, best=13.6033400743
#
# 	Proposed next point to try: 0.981586-0.017627-0.013109-0.014032-0.047727-0.025887-0.016956-0.631212

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: 1.09**2 * Matern(length_scale=[7.94e+04, 0.0371], nu=2.5) + WhiteKernel(noise_level=1e-05)
# F2: 1.08**2 * Matern(length_scale=[0.0691, 1e+05], nu=2.5) + WhiteKernel(noise_level=0.0123)
# F3: 1.24**2 * Matern(length_scale=[3.46e+04, 1.41e+04, 0.072], nu=1.5) + WhiteKernel(noise_level=0.0342)
# F4: 7.35**2 * Matern(length_scale=[5.02, 5.01, 5.1, 5], nu=1.5) + WhiteKernel(noise_level=1e-05)
# F5: 1.83**2 * RBF(length_scale=[1e+05, 5.19, 0.297, 0.61]) + WhiteKernel(noise_level=0.00201)
# F6: 2.62**2 * Matern(length_scale=[1.35, 3.01, 2.2, 3.06, 3.57], nu=1.5) + WhiteKernel(noise_level=0.0425)
# F7: 0.899**2 * Matern(length_scale=[1.17, 1.14e+04, 5.89e+03, 0.472, 0.203, 0.242], nu=1.5) + WhiteKernel(noise_level=1e-05)
# F8: 9.88**2 * Matern(length_scale=[5.87, 8.29, 4.59, 9.03, 18.3, 8.08, 5.91, 1e+05], nu=2.5) + WhiteKernel(noise_level=1e-05)
#
#
# F1:
# 0: 0.501510-0.207564
# 1: 0.016199-0.328627
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 0.486308-0.744992
# 5: 0.502619-0.334044
# 6: 0.499919-0.334074
# 7: 0.500002-0.334076
#
# F2:
# 0: 0.691959-0.499987
# 1: 0.000000-0.496849
# 2: 2.591033e-05-7.021707e-01
# 3: 0.016199-0.328627
# 4: 0.692787-0.500000
# 5: 0.000000-0.500000
