# %% [markdown]
# ## Setup

# %%
import os

from numpy import ndarray
from sklearn.gaussian_process.kernels import Matern, RationalQuadratic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats._qmc import Sobol
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats import norm
from scipy.optimize import minimize
import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'


def penaltyWeightAndScaleForDimension(d):
    #Curse of dimensionality means this needs to be much tighter at higher dimensions
    #This is intended to reduce the acquisition function's information gain by 10% if the point has a Euclidean distance of 1/20th or 1/50th of a boundary.
    if d <= 5:
        return 0.1, 0.05
    else:
        return 0.1, 0.02

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma

#
def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }


from sklearn.model_selection import GridSearchCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

def findTunedGaussianProcessRegressor(X_samples, y_samples):
    #Use grid search to work out which GP hyper params are best to fit to this problem
    param_grid = {
        'kernel': [RBF(length_scale=0.5), RBF(length_scale=1.0), RBF(length_scale=2.0),
                   Matern(nu=0.5, length_scale=1.0), Matern(nu=1.5,length_scale=1.0 ), Matern(nu=2.5, length_scale=1.0),
                   Matern(nu=0.5, length_scale=2.0), Matern(nu=1.5,length_scale=2.0 ), Matern(nu=2.5, length_scale=2.0),
                   RationalQuadratic(alpha=1.0, length_scale=1.0), RationalQuadratic(alpha=1.0, length_scale=2.0)],
        'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
        'n_restarts_optimizer': [5, 10, 20]
    }
    gp = GaussianProcessRegressor()
    grid_search = GridSearchCV(gp, param_grid, cv=3)
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_



def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims
    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]
    penaltyWeight, penalityScale = penaltyWeightAndScaleForDimension(n_dims)

    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )

    gp.fit(X_samples, y_samples)


    # -----------------------------
    # 2. Acquisition function
    # -----------------------------

    # -----------------------------
    # 2.1 Boundary Penalty.
    # GP tends to hug the boundary, so add a penalty if a suggested point is close to boundary.
    # Scale controls how far from the boundary the penalty reaches. At scale=0.05, a point at x=0.05 gets a penalty of exp(-1) ≈ 0.37, meaning the penalty is significant only within the last ~5% of the search space.
    # Weight controls how strongly that penalty suppresses the acquisition value. At weight=0.1, the maximum possible suppression is 10% of the acquisition value.
    #
    # -----------------------------
    def boundary_penalty(X, weight=0.1, scale=0.05):
        X = np.atleast_2d(X)
        d = np.minimum(X, 1.0 - X)    #Find point closest to boundary at 0 or 1 in any dimension.
        penalty = np.mean(np.exp(-d / scale), axis=1)   #exp(-small) tends towards 1, exp(-large) tends towards 0. Mean takes into account other dimensions.
        return weight * penalty


    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        penalty = boundary_penalty(X, weight=penaltyWeight, scale=penalityScale)
        return val * (1 - penalty)


    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Filter out duplicate candidates - because acquisition functions can suggest previous points.
    def is_duplicate(x, X_samples, tol=1e-5):
        return np.any(np.linalg.norm(X_samples - x, axis=1) < tol)
    mask = np.array([not is_duplicate(x, X_samples) for x in X_candidates])
    X_candidates = X_candidates[mask]
    acq_vals = acq_vals[mask]


    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{len(X_candidates)} Sobol candidates, best {len(X_start)} to be minimised in local search")
    print(f"\tInitial acquisition function stats {summary_stats(acq_vals)}")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition


    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun
        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
def sortByLargestOutputDescending(arr):
    return  arr[np.argsort(arr[:, 2])[::-1]]

def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')



def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)


    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem is ${bestParams}")
    gpKernels[functionName] = bestParams


    functionProposedPoints = {}
    count = -1
    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
def collatePreviousSubmissions(functionNo):
    functionIndex = functionNo -1
    assert(functionIndex >= 0)
    assert(functionIndex <= 7)

    #Search for subfolders and find last submission week and results
    week_folders = [d for d in os.listdir("submission_results") if d.startswith("week") ]
    week_folders.sort(key=lambda w: int(w.replace("week", "")))
    last_week = week_folders[-1]
    week_dir = os.path.join("submission_results", last_week)


    def load_file(file_name):
        file_path = os.path.join(week_dir, file_name)
        all_lines = []
        with open(file_path, "r") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                # Parse the trusted Python literals
                parsedData = eval(line, {"array": np.array, "np": np})
                all_lines.append(parsedData)
        return all_lines
    allSubmissions = load_file("inputs.txt")
    allResults = load_file("outputs.txt")

    #Extract the functionNo inputs and outputs only and return those arrays only
    functionSubmissions = np.array([line[functionIndex] for line in allSubmissions])
    functionResults = np.array([line[functionIndex] for line in allResults])

    return functionSubmissions, functionResults

# %%
def combineInitialDataAndSubmissionsToDate(functionNo):
    assert(functionNo >= 1)
    assert(functionNo <= 8)

    initialInputs = np.load(f'initial_data/function_{functionNo}/initial_inputs.npy')
    initialOutputs = np.load(f'initial_data/function_{functionNo}/initial_outputs.npy')

    submissions, results = collatePreviousSubmissions(functionNo)

    combined_Inputs = np.vstack((initialInputs, submissions))
    combined_Outputs = np.concatenate((initialOutputs, results))

    assert combined_Inputs.shape[1] == initialInputs.shape[1]
    assert combined_Outputs.shape[0] == combined_Inputs.shape[0]

    return combined_Inputs, combined_Outputs

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.029245 0.037348] , Max:  [0.88388983 0.8798981 ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  2.6752879910742468e-09
#
# [[ 5.000000e-001  5.000000e-001  2.675288e-009]
#  [ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 14 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 1e-08, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00125441, 'mean': 0.0005169, 'std': 0.00025868, 'q1': 0.00035928, 'median': 0.00051034, 'q3': 0.00066482}
# 	Local search 1/64, x=[0.99356854 0.99358244], val=0.0012545025485391438, best=0.0012545025
# 	Local search 2/64, x=[0.99363742 0.99419378], val=0.0012545114658654526, best=0.0012545115
# 	Local search 3/64, x=[0.99357725 0.99434652], val=0.0012545126058434069, best=0.0012545126
# 	Local search 4/64, x=[0.99347639 0.99449701], val=0.0012545132823036484, best=0.0012545133
# 	Local search 6/64, x=[0.9934199  0.99436092], val=0.0012545133208593153, best=0.0012545133
# 	Local search 11/64, x=[0.99320675 0.99445994], val=0.001254513386819687, best=0.0012545134
# 	Local search 34/64, x=[0.99322221 0.99449194], val=0.0012545134601975943, best=0.0012545135
# 	Local search 45/64, x=[0.99338128 0.99454772], val=0.0012545134985051114, best=0.0012545135
#
# 	Proposed next point to try: 0.993381-0.994548
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.00504014 0.99874309], val=5e-322, best=0.0000000000
#
# 	Proposed next point to try: 0.005040-0.998743
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0034754, 'max': 0.00091789, 'mean': 4.58e-05, 'std': 0.0005358, 'q1': 2.916e-05, 'median': 0.00013825, 'q3': 0.00028511}
# 	Local search 1/64, x=[0.98037966 0.9927029 ], val=0.0009178909116293471, best=0.0009178909
# 	Local search 3/64, x=[0.98133422 0.99241683], val=0.0009179077685860905, best=0.0009179078
# 	Local search 4/64, x=[0.98152899 0.99165906], val=0.0009179125150915597, best=0.0009179125
# 	Local search 12/64, x=[0.9819339  0.99178724], val=0.0009179128734043147, best=0.0009179129
# 	Local search 15/64, x=[0.98174902 0.99175792], val=0.0009179131377071799, best=0.0009179131
#
# 	Proposed next point to try: 0.981749-0.991758
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0021811, 'max': 0.01216905, 'mean': 0.00639308, 'std': 0.0020292, 'q1': 0.00508961, 'median': 0.00634444, 'q3': 0.00744087}
# 	Local search 1/64, x=[0.0092146  0.99180947], val=0.01216980551033428, best=0.0121698055
# 	Local search 4/64, x=[0.00924275 0.99174521], val=0.01216980588064006, best=0.0121698059
# 	Local search 5/64, x=[0.00922874 0.99174857], val=0.012169805989782432, best=0.0121698060
# 	Local search 9/64, x=[0.00919363 0.99173411], val=0.012169806059827018, best=0.0121698061
#
# 	Proposed next point to try: 0.009194-0.991734
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00089603, 'max': 0.02396217, 'mean': 0.01286991, 'std': 0.00375404, 'q1': 0.01041448, 'median': 0.01272315, 'q3': 0.0147337}
# 	Local search 1/64, x=[0.008326   0.99087793], val=0.02396387938475981, best=0.0239638794
# 	Local search 33/64, x=[0.00831692 0.99087209], val=0.02396387939512022, best=0.0239638794
#
# 	Proposed next point to try: 0.008317-0.990872
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.00167412, 'max': 0.04754842, 'mean': 0.02582355, 'std': 0.00724058, 'q1': 0.02113972, 'median': 0.02552139, 'q3': 0.02931798}
# 	Local search 1/64, x=[0.00790175 0.99045438], val=0.04755250373482668, best=0.0475525037
# 	Local search 2/64, x=[0.00785846 0.99041244], val=0.047552504208096945, best=0.0475525042
# 	Local search 9/64, x=[0.00787423 0.99044502], val=0.04755250423751001, best=0.0475525042
# 	Local search 19/64, x=[0.00786324 0.99042899], val=0.04755250433126365, best=0.0475525043
# 	Local search 42/64, x=[0.0078768  0.99042838], val=0.047552504369560954, best=0.0475525044
# 	Local search 44/64, x=[0.00787019 0.99042626], val=0.04755250437578141, best=0.0475525044
#
# 	Proposed next point to try: 0.007870-0.990426

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.14269907 0.02869772] , Max:  [0.87779099 0.970764  ]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
#
# [[ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.600000  0.500000  0.144121]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 14 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.0001, 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.54843186, 'mean': 0.09041242, 'std': 0.09807472, 'q1': 0.00055483, 'median': 0.05636204, 'q3': 0.17494729}
# 	Local search 1/64, x=[0.54398232 1.        ], val=0.5491301463855988, best=0.5491301464
# 	Local search 2/64, x=[0.54398198 1.        ], val=0.5491301463856261, best=0.5491301464
# 	Local search 3/64, x=[0.54398213 1.        ], val=0.5491301463861075, best=0.5491301464
# 	Local search 4/64, x=[0.54398214 1.        ], val=0.5491301463861116, best=0.5491301464
# 	Local search 5/64, x=[0.54398214 1.        ], val=0.5491301463861127, best=0.5491301464
# 	Local search 8/64, x=[0.54398214 1.        ], val=0.549130146386113, best=0.5491301464
# 	Local search 21/64, x=[0.54398214 1.        ], val=0.5491301463861133, best=0.5491301464
# 	Local search 55/64, x=[0.54398214 1.        ], val=0.5491301463861136, best=0.5491301464
# 	Local search 56/64, x=[0.54398214 1.        ], val=0.5491301463861139, best=0.5491301464
#
# 	Proposed next point to try: 0.543982-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.12654689, 'max': 0.140187, 'mean': 0.13878586, 'std': 0.00198284, 'q1': 0.13816892, 'median': 0.13976674, 'q3': 0.14013214}
# 	Local search 1/64, x=[0.49788751 0.49629947], val=0.1401869987068379, best=0.1401869987
#
# 	Proposed next point to try: 0.497888-0.496299
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.21814015, 'mean': 0.02611409, 'std': 0.03669578, 'q1': 0.0, 'median': 0.00326323, 'q3': 0.05001392}
# 	Local search 1/64, x=[0.50611274 1.        ], val=0.2185775380622352, best=0.2185775381
# 	Local search 4/64, x=[0.50611246 1.        ], val=0.218577538062727, best=0.2185775381
# 	Local search 6/64, x=[0.50611248 1.        ], val=0.2185775380627299, best=0.2185775381
# 	Local search 7/64, x=[0.50611249 1.        ], val=0.21857753806273053, best=0.2185775381
# 	Local search 41/64, x=[0.50611249 1.        ], val=0.21857753806273056, best=0.2185775381
# 	Local search 52/64, x=[0.50611248 1.        ], val=0.21857753806273103, best=0.2185775381
#
# 	Proposed next point to try: 0.506112-1.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.49788751 0.49629947], val=5.257528935873137e-96, best=0.0000000000
#
# 	Proposed next point to try: 0.497888-0.496299
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.09026962, 'max': 0.09999952, 'mean': 0.09900005, 'std': 0.00141442, 'q1': 0.09855996, 'median': 0.09969974, 'q3': 0.09996039}
# 	Local search 1/64, x=[0.49788751 0.49629947], val=0.0999995187668257, best=0.0999995188
#
# 	Proposed next point to try: 0.497888-0.496299
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0151602, 'max': 5.01041726, 'mean': 2.44657964, 'std': 1.50836388, 'q1': 1.07305346, 'median': 2.25650288, 'q3': 3.83328467}
# 	Local search 1/64, x=[0.12008892 0.88568234], val=5.0104372031379265, best=5.0104372031
# 	Local search 4/64, x=[0.12008905 0.88568253], val=5.010437203137987, best=5.0104372031
# 	Local search 5/64, x=[0.12008909 0.88568252], val=5.010437203138001, best=5.0104372031
# 	Local search 10/64, x=[0.12008904 0.88568247], val=5.010437203138019, best=5.0104372031
# 	Local search 12/64, x=[0.12008903 0.88568245], val=5.01043720313802, best=5.0104372031
# 	Local search 21/64, x=[0.12008903 0.88568244], val=5.010437203138021, best=5.0104372031
# 	Local search 31/64, x=[0.12008904 0.88568246], val=5.0104372031380215, best=5.0104372031
#
# 	Proposed next point to try: 0.120089-0.885682
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.45185936, 'max': 10.00247568, 'mean': 9.85050249, 'std': 0.44305474, 'q1': 9.83421023, 'median': 9.96462879, 'q3': 9.99550012}
# 	Local search 1/64, x=[0.44433274 0.6471842 ], val=10.002490763929165, best=10.0024907639
# 	Local search 2/64, x=[0.44424293 0.64717076], val=10.002490765164344, best=10.0024907652
# 	Local search 45/64, x=[0.44423318 0.64716952], val=10.002490765172556, best=10.0024907652
#
# 	Proposed next point to try: 0.444233-0.647170
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.13665252, 'max': 19.58051183, 'mean': 9.08271368, 'std': 5.89330227, 'q1': 3.81231911, 'median': 8.13283158, 'q3': 14.40168738}
# 	Local search 1/64, x=[0.09250142 0.89704204], val=19.581064671915083, best=19.5810646719
# 	Local search 2/64, x=[0.09250137 0.89704255], val=19.581064671925244, best=19.5810646719
# 	Local search 5/64, x=[0.09250118 0.8970424 ], val=19.581064671925752, best=19.5810646719
# 	Local search 8/64, x=[0.09250124 0.89704242], val=19.581064671925926, best=19.5810646719
# 	Local search 27/64, x=[0.09250124 0.89704242], val=19.58106467192593, best=19.5810646719
#
# 	Proposed next point to try: 0.092501-0.897042

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.151837  0.439991  0.990882 -0.398926]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.431029  0.814368  0.806413 -0.098068]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.600097  0.725136  0.066089 -0.036378]]
#
# Starting 3D Bayes Optimisation from 19 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 3.25e-06, 'max': 0.00020411, 'mean': 2.978e-05, 'std': 2.585e-05, 'q1': 1.039e-05, 'median': 2.173e-05, 'q3': 4.133e-05}
# 	Local search 1/96, x=[1. 1. 0.], val=0.00021608380029085808, best=0.0002160838
#
# 	Proposed next point to try: 1.000000-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[9.89468763e-01 1.06479041e-04 2.75666872e-02], val=4.57998226780452e-09, best=0.0000000046
#
# 	Proposed next point to try: 9.894688e-01-1.064790e-04-2.756669e-02
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[9.89468763e-01 1.06479041e-04 2.75666872e-02], val=5.222135168777316e-56, best=0.0000000000
#
# 	Proposed next point to try: 9.894688e-01-1.064790e-04-2.756669e-02
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.11623995, 'max': -0.08454593, 'mean': -0.10029206, 'std': 0.00571916, 'q1': -0.10414282, 'median': -0.09952738, 'q3': -0.09595809}
# 	Local search 1/96, x=[1. 1. 0.], val=-0.08244783101914836, best=-0.0824478310
#
# 	Proposed next point to try: 1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.03070162, 'max': 0.08284217, 'mean': 0.05079462, 'std': 0.01104626, 'q1': 0.04182265, 'median': 0.05014599, 'q3': 0.0589658}
# 	Local search 1/96, x=[0.99321864 0.98036101 0.01611069], val=0.08293475493995559, best=0.0829347549
# 	Local search 9/96, x=[0.99321678 0.98036326 0.01611107], val=0.08293475494138972, best=0.0829347549
# 	Local search 19/96, x=[0.99321715 0.98036185 0.01611181], val=0.08293475494214866, best=0.0829347549
#
# 	Proposed next point to try: 0.993217-0.980362-0.016112
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -32.11543114, 'max': -0.08725133, 'mean': -16.19004735, 'std': 3.91840166, 'q1': -18.76245229, 'median': -16.15643446, 'q3': -13.60956056}
# 	Local search 1/128, x=[0.43316097 0.40834326 0.38033778 0.38687026], val=0.8163223465939607, best=0.8163223466
# 	Local search 2/128, x=[0.43316093 0.40834312 0.38033785 0.38687026], val=0.8163223466053403, best=0.8163223466
# 	Local search 5/128, x=[0.43316092 0.40834314 0.38033786 0.38687026], val=0.8163223466055589, best=0.8163223466
# 	Local search 48/128, x=[0.43316093 0.40834314 0.38033786 0.38687026], val=0.8163223466055721, best=0.8163223466
# 	Local search 93/128, x=[0.43316093 0.40834314 0.38033786 0.38687027], val=0.8163223466055738, best=0.8163223466
#
# 	Proposed next point to try: 0.433161-0.408343-0.380338-0.386870
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -30.63491129, 'max': 1.21931976, 'mean': -12.75565858, 'std': 3.89189416, 'q1': -15.23222727, 'median': -12.65754924, 'q3': -10.18786586}
# 	Local search 1/128, x=[0.44954326 0.41441237 0.39057133 0.36882403], val=1.7357697034830633, best=1.7357697035
# 	Local search 4/128, x=[0.44954322 0.41441239 0.39057137 0.36882404], val=1.735769703483503, best=1.7357697035
#
# 	Proposed next point to try: 0.449543-0.414412-0.390571-0.368824
#
# Using UCB Acquisition function with Kappa = 10
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -29.4494082, 'max': 2.93275965, 'mean': -9.25118024, 'std': 3.89020428, 'q1': -11.65034745, 'median': -9.08391785, 'q3': -6.65892754}
# 	Local search 1/128, x=[0.46281967 0.42791599 0.41064183 0.35955489], val=3.2339830818320356, best=3.2339830818
# 	Local search 9/128, x=[0.4628197  0.427916   0.4106418  0.35955489], val=3.2339830818321436, best=3.2339830818
#
# 	Proposed next point to try: 0.462820-0.427916-0.410642-0.359555
#
# Using UCB Acquisition function with Kappa = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -27.29686878, 'max': 7.40453482, 'mean': -2.24222356, 'std': 3.96329507, 'q1': -4.55945442, 'median': -1.92352642, 'q3': 0.46237402}
# 	Local search 1/128, x=[0.43000892 0.45413695 0.46229736 0.35157431], val=7.539529888008951, best=7.5395298880
# 	Local search 2/128, x=[0.43001422 0.45413557 0.46229689 0.35157471], val=7.539529889709004, best=7.5395298897
# 	Local search 99/128, x=[0.43001422 0.45413557 0.46229689 0.35157471], val=7.539529889709019, best=7.5395298897
#
# 	Proposed next point to try: 0.430014-0.454136-0.462297-0.351575

# %%
f5_Inputs, f5_Outputs = combineInitialDataAndSubmissionsToDate(5)
findNextGuess('F5', f5_Inputs, f5_Outputs)
# Out:
# ********************
# F5  -  4 D
# ********************
#  Inputs -   Min: [0.013737   0.03819337 0.08894684 0.07288048] , Max:  [0.924901   0.86254031 1.         0.9576439 ]
#  Output -   Min: 0.1129397953712203 , Max (Best):  2263.948440073915
#
# [[3.251100e-01 8.389740e-01 1.000000e+00 9.341090e-01 2.263948e+03]
#  [2.983980e-01 8.408080e-01 9.794320e-01 9.188810e-01 1.959096e+03]
#  [2.241890e-01 8.464805e-01 8.794842e-01 8.785157e-01 1.088860e+03]
#  [6.834322e-01 1.186626e-01 8.290459e-01 5.675766e-01 7.843439e+01]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.18032462, 'max': 1897.3109045, 'mean': 114.77337721, 'std': 135.57417252, 'q1': 40.74115566, 'median': 70.04349839, 'q3': 132.34817424}
# 	Local search 1/128, x=[0.32511  0.838974 1.       0.934109], val=2169.4862964913873, best=2169.4862964914
# 	Local search 41/128, x=[0.32511  0.838974 1.       0.934109], val=2169.4862967894524, best=2169.4862967895
# 	Local search 42/128, x=[0.32511  0.838974 1.       0.934109], val=2169.486305096587, best=2169.4863050966
# 	Local search 75/128, x=[0.32511  0.838974 1.       0.934109], val=2169.4863220522748, best=2169.4863220523
# 	Local search 76/128, x=[0.32511  0.838974 1.       0.934109], val=2169.4863226982134, best=2169.4863226982
# 	Local search 104/128, x=[0.32511  0.838974 1.       0.934109], val=2169.4863299429867, best=2169.4863299430
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.23269737, 'max': 1899.58522802, 'mean': 119.29736332, 'std': 135.56748277, 'q1': 45.22445441, 'median': 74.50515222, 'q3': 136.9556398}
# 	Local search 1/128, x=[0.32511  0.838974 1.       0.934109], val=2169.9610372201805, best=2169.9610372202
# 	Local search 3/128, x=[0.32511  0.838974 1.       0.934109], val=2169.961045280026, best=2169.9610452800
# 	Local search 28/128, x=[0.32511  0.838974 1.       0.934109], val=2169.961060347278, best=2169.9610603473
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109
#
# Using UCB Acquisition function with Kappa = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 9.73308517, 'max': 1904.13387614, 'mean': 128.34533635, 'std': 135.55577666, 'q1': 54.18179172, 'median': 83.4524917, 'q3': 146.15880902}
# 	Local search 1/128, x=[0.32511    0.838974   1.         0.93410899], val=2170.9105088272254, best=2170.9105088272
# 	Local search 2/128, x=[0.32511  0.838974 1.       0.934109], val=2170.9105287474913, best=2170.9105287475
# 	Local search 5/128, x=[0.32511  0.838974 1.       0.934109], val=2170.9105327919583, best=2170.9105327920
# 	Local search 8/128, x=[0.32511  0.838974 1.       0.934109], val=2170.9105368153737, best=2170.9105368154
# 	Local search 28/128, x=[0.32511  0.838974 1.       0.934109], val=2170.9105525482864, best=2170.9105525483
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109

# %%
f6_Inputs, f6_Outputs = combineInitialDataAndSubmissionsToDate(6)
findNextGuess('F6', f6_Inputs, f6_Outputs)
# Out:
# ********************
# F6  -  5 D
# ********************
#  Inputs -   Min: [0.021081  0.076503  0.0165229 0.042143  0.003667 ] , Max:  [0.95773967 0.93187122 0.989507   0.96165559 0.89281919]
#  Output -   Min: -2.5711696316081234 , Max (Best):  -0.2776577094327388
#
# [[ 0.585939  0.538496  0.989507  0.863517  0.003667 -0.897936]
#  [ 0.945069  0.288459  0.978806  0.961656  0.598016 -1.694343]
#  [ 0.145111  0.896685  0.896322  0.726272  0.236272 -1.233786]
#  [ 0.021735  0.428084  0.835939  0.489489  0.511082 -1.356682]
#  [ 0.629308  0.803484  0.811408  0.045613  0.110624 -1.622839]
#  [ 0.728186  0.154693  0.732552  0.693997  0.056401 -0.714265]
000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	81919 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00095816, 'mean': 1.32e-06, 'std': 1.72e-05, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.12590809 0.01911933 0.5747747  1.         0.        ], val=0.001190134039675958, best=0.0011901340
# 	Local search 2/160, x=[0.12583138 0.01864129 0.57503604 1.         0.        ], val=0.0011901364581223656, best=0.0011901365
# 	Local search 5/160, x=[0.12573544 0.01856192 0.57503974 1.         0.        ], val=0.0011901365711684613, best=0.0011901366
# 	Local search 8/160, x=[0.12572815 0.01856249 0.57506464 1.         0.        ], val=0.0011901365788106052, best=0.0011901366
# 	Local search 12/160, x=[0.12572478 0.01857611 0.57505835 1.         0.        ], val=0.00119013658055993, best=0.0011901366
# 	Local search 144/160, x=[0.12572236 0.01858064 0.57506127 1.         0.        ], val=0.001190136580561065, best=0.0011901366
#
# 	Proposed next point to try: 0.125722-0.018581-0.575061-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81919 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.37866232 0.92978967 0.61042971 0.88879672 0.69478997], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.378662-0.929790-0.610430-0.888797-0.694790
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81919 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.55829869, 'max': -0.32159807, 'mean': -1.44633221, 'std': 0.39788678, 'q1': -1.72383474, 'median': -1.47413989, 'q3': -1.18055037}
# 	Local search 1/160, x=[0.36380024 0.31117819 0.49624902 0.84641152 0.07048462], val=-0.29777318234291095, best=-0.2977731823
# 	Local search 3/160, x=[0.36380173 0.31117806 0.49625096 0.84640927 0.07048511], val=-0.29777318232747085, best=-0.2977731823
# 	Local search 4/160, x=[0.36380149 0.31117772 0.4962512  0.84640979 0.07048492], val=-0.29777318232654715, best=-0.2977731823
# 	Local search 5/160, x=[0.3638016  0.31117765 0.49625096 0.84640998 0.07048489], val=-0.29777318232641586, best=-0.2977731823
# 	Local search 22/160, x=[0.36380159 0.31117787 0.49625088 0.84640992 0.07048498], val=-0.29777318232639055, best=-0.2977731823
# 	Local search 57/160, x=[0.36380157 0.31117786 0.49625098 0.84640986 0.07048495], val=-0.2977731823263805, best=-0.2977731823
#
# 	Proposed next point to try: 0.363802-0.311178-0.496251-0.846410-0.070485
#
# Using UCB Acquisition function with Kappa = 5
# 	81919 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.92521248, 'max': 1.15199223, 'mean': -0.34958688, 'std': 0.43525682, 'q1': -0.6465899, 'median': -0.34102682, 'q3': -0.05466238}
# 	Local search 1/160, x=[0.00959243 0.         0.74509676 1.         0.        ], val=1.1774273722301445, best=1.1774273722
# 	Local search 16/160, x=[0.00959238 0.         0.74509722 1.         0.        ], val=1.177427372230244, best=1.1774273722
# 	Local search 33/160, x=[0.00959234 0.         0.74509711 1.         0.        ], val=1.1774273722302508, best=1.1774273722
# 	Local search 59/160, x=[0.00959236 0.         0.74509732 1.         0.        ], val=1.1774273722302562, best=1.1774273722
# 	Local search 70/160, x=[0.00959235 0.         0.74509743 1.         0.        ], val=1.1774273722302573, best=1.1774273722
#
# 	Proposed next point to try: 0.009592-0.000000-0.745097-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 
Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00986386, 'mean': 2.56e-06, 'std': 4.934e-05, 'q1': 3e-08, 'median': 1.7e-07, 'q3': 8.7e-07}
# 	Local search 1/192, x=[0.00672168 0.46357465 0.30207203 0.16507957 0.35392019 0.73169211], val=0.016469812670945928, best=0.0164698127
# 	Local search 2/192, x=[0.00672299 0.46357276 0.30207527 0.16507988 0.3539171  0.73169393], val=0.016469812692407344, best=0.0164698127
# 	Local search 3/192, x=[0.00672318 0.46357262 0.30207523 0.16508052 0.35391878 0.73169254], val=0.016469812700175883, best=0.0164698127
# 	Local search 111/192, x=[0.0067234  0.46357288 0.30207536 0.16508052 0.35391827 0.7316926 ], val=0.016469812700211472, best=0.0164698127
# 	Local search 137/192, x=[0.0067231  0.46357288 0.30207507 0.16508033 0.35391859 0.73169303], val=0.01646981270041961, best=0.0164698127
#
# 	Proposed next point to try: 0.006723-0.463573-0.302075-0.165080-0.353919-0.731693
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00183573, 'mean': 6.6e-07, 'std': 1.068e-05, 'q1': 0.0, 'median': 3e-08, 'q3': 2e-07}
# 	Local search 1/192, x=[0.         0.48259672 0.32315508 0.14807511 0.34671681 0.73232752], val=0.002822015724783617, best=0.0028220157
# 	Local search 2/192, x=[0.         0.48262504 0.32313194 0.14807209 0.34670433 0.73271271], val=0.0028220250993800573, best=0.0028220251
# 	Local search 9/192, x=[0.         0.48263093 0.32311892 0.14806604 0.3466957  0.73269347], val=0.002822025145874838, best=0.0028220251
#
# 	Proposed next point to try: 0.000000-0.482631-0.323119-0.148066-0.346696-0.732693
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 8.5e-07, 'mean': 0.0, 'std': 1e-08, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.0595129  0.50583572 0.35074071 0.00732919 0.41849532 0.72044843], val=8.471896714253676e-07, best=0.0000008472
#
# 	Proposed next point to try: 0.059513-0.505836-0.350741-0.007329-0.418495-0.720448
#
# Using Expected Improvement Acquisition function with xi = 20
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.13139505 0.13818232 0.21739867 0.51171881 0.49611845 0.17559407], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.131395-0.138182-0.217399-0.511719-0.496118-0.175594
#
# Using UCB Acquisition function with Kappa = 0.1
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.00769238, 'max': 1.50781023, 'mean': 0.25633058, 'std': 0.1311183, 'q1': 0.16029485, 'median': 0.23391806, 'q3': 0.32573209}
# 	Local search 1/192, x=[0.03303325 0.4447201  0.2846464  0.17040911 0.36196351 0.73196751], val=1.6223799565243084, best=1.6223799565
# 	Local search 13/192, x=[0.03303326 0.44472011 0.28464638 0.1704092  0.36196354 0.73196752], val=1.6223799565243477, best=1.6223799565
# 	Local search 65/192, x=[0.03303323 0.44472009 0.28464638 0.17040915 0.36196351 0.73196754], val=1.6223799565243793, best=1.6223799565
# 	Local search 174/192, x=[0.03303325 0.4447201  0.28464636 0.17040914 0.36196352 0.73196757], val=1.6223799565243846, best=1.6223799565
#
# 	Proposed next point to try: 0.033033-0.444720-0.284646-0.170409-0.361964-0.731968
#
# Using UCB Acquisition function with Kappa = 5
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.70434151, 'max': 2.3256014, 'mean': 1.7600014, 'std': 0.16005053, 'q1': 1.65017302, 'median': 1.76079719, 'q3': 1.86998326}
# 	Local search 1/192, x=[0.03755809 0.518382   0.41195643 0.06766022 0.321529   0.75363216], val=2.361755949098831, best=2.3617559491
# 	Local search 21/192, x=[0.0375582  0.51838188 0.41195608 0.0676598  0.32152867 0.75363262], val=2.361755949099409, best=2.3617559491
# 	Local search 106/192, x=[0.03755808 0.51838234 0.41195587 0.06765962 0.32152899 0.75363251], val=2.3617559490995976, best=2.3617559491
# 	Local search 155/192, x=[0.03755816 0.51838198 0.41195602 0.06765992 0.32152899 0.7536326 ], val=2.361755949099599, best=2.3617559491
#
# 	Proposed next point to try: 0.037558-0.518382-0.411956-0.067660-0.321529-0.753633
#
# Using UCB Acquisition function with Kappa = 10
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 1.40014467, 'max': 3.97497927, 'mean': 3.29436721, 'std': 0.23729884, 'q1': 3.14197954, 'median': 3.31101787, 'q3': 3.46285589}
# 	Local search 1/192, x=[0.04797957 0.94877354 0.94842372 0.04429932 0.04786891 0.9467664 ], val=4.035426474220807, best=4.0354264742
# 	Local search 2/192, x=[0.04797754 0.94877414 0.94842431 0.04430241 0.04786797 0.94676158], val=4.035426474346178, best=4.0354264743
# 	Local search 3/192, x=[0.04798127 0.94877302 0.94842506 0.0443017  0.04786879 0.94676011], val=4.03542647441976, best=4.0354264744
# 	Local search 4/192, x=[0.04798152 0.94877363 0.94842396 0.04430223 0.04786792 0.94676221], val=4.0354264744399595, best=4.0354264744
# 	Local search 15/192, x=[0.0479811  0.94877328 0.94842448 0.04430232 0.04786878 0.94676219], val=4.035426474447076, best=4.0354264744
# 	Local search 34/192, x=[0.04798108 0.9487737  0.94842423 0.04430249 0.04786874 0.94676156], val=4.035426474447832, best=4.0354264744
# 	Local search 54/192, x=[0.04798111 0.94877369 0.94842441 0.04430241 0.04786881 0.94676189], val=4.0354264744487605, best=4.0354264744
#
# 	Proposed next point to try: 0.047981-0.948774-0.948424-0.044302-0.047869-0.946762
#
# Using UCB Acquisition function with Kappa = 20
# 	98303 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 2.77625598, 'max': 7.61891031, 'mean': 6.36309147, 'std': 0.42972872, 'q1': 6.0969689, 'median': 6.38868454, 'q3': 6.66261173}
# 	Local search 1/192, x=[0.04578935 0.96120985 0.9523108  0.04628356 0.0503332  0.05052849], val=7.726434043653962, best=7.7264340437
#
# 	Proposed next point to try: 0.045789-0.961210-0.952311-0.046284-0.050333-0.050528

# %%
f8_Inputs, f8_Outputs = combineInitialDataAndSubmissionsToDate(8)
findNextGuess('F8', f8_Inputs, f8_Outputs)
# Out:
# ********************
# F8  -  8 D
# ********************
#  Inputs -   Min: [0.00907698 0.002882   0.02292868 0.         0.00964888 0.02211341
#  0.03590888 0.02729   ] , Max:  [0.98594539 0.97397979 0.9988855  0.958365   0.989136   0.993478
#  0.99291449 0.9887551 ]
#  Output -   Min: 5.5921933895401965 , Max (Best):  9.838102201175
#
# [[9.849332e-01 6.995063e-01 9.988855e-01 1.801485e-01 5.801431e-01
#   2.310872e-01 4.908269e-01 3.136827e-01 5.592193e+00]
#  [1.780070e-01 5.662227e-01 9.948618e-01 2.103250e-01 3.201527e-01
#   7.079088e-01 6.353845e-01 1.071316e-01 7.005227e+00]
known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 10}
# Using Expected Improvement Acquisition function with xi = 0
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.51261361, 'mean': 0.00175316, 'std': 0.01744512, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.06632426 0.2685502  0.00888676 0.31027467 0.56817499 0.5248267
#  0.14144755 0.43955637], val=0.5896861367822916, best=0.5896861368
# 	Local search 2/256, x=[0.07168125 0.27103213 0.00790136 0.30943329 0.57155871 0.52820706
#  0.13957946 0.4435657 ], val=0.5898837219951081, best=0.5898837220
# 	Local search 3/256, x=[0.07441087 0.27399949 0.00681601 0.31489501 0.57035701 0.52527251
#  0.14538798 0.44285226], val=0.5899778435919318, best=0.5899778436
# 	Local search 35/256, x=[0.07091847 0.27577659 0.00711944 0.31205837 0.57082221 0.52977295
#  0.14348799 0.44276708], val=0.5899938832161621, best=0.5899938832
# 	Local search 39/256, x=[0.07467722 0.27770811 0.00710054 0.31374626 0.5682952  0.53133526
#  0.14291912 0.44191081], val=0.5900050595998638, best=0.5900050596
# 	Local search 97/256, x=[0.07456413 0.27546089 0.00691309 0.31298839 0.57124389 0.52809648
#  0.14197056 0.44087014], val=0.5900086348940659, best=0.5900086349
# 	Local search 152/256, x=[0.07497186 0.27646291 0.00635907 0.31379925 0.56925876 0.53042638
#  0.14580527 0.44131609], val=0.5900135449446964, best=0.5900135449
#
# 	Proposed next point to try: 0.074972-0.276463-0.006359-0.313799-0.569259-0.530426-0.145805-0.441316
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.41319977, 'mean': 0.00084348, 'std': 0.01064799, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.07182765 0.26874009 0.00288154 0.30960035 0.56165719 0.52108446
#  0.14219487 0.44426794], val=0.4906062198252931, best=0.4906062198
# 	Local search 2/256, x=[0.07158325 0.27317808 0.00428704 0.31478246 0.57171096 0.53036307
#  0.14148472 0.43946637], val=0.49095893651796696, best=0.4909589365
# 	Local search 14/256, x=[0.07581857 0.27658427 0.0051426  0.31470525 0.57114346 0.53134106
#  0.14218069 0.44106855], val=0.4909788064865268, best=0.4909788065
# 	Local search 31/256, x=[0.07493193 0.27678717 0.00427585 0.31411231 0.56891788 0.53133222
#  0.14317167 0.4439069 ], val=0.4909834551269256, best=0.4909834551
# 	Local search 42/256, x=[0.07392533 0.27574606 0.00510927 0.31427515 0.57092625 0.5283732
#  0.14568323 0.4410604 ], val=0.4909899392286408, best=0.4909899392
# 	Local search 141/256, x=[0.07433249 0.27454923 0.00407379 0.31347333 0.56975464 0.53150435
#  0.14385781 0.44029283], val=0.49099486289493804, best=0.4909948629
#
# 	Proposed next point to try: 0.074332-0.274549-0.004074-0.313473-0.569755-0.531504-0.143858-0.440293
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0461323, 'mean': 7.5e-06, 'std': 0.00033879, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.06571229 0.28072191 0.         0.30840662 0.56623937 0.52513286
#  0.13556333 0.43068922], val=0.10659981692991724, best=0.1065998169
# 	Local search 3/256, x=[0.07214303 0.27702838 0.         0.31784781 0.56685547 0.5304874
#  0.13245835 0.43608393], val=0.1067468944810008, best=0.1067468945
# 	Local search 5/256, x=[0.06646408 0.27966328 0.         0.31570561 0.56233375 0.53290613
#  0.1363368  0.4311902 ], val=0.1067928094785832, best=0.1067928095
# 	Local search 24/256, x=[0.06727276 0.28198579 0.         0.31670246 0.562768   0.53601455
#  0.13500915 0.43535015], val=0.10680661857439425, best=0.1068066186
# 	Local search 43/256, x=[0.06846958 0.28063026 0.         0.31692025 0.56342194 0.53504567
#  0.13350769 0.43479929], val=0.10681600141636662, best=0.1068160014
#
# 	Proposed next point to try: 0.068470-0.280630-0.000000-0.316920-0.563422-0.535046-0.133508-0.434799
#
# Using Expected Improvement Acquisition function with xi = 20
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.21226386 0.47224533 0.67858808 0.42222545 0.79719655 0.63994755
#  0.41609054 0.77683022], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.212264-0.472245-0.678588-0.422225-0.797197-0.639948-0.416091-0.776830
#
# Using UCB Acquisition function with Kappa = 0.1
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.38900661, 'max': 10.33648388, 'mean': 7.91550998, 'std': 0.98328048, 'q1': 7.23080093, 'median': 7.9667024, 'q3': 8.65186649}
# 	Local search 1/256, x=[0.08799981 0.2694624  0.04930243 0.32010861 0.57826615 0.5309948
#  0.14351293 0.44623145], val=10.414396523693568, best=10.4143965237
# 	Local search 2/256, x=[0.08891172 0.27365788 0.05190672 0.31621737 0.56913306 0.53529776
#  0.14256123 0.44676355], val=10.414659520283884, best=10.4146595203
# 	Local search 8/256, x=[0.08756009 0.27041352 0.0519409  0.31390106 0.57166987 0.53799858
#  0.13666349 0.44438359], val=10.414692969280495, best=10.4146929693
# 	Local search 11/256, x=[0.08756677 0.2691595  0.05162024 0.31391796 0.56714122 0.53088554
#  0.13876214 0.44386245], val=10.414695482200795, best=10.4146954822
# 	Local search 22/256, x=[0.09042706 0.2720489  0.05161537 0.31279072 0.57052559 0.53144118
#  0.14132087 0.44396283], val=10.41469902386573, best=10.4146990239
# 	Local search 66/256, x=[0.08753514 0.27286648 0.05123724 0.31064242 0.57037519 0.53280743
#  0.1416057  0.4436743 ], val=10.414723291897829, best=10.4147232919
# 	Local search 180/256, x=[0.08837301 0.27140146 0.05161878 0.3112224  0.56884434 0.53343259
#  0.14025644 0.44508312], val=10.414727920045497, best=10.4147279200
#
# 	Proposed next point to try: 0.088373-0.271401-0.051619-0.311222-0.568844-0.533433-0.140256-0.445083
#
# Using UCB Acquisition function with Kappa = 5
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.28545672, 'max': 10.89437072, 'mean': 8.53177885, 'std': 0.96452399, 'q1': 7.84646446, 'median': 8.56949156, 'q3': 9.25927614}
# 	Local search 1/256, x=[0.06398782 0.27982039 0.03977893 0.27961036 0.44520673 0.61798718
#  0.05245665 0.25785096], val=10.993971259562127, best=10.9939712596
# 	Local search 7/256, x=[0.06517447 0.27489691 0.0404808  0.27498904 0.43842984 0.61540503
#  0.05267721 0.25322448], val=10.994015322466446, best=10.9940153225
# 	Local search 74/256, x=[0.06522151 0.27054278 0.03875257 0.27264169 0.43775811 0.62033182
#  0.05221624 0.25273619], val=10.994031125928794, best=10.9940311259
# 	Local search 170/256, x=[0.06474024 0.27090709 0.03934203 0.271271   0.43926084 0.61635337
#  0.05256436 0.25226296], val=10.99404742154095, best=10.9940474215
#
# 	Proposed next point to try: 0.064740-0.270907-0.039342-0.271271-0.439261-0.616353-0.052564-0.252263
#
# Using UCB Acquisition function with Kappa = 10
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.07652177, 'max': 11.7381173, 'mean': 9.16062754, 'std': 0.97614396, 'q1': 8.45546737, 'median': 9.1803776, 'q3': 9.89140555}
# 	Local search 1/256, x=[0.05679286 0.07205572 0.03851973 0.06041928 0.31794624 0.90597231
#  0.03347917 0.05039233], val=11.98153154901064, best=11.9815315490
# 	Local search 12/256, x=[0.05877117 0.07146516 0.03891251 0.06175303 0.3051669  0.90521947
#  0.03324706 0.04964748], val=11.981545711000924, best=11.9815457110
# 	Local search 14/256, x=[0.05858345 0.06959056 0.03884134 0.06131167 0.30936795 0.90361939
#  0.03319271 0.05079539], val=11.98154783031757, best=11.9815478303
# 	Local search 25/256, x=[0.05780625 0.07130714 0.03863105 0.06188309 0.31395631 0.90483334
#  0.03301048 0.0500881 ], val=11.981575410996644, best=11.9815754110
# 	Local search 34/256, x=[0.05679368 0.07235118 0.03933123 0.06118318 0.31186295 0.90480981
#  0.03332536 0.05023006], val=11.981584305761123, best=11.9815843058
# 	Local search 104/256, x=[0.05741269 0.07080133 0.03918346 0.06113845 0.31162499 0.90625885
#  0.03329977 0.04992472], val=11.98159137082509, best=11.9815913708
#
# 	Proposed next point to try: 0.057413-0.070801-0.039183-0.061138-0.311625-0.906259-0.033300-0.049925
#
# Using UCB Acquisition function with Kappa = 20
# 	131071 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 7.1861996, 'max': 14.56165204, 'mean': 10.41831619, 'std': 1.08593627, 'q1': 9.62111102, 'median': 10.40094393, 'q3': 11.19548324}
# 	Local search 1/256, x=[0.02466124 0.96348672 0.01960601 0.95402864 0.05300322 0.96604069
#  0.0317708  0.95181913], val=14.862412256670124, best=14.8624122567
# 	Local search 2/256, x=[0.02635101 0.95722423 0.01649117 0.95436484 0.95520079 0.95612788
#  0.03698158 0.96608981], val=14.862853352447132, best=14.8628533524
# 	Local search 4/256, x=[0.02630812 0.95678101 0.01626739 0.95406123 0.95467224 0.95708544
#  0.03757271 0.96576856], val=14.862862744685842, best=14.8628627447
# 	Local search 8/256, x=[0.02659209 0.95721019 0.01666458 0.95398397 0.95427802 0.95721058
#  0.03717551 0.96579578], val=14.862904630037193, best=14.8629046300
# 	Local search 48/256, x=[0.02673254 0.9578739  0.01658388 0.95411592 0.95459594 0.95667377
#  0.03769013 0.96561062], val=14.862905511624156, best=14.8629055116
# 	Local search 55/256, x=[0.02680124 0.95736993 0.01661681 0.95437567 0.95472318 0.95711151
#  0.03748571 0.96563854], val=14.862907233611757, best=14.8629072336
# 	Local search 66/256, x=[0.02675768 0.95776458 0.01674526 0.95385735 0.95376331 0.95701062
#  0.03739069 0.96598135], val=14.862907414472275, best=14.8629074145
# 	Local search 105/256, x=[0.02680245 0.95763868 0.01666748 0.95443231 0.95401121 0.95741428
#  0.0374454  0.96613899], val=14.862908435932749, best=14.8629084359
# 	Local search 176/256, x=[0.02665611 0.95788469 0.01659901 0.95461472 0.95388787 0.95721324
#  0.03744019 0.96598407], val=14.862908511765458, best=14.8629085118
# 	Local search 254/256, x=[0.0267347  0.95776792 0.01670036 0.95439201 0.95472072 0.95688062
#  0.03738053 0.96575847], val=14.862911551934014, best=14.8629115519
#
# 	Proposed next point to try: 0.026735-0.957768-0.016700-0.954392-0.954721-0.956881-0.037381-0.965758

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: {'alpha': 1e-08, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 5}
# F2: {'alpha': 0.0001, 'kernel': RBF(length_scale=1), 'n_restarts_optimizer': 5}
# F3: {'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 20}
# F4: {'alpha': 1e-08, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 10}
# F5: {'alpha': 0.01, 'kernel': Matern(length_scale=2, nu=0.5), 'n_restarts_optimizer': 20}
# F6: {'alpha': 0.01, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 5}
# F7: {'alpha': 0.0001, 'kernel': RationalQuadratic(alpha=1, length_scale=2), 'n_restarts_optimizer': 5}
# F8: {'alpha': 0.01, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 10}
#
#
# F1:
# 0: 0.993381-0.994548
# 1: 0.005040-0.998743
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 0.981749-0.991758
# 5: 0.009194-0.991734
# 6: 0.008317-0.990872
# 7: 0.007870-0.990426
#
# F2:
# 0: 0.543982-1.000000
# 1: 0.497888-0.496299
# 2: 0.506112-1.000000
# 3: 0.497888-0.496299
# 4: 0.497888-0.496299
