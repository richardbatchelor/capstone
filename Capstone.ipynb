# %% [markdown]
# ## Setup

# %%
import numpy as np
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats._qmc import Sobol
from scipy.stats import norm
from scipy.optimize import minimize
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern
from sklearn.model_selection import GridSearchCV

from dataloading_utils import (combineInitialDataAndSubmissionsToDate, sortByLargestOutputDescending)


import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma


def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
from sklearn.gaussian_process.kernels import WhiteKernel


def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }

def findTunedGaussianProcessRegressor(X_samples, y_samples):
    n_dims = X_samples.shape[1]

    base_kernels = [
        ConstantKernel(1.0) * RBF(length_scale=np.ones(n_dims)),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=0.5),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=1.5),
        ConstantKernel(1.0) * Matern(length_scale=np.ones(n_dims), nu=2.5),
    ]
    kernels = [k + WhiteKernel() for k in base_kernels]

    param_grid = {
        'kernel': kernels,
        'n_restarts_optimizer': [10]
    }

    gp = GaussianProcessRegressor(normalize_y=True)

    grid_search = GridSearchCV(gp, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_




# def findTunedGaussianProcessRegressor(X_samples, y_samples):
#     n_dims = X_samples.shape[1]
#
#     # ARD kernels (vector length_scale)
#     rbf_ard = RBF(length_scale=np.ones(n_dims),
#                   length_scale_bounds=(1e-2, 1e2))
#     rbf_ardC = RBF(length_scale=np.ones(n_dims),
#                   length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#
#     matern_05 = Matern(length_scale=np.ones(n_dims), nu=0.5,
#                        length_scale_bounds=(1e-2, 1e2))
#     matern_15 = Matern(length_scale=np.ones(n_dims), nu=1.5,
#                        length_scale_bounds=(1e-2, 1e2))
#     matern_25 = Matern(length_scale=np.ones(n_dims), nu=2.5,
#                        length_scale_bounds=(1e-2, 1e2))
#
#     matern_05C = Matern(length_scale=np.ones(n_dims), nu=0.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#     matern_15C = Matern(length_scale=np.ones(n_dims), nu=1.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#     matern_25C = Matern(length_scale=np.ones(n_dims), nu=2.5,
#                        length_scale_bounds=(1e-2, 1e2)) * ConstantKernel(1.0)
#
#     param_grid = {
#         'kernel': [
#             rbf_ard,
#             rbf_ardC,
#             matern_05, matern_15, matern_25,
#             matern_05C, matern_15C, matern_25C,
#         ],
#         'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
#         'n_restarts_optimizer': [5, 10, 20]
#     }
#
#     gp = GaussianProcessRegressor(normalize_y=True)
#
#     grid_search = GridSearchCV(gp, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
#     grid_search.fit(X_samples, y_samples)
#
#     return grid_search.best_estimator_, grid_search.best_params_


def penaltyWeightAndScaleForDimension(d):
    #Curse of dimensionality means this needs to be much tighter at higher dimensions
    #This is intended to reduce the acquisition function's information gain by 10% if the point has a Euclidean distance of 1/20th or 1/50th of a boundary.
    if d <= 5:
        return 0.1, 0.05
    else:
        return 0.1, 0.02


def get_length_scale(kernel):
    if hasattr(kernel, "length_scale"):
        return kernel.length_scale
    elif hasattr(kernel, "k1"):
        return get_length_scale(kernel.k1)
    elif hasattr(kernel, "k2"):
        return get_length_scale(kernel.k2)
    return None



def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None,
        excludeDuplicates = True):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims

    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]
    penaltyWeight, penalityScale = penaltyWeightAndScaleForDimension(n_dims)

    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process - or assume one has been fitted
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )
        gp.fit(X_samples, y_samples)
        print(f"Fitted default GaussianProcessRegressor since one not provided")

    # -----------------------------
    # 2. Acquisition function
    # -----------------------------

    # -----------------------------
    # 2.1 Boundary Penalty.
    # GP tends to hug the boundary, so add a penalty if a suggested point is close to boundary.
    # Scale controls how far from the boundary the penalty reaches. At scale=0.05, a point at x=0.05 gets a penalty of exp(-1) ≈ 0.37, meaning the penalty is significant only within the last ~5% of the search space.
    # Weight controls how strongly that penalty suppresses the acquisition value. At weight=0.1, the maximum possible suppression is 10% of the acquisition value.
    #
    # -----------------------------
    def boundary_penalty(X, weight=0.1, scale=0.05):
        X = np.atleast_2d(X)
        d = np.minimum(X, 1.0 - X)    #Find point closest to boundary at 0 or 1 in any dimension.
        penalty = np.mean(np.exp(-d / scale), axis=1)   #exp(-small) tends towards 1, exp(-large) tends towards 0. Mean takes into account other dimensions.
        return weight * penalty


    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        penalty = boundary_penalty(X, weight=penaltyWeight, scale=penalityScale)
        return val * (1 - penalty)


    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Filter out duplicate candidates, based on Eucledian distance because acquisition functions can suggest previous points.
    def is_duplicate(x, X_samples, tol=1e-5):
        return np.any(np.linalg.norm(X_samples - x, axis=1) < tol)

    if (excludeDuplicates):
        mask = np.array([not is_duplicate(x, X_samples) for x in X_candidates])
        X_candidates = X_candidates[mask]
        acq_vals = acq_vals[mask]


    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{ len(X_candidates) } Sobol candidates, best { len(X_start) } to be minimised in local search")
    print(f"\tInitial acquisition function stats { summary_stats(acq_vals) }")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition

    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun

        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val, X_start

# %%
def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')


def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)

    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem initially is ${bestParams}")
    print()

    #Fit GaussianProcesses to samples provided
    gpr.fit(f_Inputs, f_Outputs)
    gpKernels[functionName] = gpr.kernel_   #Get the kernel after it has been fitted.


    lengthScale = get_length_scale(gpr.kernel_)
    if lengthScale is not None:
        print(f"Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is {lengthScale}")


    functionProposedPoints = {}
    count = -1

    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.00787  0.037348] , Max:  [0.88388983 0.990426  ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  5.350575982148602e-09
#
# [[ 5.500000e-001  5.500000e-001  5.350576e-009]
#  [ 5.000000e-001  5.000000e-001  2.675288e-009]
#  [ 5.000020e-001  3.340760e-001  2.397010e-010]
#  [ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 7.870000e-003  9.904260e-001  0.000000e+000]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 2.386200e-001  4.997890e-001 -1.652362e-028]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 18 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1], nu=0.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00027307, 'mean': 0.00020974, 'std': 7.519e-05, 'q1': 0.00018224, 'median': 0.00024702, 'q3': 0.00026065}
# 	Local search 1/64, x=[0.46560704 0.49818924], val=0.0002730702937334768, best=0.0002730703
# 	Local search 29/64, x=[0.46552108 0.48357258], val=0.00027307039424145674, best=0.0002730704
#
# 	Proposed next point to try: 0.465521-0.483573
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00360136, 'max': 3.787e-05, 'mean': -0.000153, 'std': 0.00049613, 'q1': -7.641e-05, 'median': -2.321e-05, 'q3': 1.273e-05}
# 	Local search 1/64, x=[0.42079533 0.51127631], val=3.786799882921673e-05, best=0.0000378680
# 	Local search 11/64, x=[0.42073221 0.48482912], val=3.786833071107307e-05, best=0.0000378683
#
# 	Proposed next point to try: 0.420732-0.484829
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00346616, 'max': 0.00411442, 'mean': 0.00316047, 'std': 0.00104383, 'q1': 0.00264861, 'median': 0.00353126, 'q3': 0.00395398}
# 	Local search 1/64, x=[0.16735409 0.50303699], val=0.0041144218223468434, best=0.0041144218
# 	Local search 37/64, x=[0.16716216 0.511052  ], val=0.00411442201525267, best=0.0041144220
#
# 	Proposed next point to try: 0.167162-0.511052
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00332819, 'max': 0.00841208, 'mean': 0.00654156, 'std': 0.00189408, 'q1': 0.00541674, 'median': 0.00722206, 'q3': 0.00805294}
# 	Local search 1/64, x=[0.16525341 0.51355888], val=0.008412083109408379, best=0.0084120831
# 	Local search 5/64, x=[0.16493384 0.49034291], val=0.008412089532204675, best=0.0084120895
# 	Local search 30/64, x=[0.16497263 0.50682167], val=0.00841209070695666, best=0.0084120907
# 	Local search 35/64, x=[0.1650315  0.50302813], val=0.008412091915114333, best=0.0084120919
# 	Local search 43/64, x=[0.16498663 0.4970969 ], val=0.008412092291847683, best=0.0084120923
#
# 	Proposed next point to try: 0.164987-0.497097
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00305227, 'max': 0.01700755, 'mean': 0.01330374, 'std': 0.00368036, 'q1': 0.01121022, 'median': 0.01462199, 'q3': 0.01625299}
# 	Local search 1/64, x=[0.16437432 0.52823635], val=0.017007550174488278, best=0.0170075502
# 	Local search 2/64, x=[0.1643258  0.47566528], val=0.017007555525816793, best=0.0170075555
# 	Local search 5/64, x=[0.16432736 0.5233932 ], val=0.017007556698756685, best=0.0170075567
# 	Local search 7/64, x=[0.16433365 0.51354885], val=0.0170075677268881, best=0.0170075677
# 	Local search 15/64, x=[0.16435084 0.49034147], val=0.017007571462287225, best=0.0170075715
# 	Local search 18/64, x=[0.16434453 0.50682329], val=0.01700757407786139, best=0.0170075741
# 	Local search 30/64, x=[0.16435323 0.49709542], val=0.01700757737805393, best=0.0170075774
# 	Local search 39/64, x=[0.16433987 0.49916579], val=0.01700757909920466, best=0.0170075791
#
# 	Proposed next point to try: 0.164340-0.499166

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.         0.02869772] , Max:  [0.996055 0.970764]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6390022767203885
#
# [[ 0.720000  0.880000  0.639002]
#  [ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.600000  0.500000  0.144121]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.996055  0.236836 -0.006793]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.000000  0.500000 -0.031277]
#  [ 0.092501  0.897042 -0.043957]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 18 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1], nu=1.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01293486, 'mean': 0.00038488, 'std': 0.00165391, 'q1': 0.0, 'median': 1e-08, 'q3': 2.11e-05}
# 	Local search 1/64, x=[0.7124111  0.63396773], val=0.012934859102819721, best=0.0129348591
# 	Local search 3/64, x=[0.71241111 0.50235441], val=0.012935256377223089, best=0.0129352564
# 	Local search 9/64, x=[0.71240983 0.50004465], val=0.012935257571233195, best=0.0129352576
# 	Local search 11/64, x=[0.71241179 0.49976712], val=0.012935257600902385, best=0.0129352576
# 	Local search 35/64, x=[0.71241118 0.49999633], val=0.012935257790543789, best=0.0129352578
#
# 	Proposed next point to try: 0.712411-0.499996
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 6.994e-05, 'mean': 4.76e-06, 'std': 1.231e-05, 'q1': 0.0, 'median': 0.0, 'q3': 8e-07}
# 	Local search 1/64, x=[0.68739605 0.44482064], val=6.993559073745349e-05, best=0.0000699356
# 	Local search 7/64, x=[0.68739622 0.55391427], val=6.993560262700899e-05, best=0.0000699356
# 	Local search 13/64, x=[0.687396   0.51330543], val=6.993586221830255e-05, best=0.0000699359
# 	Local search 18/64, x=[0.68739666 0.4978855 ], val=6.993590336085494e-05, best=0.0000699359
#
# 	Proposed next point to try: 0.687397-0.497885
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.23895901 0.57202577], val=3.26587873969304e-09, best=0.0000000033
#
# 	Proposed next point to try: 0.238959-0.572026
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.06108852, 'max': 0.63795899, 'mean': 0.16408362, 'std': 0.1768717, 'q1': 0.02501377, 'median': 0.10826768, 'q3': 0.24461529}
# 	Local search 1/64, x=[0.71257908 0.50235294], val=0.6379591513211639, best=0.6379591513
# 	Local search 2/64, x=[0.71258074 0.50000092], val=0.6379592205632234, best=0.6379592206
# 	Local search 3/64, x=[0.71257943 0.49999997], val=0.6379592211073405, best=0.6379592211
# 	Local search 7/64, x=[0.71257932 0.49999977], val=0.6379592211080588, best=0.6379592211
# 	Local search 14/64, x=[0.71257937 0.50000008], val=0.6379592211103167, best=0.6379592211
# 	Local search 21/64, x=[0.71257923 0.50000019], val=0.6379592211108067, best=0.6379592211
# 	Local search 35/64, x=[0.71257924 0.49999995], val=0.637959221114828, best=0.6379592211
#
# 	Proposed next point to try: 0.712579-0.500000
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.1242846, 'max': 1.09403507, 'mean': 0.62671208, 'std': 0.25796218, 'q1': 0.41669143, 'median': 0.63286436, 'q3': 0.82467869}
# 	Local search 1/64, x=[0.23907781 0.54166628], val=1.0940352581736463, best=1.0940352582
# 	Local search 2/64, x=[0.23907931 0.46904891], val=1.0940363610875592, best=1.0940363611
# 	Local search 4/64, x=[0.23908102 0.51045423], val=1.094037912596879, best=1.0940379126
# 	Local search 5/64, x=[0.23908113 0.49999956], val=1.0940384903152374, best=1.0940384903
# 	Local search 15/64, x=[0.23907819 0.49999995], val=1.0940384904906977, best=1.0940384905
# 	Local search 16/64, x=[0.23907866 0.50000002], val=1.094038490554726, best=1.0940384906
# 	Local search 20/64, x=[0.23907905 0.5       ], val=1.0940384905822744, best=1.0940384906
# 	Local search 51/64, x=[0.23907947 0.49999997], val=1.0940384905843252, best=1.0940384906
#
# 	Proposed next point to try: 0.239079-0.500000
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.30915346, 'max': 2.10751563, 'mean': 1.09878194, 'std': 0.47591957, 'q1': 0.70053566, 'median': 1.03727687, 'q3': 1.40538387}
# 	Local search 1/64, x=[0.23920991 0.54168137], val=2.1075164745040498, best=2.1075164745
# 	Local search 2/64, x=[0.23920753 0.50000079], val=2.107522703506567, best=2.1075227035
# 	Local search 11/64, x=[0.23920949 0.49999944], val=2.1075227042426716, best=2.1075227042
# 	Local search 18/64, x=[0.23921018 0.50000005], val=2.1075227043035567, best=2.1075227043
# 	Local search 35/64, x=[0.23920967 0.50000002], val=2.1075227043085336, best=2.1075227043
# 	Local search 38/64, x=[0.23921011 0.49999999], val=2.1075227043118203, best=2.1075227043
#
# 	Proposed next point to try: 0.239210-0.500000
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.63923098, 'max': 4.13448825, 'mean': 2.04292165, 'std': 0.96025494, 'q1': 1.2686477, 'median': 1.83544513, 'q3': 2.68235979}
# 	Local search 1/64, x=[0.23929151 0.50000004], val=4.134495295536793, best=4.1344952955
# 	Local search 11/64, x=[0.23929174 0.50000005], val=4.134495295537701, best=4.1344952955
# 	Local search 40/64, x=[0.23929164 0.49999999], val=4.1344952955476035, best=4.1344952955
#
# 	Proposed next point to try: 0.239292-0.500000

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.        ] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.380000  0.450000  0.400000 -0.022475]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.600097  0.725136  0.066089 -0.036378]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.500003  0.500001  0.656244 -0.092565]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.431029  0.814368  0.806413 -0.098068]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.500001  0.500000  0.000000 -0.107063]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965337  0.047492  0.944587 -0.273443]
#  [ 0.151837  0.439991  0.990882 -0.398926]]
#
# Starting 3D Bayes Optimisation from 23 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01499099, 'mean': 0.00248231, 'std': 0.003458, 'q1': 3.5e-07, 'median': 0.00070519, 'q3': 0.00399783}
# 	Local search 1/96, x=[0.59581601 0.35874803 0.86787086], val=0.01499116963070852, best=0.0149911696
# 	Local search 3/96, x=[0.49662416 0.38572703 0.86787087], val=0.014991459770836674, best=0.0149914598
# 	Local search 9/96, x=[0.47428698 0.50001818 0.86786721], val=0.014991646661793938, best=0.0149916467
# 	Local search 11/96, x=[0.48063463 0.50779082 0.86787094], val=0.014991647581774332, best=0.0149916476
# 	Local search 40/96, x=[0.49948067 0.50072117 0.86787176], val=0.014991661589059128, best=0.0149916616
#
# 	Proposed next point to try: 0.499481-0.500721-0.867872
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00029494, 'mean': 1.265e-05, 'std': 4.478e-05, 'q1': 0.0, 'median': 0.0, 'q3': 3.6e-07}
# 	Local search 1/96, x=[0.53336081 0.51757234 0.86650293], val=0.00029493953566550027, best=0.0002949395
# 	Local search 76/96, x=[0.48955069 0.53678278 0.86650244], val=0.000294939559035083, best=0.0002949396
#
# 	Proposed next point to try: 0.489551-0.536783-0.866502
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.43038062 0.39738424 0.86503145], val=5.914752426412087e-25, best=0.0000000000
#
# 	Proposed next point to try: 0.430381-0.397384-0.865031
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.37871622, 'max': -0.02089719, 'mean': -0.09049351, 'std': 0.07551776, 'q1': -0.11445973, 'median': -0.06601104, 'q3': -0.03902759}
# 	Local search 1/96, x=[0.         0.         0.39776045], val=-0.020622671773269156, best=-0.0206226718
# 	Local search 2/96, x=[1.         0.         0.39776072], val=-0.020622671084982638, best=-0.0206226711
# 	Local search 5/96, x=[1.         1.         0.39776068], val=-0.02062267107405189, best=-0.0206226711
# 	Local search 82/96, x=[1.         1.         0.39776069], val=-0.020622671074051628, best=-0.0206226711
#
# 	Proposed next point to try: 1.000000-1.000000-0.397761
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.25855953, 'max': 0.23307384, 'mean': 0.06341839, 'std': 0.09589522, 'q1': 0.01389456, 'median': 0.08029687, 'q3': 0.11654886}
# 	Local search 1/96, x=[0.44176822 0.45684238 0.86559685], val=0.23307479318317031, best=0.2330747932
# 	Local search 3/96, x=[0.50747592 0.50000004 0.86559525], val=0.23307599983536062, best=0.2330759998
# 	Local search 22/96, x=[0.49853426 0.50047772 0.86559685], val=0.23307604321026787, best=0.2330760432
# 	Local search 40/96, x=[0.49816034 0.49999997 0.86559617], val=0.23307604382315658, best=0.2330760438
#
# 	Proposed next point to try: 0.498160-0.500000-0.865596
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.13669105, 'max': 0.49642505, 'mean': 0.22047134, 'std': 0.12876739, 'q1': 0.14018823, 'median': 0.22619972, 'q3': 0.29418784}
# 	Local search 1/96, x=[0.43038095 0.39738488 0.86498782], val=0.49642539878532543, best=0.4964253988
# 	Local search 2/96, x=[0.48956826 0.53675304 0.86498875], val=0.49643179312265995, best=0.4964317931
# 	Local search 4/96, x=[0.46234968 0.50000079 0.86498937], val=0.49643193911073524, best=0.4964319391
# 	Local search 5/96, x=[0.50746518 0.5        0.8649833 ], val=0.4964326604005371, best=0.4964326604
# 	Local search 8/96, x=[0.49973784 0.50044445 0.86498438], val=0.4964327725349005, best=0.4964327725
# 	Local search 20/96, x=[0.50002948 0.50007991 0.86498943], val=0.49643278325188533, best=0.4964327833
# 	Local search 35/96, x=[0.50000395 0.49994507 0.86498762], val=0.49643278447317, best=0.4964327845
# 	Local search 36/96, x=[0.49997643 0.5000011  0.86498784], val=0.4964327849962779, best=0.4964327850
# 	Local search 75/96, x=[0.49999956 0.50001853 0.86498815], val=0.4964327850626157, best=0.4964327851
#
# 	Proposed next point to try: 0.500000-0.500019-0.864988
#
# Using UCB Acquisition function with Kappa = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0
# 	Local search 26/128, x=[0.43375944 0.4468072  0.30926139 0.4314742 ], val=0.003869095478917741, best=0.0038690955
# 	Local search 78/128, x=[0.43375967 0.44680839 0.30926144 0.4314748 ], val=0.0038690954793011486, best=0.0038690955
# 	Local search 112/128, x=[0.4337592  0.44680811 0.30926251 0.43147377], val=0.003869095481636528, best=0.0038690955
#
# 	Proposed next point to try: 0.433759-0.446808-0.309263-0.431474
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.97379464 0.04219307 0.00895425 0.0875011 ], val=3.267546099042626e-20, best=0.0000000000
#
# 	Proposed next point to try: 0.973795-0.042193-0.008954-0.087501
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -39.12070866, 'max': 0.22934858, 'mean': -17.25195146, 'std': 6.96952978, 'q1': -22.15731168, 'median': -17.27430843, 'q3': -12.11779918}
# 	Local search 1/128, x=[0.42875297 0.42142156 0.36463002 0.42336367], val=0.37998054743229487, best=0.3799805474
# 	Local search 2/128, x=[0.42875175 0.42142228 0.36463077 0.42336371], val=0.379980547530601, best=0.3799805475
# 	Local search 3/128, x=[0.42875043 0.4214215  0.36462844 0.42336216], val=0.3799805475889837, best=0.3799805476
# 	Local search 5/128, x=[0.42875189 0.42142207 0.36462844 0.42336215], val=0.3799805475984914, best=0.3799805476
# 	Local search 6/128, x=[0.42875112 0.42142136 0.36462954 0.42336207], val=0.37998054765719985, best=0.3799805477
# 	Local search 7/128, x=[0.42875101 0.42142233 0.3646286  0.42336329], val=0.37998054770823203, best=0.3799805477
# 	Local search 30/128, x=[0.42875136 0.42142214 0.36462876 0.42336357], val=0.379980547712424, best=0.3799805477
# 	Local search 53/128, x=[0.42875075 0.42142204 0.36462978 0.42336288], val=0.3799805477214647, best=0.3799805477
# 	Local search 89/128, x=[0.4287511  0.42142148 0.3646291  0.42336298], val=0.3799805477366729, best=0.3799805477
#
# 	Proposed next point to try: 0.428751-0.421421-0.364629-0.423363
#
# Using UCB Acquisition function with Kappa = 5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -31.80110376, 'max': 3.10400542, 'mean': -9.91710946, 'std': 5.85428632, 'q1': -13.83830822, 'median': -9.57451459, 'q3': -5.56988153}
# 	Local search 1/128, x=[0.44855526 0.48777637 0.13214853 0.4360881 ], val=3.2153814167928605, best=3.2153814168
# 	Local search 2/128, x=[0.44855678 0.48777615 0.13215468 0.43608786], val=3.215381417336385, best=3.2153814173
# 	Local search 12/128, x=[0.44855545 0.48777532 0.13215349 0.43608752], val=3.215381417484575, best=3.2153814175
# 	Local search 61/128, x=[0.44855532 0.48777541 0.13215539 0.43608691], val=3.215381417536332, best=3.2153814175
#
# 	Proposed next point to try: 0.448555-0.487775-0.132155-0.436087
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -29.245876, 'max': 24.11165126, 'mean': -2.43257681, 'std': 6.43618829, 'q1': -6.57161193, 'median': -1.77256854, 'q3': 1.97067137}
# 	Local search 1/128, x=[1. 0. 0. 0.], val=29.454527994277182, best=29.4545279943
#
# 	Proposed next point to try: 1.000000-0.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min':
known samples
#
# Best GP kernel and hyperparams for problem initially is ${'kernel': 1**2 * Matern(length_scale=[1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1), 'n_restarts_optimizer': 10}
#
# Using Expected Improvement Acquisition function with xi = 0
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 194.32437046, 'mean': 0.00382768, 'std': 0.77578827, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[1. 1. 1. 1.], val=691.0176836885774, best=691.0176836886
#
# 	Proposed next point to try: 1.000000-1.000000-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 194.23205077, 'mean': 0.00382505, 'std': 0.77539484, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[1. 1. 1. 1.], val=690.9276836885774, best=690.9276836886
#
# 	Proposed next point to try: 1.000000-1.000000-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 193.86280696, 'mean': 0.00381454, 'std': 0.77382183, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[1. 1. 1. 1.], val=690.5676836885774, best=690.5676836886
#
# 	Proposed next point to try: 1.000000-1.000000-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 175.94159593, 'mean': 0.00332946, 'std': 0.69843135, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[1. 1. 1. 1.], val=673.0176836885774, best=673.0176836886
#
# 	Proposed next point to try: 1.000000-1.000000-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -746.86308464, 'max': 4581.44583638, 'mean': 189.21386464, 'std': 394.5117054, 'q1': 7.8639902, 'median': 101.35140995, 'q3': 266.02294981}
# 	Local search 1/128, x=[0.96604055 1.         1.         1.        ], val=4930.446733468319, best=4930.4467334683
# 	Local search 2/128, x=[0.96603949 1.         1.         1.        ], val=4930.446733479789, best=4930.4467334798
# 	Local search 3/128, x=[0.96603968 1.         1.         1.        ], val=4930.446733479945, best=4930.4467334799
# 	Local search 9/128, x=[0.96603966 1.         1.         1.        ], val=4930.4467334800065, best=4930.4467334800
# 	Local search 34/128, x=[0.96603968 1.         1.         1.        ], val=4930.446733480351, best=4930.4467334804
#
# 	Proposed next point to try: 0.966040-1.000000-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 82.49482138, 'max': 5985.97642453, 'mean': 1586.41845524, 'std': 865.25057043, 'q1': 927.54705583, 'median': 1383.30142973, 'q3': 2049.14815752}
# 	Local search 1/128, x=[0.07752761 0.         0.         1.        ], val=6234.970446528764, best=6234.9704465288
# 	Local search 2/128, x=[0.07752787 0.         0.         1.        ], val=6234.970446531854, best=6234.9704465319
# 	Local search 7/128, x=[0.0775292 0.        0.        1.       ], val=6234.970446532654, best=6234.9704465327
# 	Local search 8/128, x=[0.07752864 0.         0.         1.        ], val=6234.970446535209, best=6234.9704465352
# 	Local search 92/128, x=[0.07752866 0.         0.         1.        ], val=6234.970446535371, best=6234.9704465354
#
# 	Proposed next point to try: 0.077529-0.000000-0.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 161.17418712, 'max': 11295.57390257, 'mean': 3012.13742523, 'std': 1550.68457422, 'q1': 1858.22309293, 'median': 2702.35622866, 'q3': 3809.07000426}
# 	Local search 1/128, x=[0.05592981 0.         0.         0.        ], val=12100.028812972794, best=12100.0288129728
# 	Local search 2/128, x=[0.0559303 0.        0.        0.       ], val=12100.028812989343, best=12100.0288129893
# 	Local search 4/128, x=[0.05593074 0.         0.         0.        ], val=12100.028812995253, best=12100.0288129953
# 	Local search 16/128, x=[0.05593086 0.         0.         0.        ], val=12100.028812995666, best=12100.0288129957
# 	Local search 36/128, x=[0.0559309 0.        0.        0.       ], val=12100.028812995692, best=12100.0288129957
# 	Local search 66/128, x=[0.05593084 0.         0.         0.        ], val=12100.028812995904, best=12100.0288129959
#
# 	Proposed next point to try: 0.055931-0.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 
Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0454562, 'mean': 0.00024283, 'std': 0.00165747, 'q1': 0.0, 'median': 0.0, 'q3': 4e-07}
# 	Local search 1/160, x=[0.37712579 0.         0.65222327 0.76263622 0.        ], val=0.05320567380019911, best=0.0532056738
# 	Local search 2/160, x=[0.37712532 0.         0.65222197 0.76263803 0.        ], val=0.05320567380220495, best=0.0532056738
# 	Local search 6/160, x=[0.37712526 0.         0.65222187 0.76263768 0.        ], val=0.053205673802297036, best=0.0532056738
#
# 	Proposed next point to try: 0.377125-0.000000-0.652222-0.762638-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.02111843, 'mean': 8.257e-05, 'std': 0.00065378, 'q1': 0.0, 'median': 0.0, 'q3': 4e-08}
# 	Local search 1/160, x=[0.36426155 0.         0.67647696 0.76796805 0.        ], val=0.02605781423401857, best=0.0260578142
# 	Local search 7/160, x=[0.36426084 0.         0.67647616 0.76796837 0.        ], val=0.02605781423498997, best=0.0260578142
# 	Local search 8/160, x=[0.36426093 0.         0.67647496 0.76796889 0.        ], val=0.026057814235360886, best=0.0260578142
#
# 	Proposed next point to try: 0.364261-0.000000-0.676475-0.767969-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00054605, 'mean': 4.8e-07, 'std': 7.24e-06, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.21608553 0.         1.         1.         0.        ], val=0.000807242095007576, best=0.0008072421
# 	Local search 11/160, x=[0.21606062 0.         1.         1.         0.        ], val=0.0008072420985180644, best=0.0008072421
# 	Local search 21/160, x=[0.2160703 0.        1.        1.        0.       ], val=0.0008072420994612308, best=0.0008072421
#
# 	Proposed next point to try: 0.216070-0.000000-1.000000-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.90169647 0.66109683 0.79777125 0.72341419 0.04159627], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.901696-0.661097-0.797771-0.723414-0.041596
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.71263331, 'max': -0.33380448, 'mean': -1.46054159, 'std': 0.41418248, 'q1': -1.76189203, 'median': -1.46776521, 'q3': -1.16471215}
# 	Local search 1/160, x=[0.4049206  0.         0.6060305  0.76090289 0.        ], val=-0.31466354594549983, best=-0.3146635459
# 	Local search 19/160, x=[0.40492051 0.         0.60603058 0.76090323 0.        ], val=-0.31466354594538215, best=-0.3146635459
# 	Local search 22/160, x=[0.40492051 0.         0.60603047 0.76090297 0.        ], val=-0.314663545945337, best=-0.3146635459
# 	Local search 62/160, x=[0.40492038 0.         0.60603033 0.76090316 0.        ], val=-0.3146635459452909, best=-0.3146635459
#
# 	Proposed next point to try: 0.404920-0.000000-0.606030-0.760903-0.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.6904992, 'max': 1.05445294, 'mean': -0.39871639, 'std': 0.40429308, 'q1': -0.68762084, 'median': -0.41223919, 'q3': -0.12381106}
# 	Local search 1/160, x=[0.04979369 0.         1.         1.         0.        ], val=1.0829492049753977, best=1.0829492050
# 	Local search 2/160, x=[0.04979319 0.         1.         1.         0.        ], val=1.0829492049763962, best=1.0829492050
# 	Local search 3/160, x=[0.04979311 0.         1.         1.         0.        ], val=1.0829492049764833, best=1.0829492050
# 	Local search 7/160, x=[0.04979308 0.         1.         1.         0.        ], val=1.082949204976503, best=1.0829492050
# 	Local search 8/160, x=[0.04979297 0.         1.         1.         0.        ], val=1.0829492049765646, best=1.0829492050
# 	Local search 10/160, x=[0.04979289 0.         1.         1.         0.        ], val=1.0829492049765825, best=1.0829492050
# 	Local search 13/160, x=[0.04979288 0.         1.         1.         0.        ], val=1.0829492049765845, best=1.0829492050
#
# 	Proposed next point to try: 0.049793-0.000000-1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.8049592, 'max': 2.90768414, 'mean': 0.68477871, 'std': 0.46670576, 'q1': 0.3583306, 'median': 0.66597151, 'q3': 0.97821924}
# 	Local search 1/160, x=[0.         0.         1.         1.         0.01372759], val=2.9499521711752816, best=2.9499521712
# 	Local search 4/160, x=[0.         0.         1.         1.         0.01372749], val=2.949952171175286, best=2.9499521712
# 	Local search 11/160, x=[0.         0.         1.         1.         0.01372759], val=2.949952171175291, best=2.9499521712
# 	Local search 26/160, x=[0.         0.         1.         1.         0.01372757], val=2.949952171175297, best=2.9499521712
# 	Local search 32/160, x=[0.         0.         1.         1.         0.01372753], val=2.9499521711753083, best=2.9499521712
# 	Local search 57/160, x=[0.         0.         1.         1.         0.01372753], val=2.949952171175309, best=2.9499521712
# 	Local search 59/160, x=[0.         0.         1.         1.         0.01372753], val=2.9499521711753194, best=2.9499521712
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000-0.013728
#
# Using UCB Acquisition function with Kappa = 20
# 	81917 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.91114352, 'max': 6.61414653, 'mean': 2.85176891, 'std': 0.71853807, 'q1': 2.34238426, 'median': 2.7722856, 'q3': 3.26785024}
# 	Local search 1/160, x=[0.         0.         1.         1.         0.02667464], val=6.703893772582824, best=6.7038937726
# 	Local search 2/160, x=[1.         0.00377546 1.         0.         0.97860583], val=6.849964238861333, best=6.8499642389
# 	Local search 3/160, x=[0.         0.         1.         1.         0.97942595], val=6.898370100180137, best=6.8983701002
# 	Local search 4/160, x=[0.         0.         1.         1.         0.97942602], val=6.898370100180162, best=6.8983701002
# 	Local search 5/160, x=[0.         0.         1.         1.         0.97942603], val=6.898370100180166, best=6.8983701002
# 	Local search 10/160, x=[0.         0.         1.         1.         0.97942598], val=6.898370100180174, best=6.8983701002
# 	Local search 28/160, x=[0.       0.       1.       1.       0.979426], val=6.898370100180187, best=6.8983701002
# 	Local search 37/160, x=[0.         0.         1.         1.         0.97942598], val=6.898370100180194, best=6.8983701002
# 	Local search 107/160, x=[0.         0.         1.         1.         0.97942597], val=6.8983701001801965, best=6.8983701002
# 	Local search 148/160, x=[0.         0.         1.         1.         0.97942597], val=6.898370100180197, best=6.8983701002
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000-0.979426

# %%
f7_Inputs, f7_Outputs = combineInitialDataAndSubmissionsToDate(7)
findNextGuess('F7', f7_Inputs, f7_Outputs)
# Out:
# ********************
# F7  -  6 D
# ********************
#  Inputs -   Min: [0.011684   0.01181284 0.00363456 0.001006   0.01494418 0.05109986] , Max:  [0.94245084 0.932801   0.982137   0.96101714 0.9986547  0.984228  ]
#  Output -   Min: 0.0027014650245082332 , Max (Best):  1.627092775388822
#
 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.         0.32488912 0.52719973 0.1393496  0.35652857 0.71653776], val=0.001514894052487359, best=0.0015148941
# 	Local search 8/192, x=[0.         0.69670042 0.65290487 0.13937287 0.35653    0.71653677], val=0.0015148941220149727, best=0.0015148941
# 	Local search 11/192, x=[0.         0.56878046 0.60625564 0.13937181 0.35652576 0.71653821], val=0.001514894125081227, best=0.0015148941
# 	Local search 14/192, x=[0.         0.43427142 0.56040811 0.1393787  0.35652825 0.71652856], val=0.0015148941279216853, best=0.0015148941
# 	Local search 18/192, x=[0.         0.34930163 0.34549229 0.13937361 0.35652972 0.71653382], val=0.0015148941404207388, best=0.0015148941
# 	Local search 40/192, x=[0.         0.42640137 0.42410818 0.13937114 0.35652887 0.71653395], val=0.001514894140870305, best=0.0015148941
# 	Local search 85/192, x=[0.         0.44894847 0.34773864 0.13937347 0.35653023 0.71653382], val=0.0015148941410543892, best=0.0015148941
#
# 	Proposed next point to try: 0.000000-0.448948-0.347739-0.139373-0.356530-0.716534
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 2.2e-07, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.00541396 0.19544032 0.62638784 0.02502969 0.32345126 0.69016614], val=2.1756164190423747e-07, best=0.0000002176
#
# 	Proposed next point to try: 0.005414-0.195440-0.626388-0.025030-0.323451-0.690166
#
# Using Expected Improvement Acquisition function with xi = 20
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.75641283 0.37401439 0.26361436 0.92899298 0.71707398 0.66908677], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.756413-0.374014-0.263614-0.928993-0.717074-0.669087
#
# Using UCB Acquisition function with Kappa = 0.1
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.01683777, 'max': 1.53511569, 'mean': 0.29409181, 'std': 0.20536751, 'q1': 0.14900007, 'median': 0.22860778, 'q3': 0.39890587}
# 	Local search 1/192, x=[0.03198064 0.70023504 0.30386318 0.17308954 0.3666129  0.73198312], val=1.6218745657126385, best=1.6218745657
# 	Local search 6/192, x=[0.03198078 0.58971768 0.47863323 0.17308958 0.36661297 0.73198309], val=1.6218745663825382, best=1.6218745664
# 	Local search 7/192, x=[0.03198141 0.53604905 0.39322237 0.17308952 0.36661296 0.73198308], val=1.6218747568116774, best=1.6218747568
# 	Local search 8/192, x=[0.0319815  0.32928653 0.30066079 0.17308955 0.36661296 0.73198304], val=1.6218747904659487, best=1.6218747905
# 	Local search 16/192, x=[0.03198169 0.39234821 0.30135599 0.1730898  0.36661288 0.73198295], val=1.6218748362732769, best=1.6218748363
# 	Local search 108/192, x=[0.0319819  0.47937772 0.317467   0.17308934 0.36661294 0.73198265], val=1.6218748411474364, best=1.6218748411
#
# 	Proposed next point to try: 0.031982-0.479378-0.317467-0.173089-0.366613-0.731983
#
# Using UCB Acquisition function with Kappa = 5
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.41550564, 'max': 2.23239272, 'mean': 1.44160464, 'std': 0.24068359, 'q1': 1.28276891, 'median': 1.43123196, 'q3': 1.5759538}
# 	Local search 1/192, x=[0.05076926 0.70160633 0.74057804 0.05097972 0.34128987 0.6679227 ], val=2.242252703034391, best=2.2422527030
# 	Local search 3/192, x=[0.0507097  0.30226915 0.61055887 0.05097762 0.34129921 0.66792125], val=2.242252786238339, best=2.2422527862
# 	Local search 7/192, x=[0.05075341 0.44894847 0.34773868 0.05098512 0.34129771 0.66791938], val=2.2422528030192406, best=2.2422528030
# 	Local search 9/192, x=[0.05075384 0.60106524 0.6497124  0.05098549 0.34129766 0.66791856], val=2.2422528033524487, best=2.2422528034
# 	Local search 13/192, x=[0.05075352 0.5766498  0.47203326 0.05098538 0.34129753 0.6679196 ], val=2.2422528041640315, best=2.2422528042
# 	Local search 55/192, x=[0.050754   0.57180787 0.55083496 0.05098515 0.34129767 0.66791956], val=2.2422528042211276, best=2.2422528042
#
# 	Proposed next point to try: 0.050754-0.571808-0.550835-0.050985-0.341298-0.667920
#
# Using UCB Acquisition function with Kappa = 10
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.80848819, 'max': 3.41161767, 'mean': 2.6125361, 'std': 0.33635447, 'q1': 2.39627146, 'median': 2.6256247, 'q3': 2.85457326}
# 	Local search 1/192, x=[0.04941849 0.3157116  0.56553052 0.03128867 0.33229036 0.56352937], val=3.4162749368351855, best=3.4162749368
# 	Local search 2/192, x=[0.04941889 0.57180789 0.55083496 0.03128793 0.33229027 0.56352914], val=3.4162749449252363, best=3.4162749449
# 	Local search 84/192, x=[0.04941876 0.56354969 0.58459531 0.03128806 0.33229011 0.56352935], val=3.416274944973593, best=3.4162749450
#
# 	Proposed next point to try: 0.049419-0.563550-0.584595-0.031288-0.332290-0.563529
#
# Using UCB Acquisition function with Kappa = 20
# 	98301 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 1.5944533, 'max': 6.41346157, 'mean': 4.95439901, 'std': 0.58491543, 'q1': 4.59211826, 'median': 4.99399011, 'q3': 5.3753634}
# 	Local search 1/192, x=[0.06659907 0.20348348 0.72955757 0.03589205 0.96849859 0.02770775], val=6.4427764649513595, best=6.4427764650
# 	Local search 2/192, x=[0.06660541 0.65211547 0.21041993 0.03589827 0.96849616 0.02770445], val=6.4427778221646745, best=6.4427778222
# 	Local search 3/192, x=[0.06660788 0.68697489 0.71966106 0.03589869 0.96849681 0.02770452], val=6.442780647237129, best=6.4427806472
# 	Local search 4/192, x=[0.06660671 0.27940153 0.32640142 0.03590009 0.96849489 0.02770484], val=6.442780650347383, best=6.4427806503
# 	Local search 5/192, x=[0.06660072 0.31508242 0.35083105 0.03589347 0.968498   0.02770921], val=6.442780732956625, best=6.4427807330
# 	Local search 8/192, x=[0.06660159 0.44085655 0.5317517  0.03589709 0.96849598 0.02770288], val=6.4427807525768985, best=6.4427807526
# 	Local search 71/192, x=[0.06660351 0.52121361 0.52034481 0.03589738 0.96849543 0.02770433], val=6.442780752765272, best=6.4427807528
# 	Local search 150/192, x=[0.06660384 0.50557003 0.56354026 0.03589735 0.96849572 0.02770447], val=6.442780752792993, best=6.4427807528
#
# 	Proposed next point to try: 0.066604-0.505570-0.563540-0.035897-0.968496-0.027704

# %%
f8_Inputs, f8_Outputs = combineInitialDataAndSubmissionsToDate(8)
findNextGuess('F8', f8_Inputs, f8_Outputs)
# Out:
# ********************
# F8  -  8 D
# ********************
#  Inputs -   Min: [0.00907698 0.002882   0.003793   0.         0.00964888 0.02211341
#  0.020978   0.02729   ] , Max:  [0.98594539 0.976249   0.9988855  0.970248   0.989136   0.993478
#  0.99291449 0.9887551 ]
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00026249, 'mean': 1e-08, 'std': 1.14e-06, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.0049668  0.06013124 0.19939806 0.         1.         0.56270968
#  0.16680463 0.23498039], val=0.002017529188361061, best=0.0020175292
# 	Local search 5/256, x=[0.0048501  0.05960303 0.19938995 0.         1.         0.56281057
#  0.16671996 0.74107885], val=0.0020175442706660204, best=0.0020175443
# 	Local search 11/256, x=[0.00525265 0.05980386 0.19943261 0.         1.         0.56300429
#  0.16698411 0.71837485], val=0.002017544697461061, best=0.0020175447
#
# 	Proposed next point to try: 0.005253-0.059804-0.199433-0.000000-1.000000-0.563004-0.166984-0.718375
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.07813444 0.05661    0.14020989 0.02351334 0.01364789 0.71081525
#  0.01581105 0.98098204], val=7.192230658448437e-18, best=0.0000000000
#
# 	Proposed next point to try: 0.078134-0.056610-0.140210-0.023513-0.013648-0.710815-0.015811-0.980982
#
# Using Expected Improvement Acquisition function with xi = 20
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.60342807 0.17521487 0.85812777 0.21291129 0.06368856 0.11996655
#  0.08000063 0.31282029], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.603428-0.175215-0.858128-0.212911-0.063689-0.119967-0.080001-0.312820
#
# Using UCB Acquisition function with Kappa = 0.1
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 3.94655377, 'max': 9.95600387, 'mean': 7.90033045, 'std': 0.96029326, 'q1': 7.26122272, 'median': 7.99233726, 'q3': 8.63232072}
# 	Local search 1/256, x=[0.09652001 0.1225276  0.16096189 0.0969554  0.88084654 0.5281856
#  0.18574717 0.45568579], val=9.992633060723076, best=9.9926330607
# 	Local search 11/256, x=[0.09658398 0.12264343 0.16098382 0.09696034 0.88108263 0.5281375
#  0.18567281 0.488086  ], val=9.992633155897762, best=9.9926331559
# 	Local search 18/256, x=[0.09658179 0.12284692 0.16114806 0.09710271 0.88162639 0.5281414
#  0.18599726 0.72030332], val=9.992633204083347, best=9.9926332041
# 	Local search 23/256, x=[0.09651765 0.12282684 0.16104632 0.09719587 0.88122686 0.52822972
#  0.18596042 0.68860116], val=9.992633431582345, best=9.9926334316
# 	Local search 26/256, x=[0.09657265 0.12272458 0.16102277 0.09708371 0.88124336 0.52816379
#  0.18590523 0.66265568], val=9.992633486860495, best=9.9926334869
# 	Local search 104/256, x=[0.09656921 0.12260595 0.16100552 0.09703082 0.8810596  0.52821885
#  0.18577198 0.69253346], val=9.992633508465131, best=9.9926335085
#
# 	Proposed next point to try: 0.096569-0.122606-0.161006-0.097031-0.881060-0.528219-0.185772-0.692533
#
# Using UCB Acquisition function with Kappa = 5
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.53498296, 'max': 10.10563793, 'mean': 8.18723301, 'std': 0.93162811, 'q1': 7.55153816, 'median': 8.27234799, 'q3': 8.90448361}
# 	Local search 1/256, x=[0.05301786 0.06391871 0.28806822 0.06018013 0.92990995 0.5802885
#  0.0774059  0.17308829], val=10.196051990063788, best=10.1960519901
# 	Local search 2/256, x=[0.05313487 0.06409097 0.28761866 0.06042781 0.92994852 0.58016855
#  0.07740687 0.72863354], val=10.196072640085486, best=10.1960726401
# 	Local search 5/256, x=[0.05312945 0.0639178  0.28803421 0.06029546 0.93002333 0.58046111
#  0.07743585 0.57777174], val=10.196073682460117, best=10.1960736825
# 	Local search 26/256, x=[0.05303759 0.06402245 0.28824732 0.0602857  0.93004887 0.58038591
#  0.07741485 0.31604567], val=10.19607382296177, best=10.1960738230
# 	Local search 57/256, x=[0.05306367 0.0640192  0.28797899 0.06024999 0.92980046 0.58047605
#  0.07750186 0.34179197], val=10.196074004916378, best=10.1960740049
# 	Local search 105/256, x=[0.05304357 0.06398991 0.28797012 0.06033548 0.92996697 0.58055788
#  0.07747797 0.30934298], val=10.196074068379625, best=10.1960740684
#
# 	Proposed next point to try: 0.053044-0.063990-0.287970-0.060335-0.929967-0.580558-0.077478-0.309343
#
# Using UCB Acquisition function with Kappa = 10
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.03270227, 'max': 10.4958378, 'mean': 8.47999072, 'std': 0.91789799, 'q1': 7.83858706, 'median': 8.55458703, 'q3': 9.18752331}
# 	Local search 1/256, x=[0.44698583 0.04394132 0.04073705 0.03506036 0.05813809 0.9228987
#  0.03122136 0.48375197], val=10.537593176348887, best=10.5375931763
# 	Local search 3/256, x=[0.03909795 0.04395957 0.28150399 0.03770211 0.05670564 0.41955468
#  0.03002363 0.27662059], val=10.554679818810083, best=10.5546798188
# 	Local search 5/256, x=[0.03921968 0.04397935 0.28213444 0.03782607 0.05698915 0.42428919
#  0.02992947 0.58901077], val=10.554684915097866, best=10.5546849151
# 	Local search 8/256, x=[0.03383584 0.04519299 0.39267237 0.04142439 0.94409377 0.69453669
#  0.03844275 0.54430485], val=10.571538029648684, best=10.5715380296
# 	Local search 17/256, x=[0.03250206 0.0473901  0.36533264 0.038939   0.94649883 0.9209384
#  0.03734513 0.56412483], val=10.577594936843994, best=10.5775949368
# 	Local search 43/256, x=[0.03249912 0.04739689 0.36515841 0.0388321  0.94638259 0.92088991
#  0.03727296 0.40258615], val=10.577594970163878, best=10.5775949702
# 	Local search 107/256, x=[0.03243536 0.04738197 0.36552726 0.03890783 0.94654328 0.92111881
#  0.03728534 0.45729576], val=10.577595122346125, best=10.5775951223
# 	Local search 199/256, x=[0.03247478 0.04725452 0.36524796 0.03893846 0.94655199 0.92112138
#  0.03722649 0.30376163], val=10.577595605695102, best=10.5775956057
#
# 	Proposed next point to try: 0.032475-0.047255-0.365248-0.038938-0.946552-0.921121-0.037226-0.303762
#
# Using UCB Acquisition function with Kappa = 20
# 	131069 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.71795704, 'max': 12.06318616, 'mean': 9.06550614, 'std': 0.93940947, 'q1': 8.38971177, 'median': 9.10536345, 'q3': 9.77699244}
# 	Local search 1/256, x=[0.97021657 0.02372603 0.01870037 0.01534737 0.04196161 0.9628981
#  0.01257156 0.32910383], val=12.667462519456507, best=12.6674625195
# 	Local search 16/256, x=[0.97026966 0.02371471 0.01870975 0.01539682 0.04196302 0.96288222
#  0.01257461 0.2667203 ], val=12.667462627900193, best=12.6674626279
# 	Local search 215/256, x=[0.97019226 0.02369521 0.01871769 0.01536919 0.04197608 0.96289067
#  0.01257036 0.26805038], val=12.667462706237748, best=12.6674627062
# 	Local search 231/256, x=[0.97022971 0.02369171 0.01870186 0.01535146 0.0419779  0.96289645
#  0.01258561 0.2900935 ], val=12.667462811321007, best=12.6674628113
#
# 	Proposed next point to try: 0.970230-0.023692-0.018702-0.015351-0.041978-0.962896-0.012586-0.290093

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: 1.04**2 * Matern(length_scale=[0.0244, 1e+05], nu=0.5) + WhiteKernel(noise_level=1e-05)
# F2: 0.955**2 * Matern(length_scale=[0.0608, 1e+05], nu=1.5) + WhiteKernel(noise_level=0.0149)
# F3: 1.25**2 * Matern(length_scale=[1.36e+04, 1e+05, 0.0763], nu=2.5) + WhiteKernel(noise_level=0.0488)
# F4: 3.16**2 * Matern(length_scale=[1.67, 1.78, 1.79, 1.66], nu=2.5) + WhiteKernel(noise_level=0.000689)
# F5: 3.71**2 * Matern(length_scale=[6.42, 1.48, 1.72, 1.04], nu=2.5) + WhiteKernel(noise_level=1e-05)
# F6: 2.34**2 * Matern(length_scale=[1.43, 3.2, 2.48, 2.12, 3.43], nu=1.5) + WhiteKernel(noise_level=0.0558)
# F7: 0.849**2 * Matern(length_scale=[1.68, 1.38e+04, 1.24e+04, 0.718, 0.33, 0.397], nu=0.5) + WhiteKernel(noise_level=1e-05)
# F8: 19.2**2 * Matern(length_scale=[8.85, 12.4, 7.11, 12.6, 20.2, 11.9, 8.92, 1e+05], nu=2.5) + WhiteKernel(noise_level=1e-05)
#
#
# F1:
# 0: 0.465521-0.483573
# 1: 0.016199-0.328627
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 0.420732-0.484829
# 5: 0.167162-0.511052
# 6: 0.164987-0.497097
# 7: 0.164340-0.499166
#
# F2:
# 0: 0.712411-0.499996
# 1: 0.687397-0.497885
# 2: 0.238959-0.572026
