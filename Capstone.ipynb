# %% [markdown]
# ## Setup

# %%
import os

from numpy import ndarray
from sklearn.gaussian_process.kernels import Matern
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats._qmc import Sobol
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats import norm
from scipy.optimize import minimize
import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma

#
def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 0.0] = 0.0
    return ei

# %%
def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }

def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims
    if n_local is None:
        n_local = 16 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]


    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    kernel = ConstantKernel(1.0) * Matern(nu=2.5)
    gp = GaussianProcessRegressor(
        kernel=kernel,
        alpha=1e-6,
        n_restarts_optimizer=5,
        normalize_y=True
    )
    gp.fit(X_samples, y_samples)

    # -----------------------------
    # 2. Acquisition function
    # -----------------------------
    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        return val

    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed)

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{len(X_candidates)} Sobol candidates, best {len(X_start)} to be minimised in local search")
    print(f"\tInitial acquisition function stats {summary_stats(acq_vals)}")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition
    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun
        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val

# %%
#Store Results from runs
runResults = {}

# %%
def lexiSort(arr):
    return arr[np.argsort(arr[:, 2])[::-1]]

def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')



def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=False):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = lexiSort(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)


    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()

    functionProposedPoints = {}
    count = -1

    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
def collatePreviousSubmissions(functionNo):
    functionIndex = functionNo -1
    assert(functionIndex >= 0)
    assert(functionIndex <= 7)

    #Search for subfolders and find last submission week and results
    week_folders = [d for d in os.listdir("submission_results") if d.startswith("week") ]
    week_folders.sort(key=lambda w: int(w.replace("week", "")))
    last_week = week_folders[-1]
    week_dir = os.path.join("submission_results", last_week)


    def load_file(file_name):
        file_path = os.path.join(week_dir, file_name)
        all_lines = []
        with open(file_path, "r") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                # Parse the trusted Python literals
                parsedData = eval(line, {"array": np.array, "np": np})
                all_lines.append(parsedData)
        return all_lines
    allSubmissions = load_file("inputs.txt")
    allResults = load_file("outputs.txt")

    #Extract the functionNo inputs and outputs only and return those arrays only
    functionSubmissions = np.array([line[functionIndex] for line in allSubmissions])
    functionResults = np.array([line[functionIndex] for line in allResults])

    return functionSubmissions, functionResults

# %%
def combineInitialDataAndSubmissionsToDate(functionNo):
    assert(functionNo >= 1)
    assert(functionNo <= 8)

    initialInputs = np.load(f'initial_data/function_{functionNo}/initial_inputs.npy')
    initialOutputs = np.load(f'initial_data/function_{functionNo}/initial_outputs.npy')

    submissions, results = collatePreviousSubmissions(functionNo)

    combined_Inputs = np.vstack((initialInputs, submissions))
    combined_Outputs = np.concatenate((initialOutputs, results))

    assert combined_Inputs.shape[1] == initialInputs.shape[1]
    assert combined_Outputs.shape[0] == combined_Inputs.shape[0]

    return combined_Inputs, combined_Outputs

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.029245 0.037348] , Max:  [0.88388983 0.8798981 ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  7.710875114502849e-16
# Starting 2D Bayes Optimisation from 12 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0002653, 'max': 0.0002653, 'mean': 0.0002653, 'std': 0.0, 'q1': 0.0002653, 'median': 0.0002653, 'q3': 0.0002653}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.00026529578026409365, best=0.0002652958
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00020117, 'max': -9.167e-05, 'mean': -0.00020083, 'std': 7.2e-07, 'q1': -0.00020084, 'median': -0.00020084, 'q3': -0.00020084}
# 	Local search 1/32, x=[0.082577   0.40365318], val=1.6096515694515868e-05, best=0.0000160965
# 	Local search 2/32, x=[0.68334062 0.86121967], val=1.609651628127087e-05, best=0.0000160965
# 	Local search 9/32, x=[0.41057396 0.14743767], val=1.609651628164887e-05, best=0.0000160965
#
# 	Proposed next point to try: 0.410574-0.147438
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00287671, 'max': 0.00473921, 'mean': 0.0045678, 'std': 0.00051746, 'q1': 0.00470369, 'median': 0.00470893, 'q3': 0.00471157}
# 	Local search 1/32, x=[0.77416126 0.81144535], val=0.00473943164398447, best=0.0047394316
# 	Local search 2/32, x=[0.77415586 0.81130569], val=0.004739431779087926, best=0.0047394318
# 	Local search 5/32, x=[0.77422475 0.81136211], val=0.0047394317932154114, best=0.0047394318
# 	Local search 8/32, x=[0.77414997 0.81135405], val=0.004739431858400029, best=0.0047394319
# 	Local search 11/32, x=[0.77417592 0.8113601 ], val=0.0047394318614324615, best=0.0047394319
#
# 	Proposed next point to try: 0.774176-0.811360
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00218672, 'max': 0.00973398, 'mean': 0.00943817, 'std': 0.00096234, 'q1': 0.00968848, 'median': 0.00971811, 'q3': 0.00971945}
# 	Local search 1/32, x=[0.79350945 0.81771461], val=0.009734052090114149, best=0.0097340521
# 	Local search 2/32, x=[0.79373992 0.81777347], val=0.009734053149443258, best=0.0097340531
#
# 	Proposed next point to try: 0.793740-0.817773
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.01615934, 'max': 0.01963501, 'mean': 0.01963257, 'std': 2.134e-05, 'q1': 0.01963275, 'median': 0.01963275, 'q3': 0.01963275}
# 	Local search 1/32, x=[0.07986675 0.4015816 ], val=0.019635011139010658, best=0.0196350111
# 	Local search 2/32, x=[0.73035224 0.73618638], val=0.01963501113908798, best=0.0196350111
# 	Local search 7/32, x=[0.73372292 0.73117871], val=0.019635011139280577, best=0.0196350111
# 	Local search 13/32, x=[0.31036753 0.08100412], val=0.019635011139303733, best=0.0196350111
# 	Local search 21/32, x=[0.72976099 0.72999831], val=0.01963501113931243, best=0.0196350111
# 	Local search 26/32, x=[0.72776764 0.73295318], val=0.01963501113931454, best=0.0196350111
# 	Local search 27/32, x=[0.08493878 0.4013216 ], val=0.019635011139326274, best=0.0196350111
# 	Local search 29/32, x=[0.88560747 0.57948756], val=0.0196350111393292, best=0.0196350111
#
# 	Proposed next point to try: 0.885607-0.579488

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.14269907 0.02869772] , Max:  [0.87779099 0.970764  ]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
# Starting 2D Bayes Optimisation from 12 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.02342799, 'mean': 0.00238995, 'std': 0.00163815, 'q1': 0.00221568, 'median': 0.00236789, 'q3': 0.00238177}
# 	Local search 1/32, x=[0.68503415 0.91711803], val=0.023447337739884097, best=0.0234473377
# 	Local search 11/32, x=[0.68503407 0.91711816], val=0.023447337739886918, best=0.0234473377
# 	Local search 16/32, x=[0.68503411 0.91711812], val=0.02344733773990687, best=0.0234473377
#
# 	Proposed next point to try: 0.685034-0.917118
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00561008, 'mean': 0.00064063, 'std': 0.00043526, 'q1': 0.00059021, 'median': 0.0006439, 'q3': 0.00064757}
# 	Local search 1/32, x=[0.6747409  0.91439239], val=0.0056201965670463275, best=0.0056201966
# 	Local search 4/32, x=[0.67474589 0.91438073], val=0.005620196569972022, best=0.0056201966
# 	Local search 5/32, x=[0.67474382 0.91438604], val=0.005620196578111511, best=0.0056201966
#
# 	Proposed next point to try: 0.674744-0.914386
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.3e-07, 'max': 5.3e-07, 'mean': 5.3e-07, 'std': 0.0, 'q1': 5.3e-07, 'median': 5.3e-07, 'q3': 5.3e-07}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=5.347038506840557e-07, best=0.0000005347
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.22550044, 'max': 0.22550044, 'mean': 0.22550044, 'std': 0.0, 'q1': 0.22550044, 'median': 0.22550044, 'q3': 0.22550044}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=0.2255004444808317, best=0.2255004445
#
# 	Proposed next point to try: 0.431029-0.814368
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00589842, 'max': 1.35383497, 'mean': 1.23710374, 'std': 0.12535373, 'q1': 1.26489499, 'median': 1.27541851, 'q3': 1.27560716}
# 	Local search 1/32, x=[0.64405291 0.93229419], val=1.3539533290641352, best=1.3539533291
# 	Local search 2/32, x=[0.64405311 0.93228585], val=1.3539533292363144, best=1.3539533292
# 	Local search 7/32, x=[0.64405312 0.93228569], val=1.3539533292363384, best=1.3539533292
# 	Local search 8/32, x=[0.64405309 0.93228565], val=1.3539533292363737, best=1.3539533292
#
# 	Proposed next point to try: 0.644053-0.932286
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.43613174, 'max': 2.38598412, 'mean': 2.34344468, 'std': 0.05614, 'q1': 2.34766507, 'median': 2.34766507, 'q3': 2.34766507}
# 	Local search 1/32, x=[0.7173158  0.91554554], val=2.3859870552438873, best=2.3859870552
# 	Local search 2/32, x=[0.68938493 0.91386436], val=2.385987250218241, best=2.3859872502
# 	Local search 8/32, x=[0.6857926  0.91927224], val=2.3859872503365263, best=2.3859872503
#
# 	Proposed next point to try: 0.685793-0.919272
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 32 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.49126711, 'max': 4.49126711, 'mean': 4.49126711, 'std': 0.0, 'q1': 4.49126711, 'median': 4.49126711, 'q3': 4.49126711}
# 	Local search 1/32, x=[0.43102947 0.81436797], val=4.491267112850602, best=4.4912671129
#
# 	Proposed next point to try: 0.431029-0.814368

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
# Starting 3D Bayes Optimisation from 17 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.00619313, 'max': 0.00619313, 'mean': 0.00619313, 'std': 0.0, 'q1': 0.00619313, 'median': 0.00619313, 'q3': 0.00619313}
# 	Local search 1/48, x=[0.43102947 0.81436797 0.80641277], val=0.006193125042959033, best=0.0061931250
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0009493, 'mean': 0.00022417, 'std': 0.0002383, 'q1': 8.61e-06, 'median': 0.00013356, 'q3': 0.00039505}
# 	Local search 1/48, x=[0.75484382 1.         0.        ], val=0.0009677151710651179, best=0.0009677152
# 	Local search 2/48, x=[0.75395142 1.         0.        ], val=0.0009677154290852153, best=0.0009677154
# 	Local search 4/48, x=[0.75459775 1.         0.        ], val=0.0009677157772696246, best=0.0009677158
# 	Local search 6/48, x=[0.75450686 1.         0.        ], val=0.0009677158982544978, best=0.0009677159
# 	Local search 8/48, x=[0.75445972 1.         0.        ], val=0.0009677159391133627, best=0.0009677159
# 	Local search 14/48, x=[0.75434366 1.         0.        ], val=0.0009677159759797866, best=0.0009677160
#
# 	Proposed next point to try: 0.754344-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/48, x=[0.99457078 0.99317452 0.00396431], val=2.2170642577129195e-12, best=0.0000000000
#
# 	Proposed next point to try: 0.994571-0.993175-0.003964
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/48, x=[0.43102947 0.81436797 0.80641277], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.09810675, 'max': -0.09810675, 'mean': -0.09810675, 'std': 0.0, 'q1': -0.09810675, 'median': -0.09810675, 'q3': -0.09810675}
# 	Local search 1/48, x=[0.43102947 0.81436797 0.80641277], val=-0.09810674543680976, best=-0.0981067454
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.31518741, 'max': 0.31518741, 'mean': 0.31518741, 'std': 0.0, 'q1': 0.31518741, 'median': 0.31518741, 'q3': 0.31518741}
# 	Local search 1/48, x=[0.43102947 0.81436797 0.80641277], val=0.3151874133034512, best=0.3151874133
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.32382783, 'max': 0.82606078, 'mean': 0.59182281, 'std': 0.17859097, 'q1': 0.47817807, 'median': 0.63517489, 'q3': 0.73975105}
# 	Local search 1/48, x=[1. 1. 0.], val=0.8269417020674323, best=0.8269417021
#
# 	Proposed next point to try: 1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	49152 Sobol candidates, best 48 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.2526917, 'max': 1.75619653, 'mean': 1.29367783, 'std': 0.35602307, 'q1': 1.06609783, 'median': 1.38066032, 'q3': 1.58687897}
# 	Local search 1/48, x=[1.         0.         0.75641956], val=1.7573694576343968, best=1.7573694576
# 	Local search 39/48, x=[1.         0.         0.75641989], val=1.7573694576344, best=1.7573694576
#
# 	Proposed next point to try: 1.000000-0.000000-0.756420

# %%
f4_Inputs, f4_Outputs = combineInitialDataAndSubmissionsToDate(4)
findNextGuess('F4', f4_Inputs, f4_Outputs)
# Out:
# ********************
# F4  -  4 D
# ********************
#  Inputs -   Min: [0.03782483 0.0062504  0.04218635 0.08151656] , Max:  [0.98562189 0.91959232 0.93917791 0.99948256]
#  Output -   Min: -32.625660215962455 , Max (Best):  0.5348195285562913
# Starting 4D Bayes Optimisation from 32 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.07866262, 'mean': 2.854e-05, 'std': 0.00081092, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.40760214 0.41149216 0.3502027  0.43796986], val=0.09500983507370848, best=0.0950098351
# 	Local search 2/64, x=[0.40760274 0.41149197 0.35020207 0.43796948], val=0.09500983507663785, best=0.0950098351
# 	Local search 41/64, x=[0.40760289 0.41149192 0.3502018  0.43797002], val=0.09500983508657967, best=0.0950098351
#
# 	Proposed next point to try: 0.407603-0.411492-0.350202-0.437970
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.04445104, 'mean': 1.759e-05, 'std': 0.00047481, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.41579241 0.41245642 0.32125973 0.43884317], val=0.053974899704153874, best=0.0539748997
# 	Local search 3/64, x=[0.41579165 0.41245382 0.32125882 0.4388414 ], val=0.053974899766953584, best=0.0539748998
# 	Local search 5/64, x=[0.41579216 0.41245541 0.32125919 0.43884168], val=0.0539748997730626, best=0.0539748998
# 	Local search 16/64, x=[0.4157918  0.41245437 0.32125909 0.43884174], val=0.053974899780269016, best=0.0539748998
#
# 	Proposed next point to try: 0.415792-0.412454-0.321259-0.438842
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00648675, 'mean': 2.49e-06, 'std': 6.238e-05, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.42816829 0.41647364 0.27493715 0.43886778], val=0.0083333503248091, best=0.0083333503
# 	Local search 2/64, x=[0.42817012 0.41647269 0.27493798 0.43886761], val=0.008333350329785931, best=0.0083333503
# 	Local search 7/64, x=[0.42817072 0.41647427 0.27493853 0.43886864], val=0.008333350332027138, best=0.0083333503
# 	Local search 12/64, x=[0.42817032 0.41647404 0.27493772 0.4388687 ], val=0.008333350332522423, best=0.0083333503
# 	Local search 31/64, x=[0.42816978 0.41647349 0.27493847 0.4388684 ], val=0.008333350334384156, best=0.0083333503
#
# 	Proposed next point to try: 0.428170-0.416473-0.274938-0.438868
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.00633194 0.14635497 0.99585999 0.93483152], val=6.936678695456264e-15, best=0.0000000000
#
# 	Proposed next point to try: 0.006332-0.146355-0.995860-0.934832
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -40.94496914, 'max': 0.54218774, 'mean': -16.98270931, 'std': 6.85371222, 'q1': -21.72718183, 'median': -16.99821223, 'q3': -12.02784415}
# 	Local search 1/64, x=[0.40808568 0.41131458 0.36851827 0.43398124], val=0.6231699192077432, best=0.6231699192
# 	Local search 2/64, x=[0.40808551 0.41131406 0.3685182  0.43398092], val=0.6231699192133241, best=0.6231699192
# 	Local search 3/64, x=[0.40808547 0.41131419 0.36851903 0.43398137], val=0.6231699192218302, best=0.6231699192
# 	Local search 4/64, x=[0.40808534 0.4113142  0.36851904 0.43398119], val=0.6231699192256912, best=0.6231699192
# 	Local search 6/64, x=[0.40808527 0.41131412 0.36851864 0.43398097], val=0.6231699192272305, best=0.6231699192
# 	Local search 12/64, x=[0.40808524 0.41131427 0.36851868 0.43398106], val=0.6231699192282469, best=0.6231699192
# 	Local search 23/64, x=[0.4080854  0.41131405 0.36851865 0.43398118], val=0.6231699192302687, best=0.6231699192
# 	Local search 45/64, x=[0.40808553 0.41131427 0.36851874 0.43398116], val=0.6231699192308849, best=0.6231699192
#
# 	Proposed next point to try: 0.408086-0.411314-0.368519-0.433981
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -32.24630307, 'max': 4.12459028, 'mean': -8.76220908, 'std': 6.12378231, 'q1': -12.66269869, 'median': -8.14005426, 'q3': -4.23032911}
# 	Local search 1/64, x=[0. 0. 1. 1.], val=6.294820831394638, best=6.2948208314
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -31.27049373, 'max': 34.90889931, 'mean': -0.37394611, 'std': 7.98502339, 'q1': -5.65529808, 'median': -0.06568157, 'q3': 4.68880892}
# 	Local search 1/64, x=[0. 0. 1. 1.], val=41.1536117175352, best=41.1536117175
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -30.11038871, 'max': 96.78773053, 'mean': 16.40258147, 'std': 15.00488705, 'q1': 6.30590687, 'median': 14.1968551, 'q3': 24.3167979}
# 	Local search 1/64, x=[0. 0. 1. 1.], val=110.87118887525924, best=110.8711888753
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000

# %%
f5_Inputs, f5_Outputs = combineInitialDataAndSubmissionsToDate(5)
findNextGuess('F5', f5_Inputs, f5_Outputs)
# Out:
# ********************
# F5  -  4 D
# ********************
#  Inputs -   Min: [0.11987923 0.03819337 0.08894684 0.07288048] , Max:  [0.924901   0.86254031 0.979432   0.9576439 ]
#  Output -   Min: 0.1129397953712203 , Max (Best):  1959.0960427268283
# Starting 4D Bayes Optimisation from 22 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 22.06828864, 'mean': 0.00654793, 'std': 0.21381345, 'q1': 5.884e-05, 'median': 0.00031684, 'q3': 0.00066874}
# 	Local search 1/64, x=[0.32362818 0.83906804 1.         0.93323766], val=36.24416960176854, best=36.2441696018
# 	Local search 12/64, x=[0.32362817 0.83906803 1.         0.93323767], val=36.244169601768974, best=36.2441696018
# 	Local search 22/64, x=[0.32362817 0.83906803 1.         0.93323767], val=36.2441696017692, best=36.2441696018
# 	Local search 44/64, x=[0.32362817 0.83906804 1.         0.93323767], val=36.24416960176921, best=36.2441696018
#
# 	Proposed next point to try: 0.323628-0.839068-1.000000-0.933238
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 22.04356208, 'mean': 0.0065413, 'std': 0.2135897, 'q1': 5.876e-05, 'median': 0.00031646, 'q3': 0.00066796}
# 	Local search 1/64, x=[0.32365815 0.83906614 1.         0.93325525], val=36.19319716604403, best=36.1931971660
# 	Local search 3/64, x=[0.32365814 0.83906613 1.         0.93325526], val=36.1931971660444, best=36.1931971660
# 	Local search 4/64, x=[0.32365814 0.83906613 1.         0.93325526], val=36.19319716604447, best=36.1931971660
# 	Local search 7/64, x=[0.32365815 0.83906612 1.         0.93325525], val=36.193197166044484, best=36.1931971660
# 	Local search 29/64, x=[0.32365815 0.83906613 1.         0.93325526], val=36.1931971660445, best=36.1931971660
# 	Local search 32/64, x=[0.32365814 0.83906612 1.         0.93325526], val=36.19319716604474, best=36.1931971660
#
# 	Proposed next point to try: 0.323658-0.839066-1.000000-0.933255
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 21.94486967, 'mean': 0.00651484, 'std': 0.21269675, 'q1': 5.844e-05, 'median': 0.00031489, 'q3': 0.00066483}
# 	Local search 1/64, x=[0.32377792 0.83905852 1.         0.93332556], val=35.99009065795953, best=35.9900906580
# 	Local search 3/64, x=[0.32377792 0.83905852 1.         0.93332556], val=35.990090657959634, best=35.9900906580
# 	Local search 7/64, x=[0.32377793 0.83905852 1.         0.93332556], val=35.99009065795983, best=35.9900906580
# 	Local search 8/64, x=[0.32377792 0.83905851 1.         0.93332556], val=35.99009065795994, best=35.9900906580
# 	Local search 17/64, x=[0.32377792 0.83905852 1.         0.93332556], val=35.99009065795998, best=35.9900906580
#
# 	Proposed next point to try: 0.323778-0.839059-1.000000-0.933326
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 17.52902054, 'mean': 0.00533709, 'std': 0.17292075, 'q1': 4.466e-05, 'median': 0.00024764, 'q3': 0.00052833}
# 	Local search 1/64, x=[0.32929344 0.83871725 1.         0.93659402], val=27.389160597152696, best=27.3891605972
# 	Local search 2/64, x=[0.32929346 0.83871729 1.         0.93659402], val=27.38916059715818, best=27.3891605972
# 	Local search 6/64, x=[0.32929346 0.83871729 1.         0.93659401], val=27.38916059715855, best=27.3891605972
# 	Local search 23/64, x=[0.32929346 0.83871729 1.         0.936594  ], val=27.38916059715868, best=27.3891605972
# 	Local search 28/64, x=[0.32929346 0.83871729 1.         0.936594  ], val=27.389160597158785, best=27.3891605972
# 	Local search 55/64, x=[0.32929346 0.8387173  1.         0.93659401], val=27.389160597158856, best=27.3891605972
#
# 	Proposed next point to try: 0.329293-0.838717-1.000000-0.936594
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 13.68244688, 'max': 1891.08992207, 'mean': 232.51917005, 'std': 102.86340208, 'q1': 183.9432611, 'median': 228.36882689, 'q3': 259.70537472}
# 	Local search 1/64, x=[0.31030781 0.8399531  0.99500028 0.92554697], val=1983.3913410434122, best=1983.3913410434
# 	Local search 2/64, x=[0.31030785 0.83995312 0.99500026 0.92554703], val=1983.3913410437199, best=1983.3913410437
# 	Local search 5/64, x=[0.31030785 0.83995313 0.99500026 0.92554703], val=1983.3913410437217, best=1983.3913410437
#
# 	Proposed next point to try: 0.310308-0.839953-0.995000-0.925547
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 362.5958458, 'max': 2933.36365613, 'mean': 2107.32720382, 'std': 210.0315204, 'q1': 2035.79102849, 'median': 2168.55082957, 'q3': 2233.78981552}
# 	Local search 1/64, x=[0.41344206 0.84796227 0.98011053 1.        ], val=2936.102931420255, best=2936.1029314203
#
# 	Proposed next point to try: 0.413442-0.847962-0.980111-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 718.62992634, 'max': 4669.99230897, 'mean': 4020.39662603, 'std': 367.1785363, 'q1': 3920.19945099, 'median': 4146.99521157, 'q3': 4251.56341506}
# 	Local search 1/64, x=[0.4952539  0.88239341 0.95350284 1.        ], val=4671.573057382532, best=4671.5730573825
# 	Local search 2/64, x=[0.49524997 0.88240548 0.95350651 1.        ], val=4671.573057451864, best=4671.5730574519
# 	Local search 4/64, x=[0.49525005 0.88240556 0.95350667 1.        ], val=4671.573057451972, best=4671.5730574520
#
# 	Proposed next point to try: 0.495250-0.882406-0.953507-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65536 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 1430.6980874, 'max': 8554.58917041, 'mean': 7846.53547046, 'std': 698.15185168, 'q1': 7682.2813233, 'median': 8103.53114504, 'q3': 8287.25984963}
# 	Local search 1/64, x=[0.55556551 0.97085609 0.95234348 1.        ], val=8556.069618648322, best=8556.0696186483
# 	Local search 2/64, x=[0.55561896 0.97071744 0.95227938 1.        ], val=8556.069619822878, best=8556.0696198229
# 	Local search 4/64, x=[0.55562137 0.97071722 0.95227886 1.        ], val=8556.069619869619, best=8556.0696198696
# 	Local search 25/64, x=[0.55562066 0.97071825 0.95227846 1.        ], val=8556.069619870403, best=8556.0696198704
# 	Local search 40/64, x=[0.55561765 0.97072483 0.95228124 1.        ], val=8556.069619871161, best=8556.0696198712
# 	Local search 47/64, x=[0.55561874 0.97072237 0.95228034 1.        ], val=8556.069619871249, best=8556.0696198712
#
# 	Proposed next point to try: 0.555619-0.970722-0.952280-1.000000

# %%
f6_Inputs, f6_Outputs = combineInitialDataAndSubmissionsToDate(6)
findNextGuess('F6', f6_Inputs, f6_Outputs)
# Out:
# ********************
# F6  -  5 D
# ********************
#  Inputs -   Min: [0.02173531 0.11440374 0.0165229  0.04561319 0.003667  ] , Max:  [0.95773967 0.93187122 0.989507   0.96165559 0.89281919]
#  Output -   Min: -2.5711696316081234 , Max (Best):  -0.2776577094327388
# Starting 5D Bayes Optimisation from 22 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.09511297, 'mean': 0.00108659, 'std': 0.00574477, 'q1': 0.0, 'median': 1e-08, 'q3': 9.02e-06}
# 	Local search 1/80, x=[0.1939142  0.25207574 0.3907333  0.98175681 0.        ], val=0.10422708917086575, best=0.1042270892
# 	Local search 8/80, x=[0.19391596 0.25207747 0.39073282 0.98175488 0.        ], val=0.1042270891740603, best=0.1042270892
# 	Local search 10/80, x=[0.19391491 0.25207912 0.39073049 0.98175654 0.        ], val=0.10422708917811488, best=0.1042270892
# 	Local search 12/80, x=[0.19391467 0.25207958 0.39072915 0.9817558  0.        ], val=0.1042270891786219, best=0.1042270892
# 	Local search 21/80, x=[0.19391499 0.25207912 0.39072963 0.98175553 0.        ], val=0.1042270891787349, best=0.1042270892
# 	Local search 31/80, x=[0.19391479 0.25207914 0.39072966 0.9817558  0.        ], val=0.10422708917874147, best=0.1042270892
# 	Local search 36/80, x=[0.1939148  0.25207905 0.3907294  0.98175597 0.        ], val=0.10422708917876794, best=0.1042270892
#
# 	Proposed next point to try: 0.193915-0.252079-0.390729-0.981756-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.05883119, 'mean': 0.0004948, 'std': 0.00296508, 'q1': 0.0, 'median': 0.0, 'q3': 1.73e-06}
# 	Local search 1/80, x=[0.14990917 0.22587279 0.37228385 1.         0.        ], val=0.06497212979521842, best=0.0649721298
# 	Local search 2/80, x=[0.1498849  0.22587564 0.37227089 1.         0.        ], val=0.06497213003804075, best=0.0649721300
# 	Local search 23/80, x=[0.14988492 0.22587495 0.37227118 1.         0.        ], val=0.06497213003804339, best=0.0649721300
# 	Local search 32/80, x=[0.14988494 0.22587534 0.37227097 1.         0.        ], val=0.06497213003807223, best=0.0649721300
# 	Local search 72/80, x=[0.14988509 0.22587535 0.37227077 1.         0.        ], val=0.06497213003807312, best=0.0649721300
#
# 	Proposed next point to try: 0.149885-0.225875-0.372271-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0063989, 'mean': 1.556e-05, 'std': 0.00015786, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/80, x=[0.         0.         0.40508494 1.         0.        ], val=0.008116962293494075, best=0.0081169623
# 	Local search 4/80, x=[0.         0.         0.40508626 1.         0.        ], val=0.008116962293528845, best=0.0081169623
#
# 	Proposed next point to try: 0.000000-0.000000-0.405086-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/80, x=[0.43102947 0.81436797 0.80641277 0.05345668 0.29793923], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413-0.053457-0.297939
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.75992114, 'max': -0.22001861, 'mean': -1.42235508, 'std': 0.4322904, 'q1': -1.72667295, 'median': -1.45866802, 'q3': -1.13180286}
# 	Local search 1/80, x=[0.29641896 0.30020565 0.43433657 0.83793235 0.02408355], val=-0.21023811405836015, best=-0.2102381141
# 	Local search 2/80, x=[0.29641902 0.30020541 0.43433629 0.83793232 0.02408333], val=-0.21023811405825482, best=-0.2102381141
# 	Local search 16/80, x=[0.29641886 0.30020543 0.43433648 0.83793249 0.02408326], val=-0.2102381140582198, best=-0.2102381141
# 	Local search 24/80, x=[0.29641904 0.30020542 0.43433655 0.83793231 0.0240835 ], val=-0.21023811405820464, best=-0.2102381141
# 	Local search 40/80, x=[0.29641904 0.30020531 0.43433653 0.8379323  0.02408334], val=-0.21023811405818169, best=-0.2102381141
#
# 	Proposed next point to try: 0.296419-0.300205-0.434337-0.837932-0.024083
#
# Using UCB Acquisition function with Kappa = 5
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.32983953, 'max': 1.59372823, 'mean': -0.256556, 'std': 0.51586849, 'q1': -0.59821827, 'median': -0.28247485, 'q3': 0.07514352}
# 	Local search 1/80, x=[0. 0. 0. 1. 0.], val=1.792487418983199, best=1.7924874190
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.09836885, 'max': 4.01320278, 'mean': 0.93303496, 'std': 0.81293478, 'q1': 0.38101025, 'median': 0.85377444, 'q3': 1.45817306}
# 	Local search 1/80, x=[0. 1. 0. 1. 0.], val=4.404959238521995, best=4.4049592385
#
# 	Proposed next point to try: 0.000000-1.000000-0.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	81920 Sobol candidates, best 80 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.63542752, 'max': 9.37408327, 'mean': 3.31221675, 'std': 1.54967744, 'q1': 2.18715897, 'median': 3.13643484, 'q3': 4.33361784}
# 	Local search 1/80, x=[0. 0. 0. 0. 0.], val=10.14235389475029, best=10.1423538948
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-0.000000-0.000000

# %%
f7_Inputs, f7_Outputs = combineInitialDataAndSubmissionsToDate(7)
findNextGuess('F7', f7_Inputs, f7_Outputs)
# Out:
# ********************
# F7  -  6 D
# ********************
#  Inputs -   Min: [0.011684   0.01181284 0.00363456 0.07365919 0.01494418 0.05109986] , Max:  [0.94245084 0.9246939  0.92457051 0.96101714 0.9986547  0.95101392]
#  Output -   Min: 0.0027014650245082332 , Max (Best):  1.627092775388822
# Starting 6D Bayes Optimisation from 32 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.04037694, 'mean': 1.015e-05, 'std': 0.0002196, 'q1': 4e-08, 'median': 3.2e-07, 'q3': 1.08e-06}
# 	Local search 1/96, x=[0.00768599 0.40740364 0.30417016 0.13670675 0.32957529 0.73775517], val=0.0538679814358783, best=0.0538679814
# 	Local search 3/96, x=[0.0076867  0.40740356 0.3041702  0.13670677 0.32957782 0.73775392], val=0.053867981459006176, best=0.0538679815
# 	Local search 4/96, x=[0.00768702 0.40740287 0.30416937 0.13670626 0.32957687 0.73775489], val=0.05386798145958714, best=0.0538679815
# 	Local search 5/96, x=[0.00768764 0.40740417 0.30416969 0.13670665 0.32957699 0.73775465], val=0.053867981473896015, best=0.0538679815
# 	Local search 7/96, x=[0.0076876  0.40740422 0.30416964 0.13670669 0.32957699 0.73775463], val=0.05386798147390634, best=0.0538679815
# 	Local search 41/96, x=[0.00768766 0.4074042  0.30416964 0.13670668 0.32957696 0.73775459], val=0.05386798147391579, best=0.0538679815
# 	Local search 85/96, x=[0.00768767 0.40740421 0.30416964 0.13670667 0.32957696 0.73775461], val=0.053867981473919455, best=0.0538679815
#
# 	Proposed next point to try: 0.007688-0.407404-0.304170-0.136707-0.329577-0.737755
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00891485, 'mean': 3.1e-06, 'std': 6.311e-05, 'q1': 1e-08, 'median': 7e-08, 'q3': 2.5e-07}
# 	Local search 1/96, x=[0.         0.37812604 0.32212026 0.11482293 0.32181973 0.77804048], val=0.010691963154119244, best=0.0106919632
# 	Local search 10/96, x=[0.         0.37812431 0.32212176 0.11482143 0.32181486 0.77803249], val=0.010691963164513325, best=0.0106919632
# 	Local search 24/96, x=[0.         0.37812447 0.32211764 0.1148212  0.32181669 0.77803439], val=0.010691963169990704, best=0.0106919632
#
# 	Proposed next point to try: 0.000000-0.378124-0.322118-0.114821-0.321817-0.778034
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 1.112e-05, 'mean': 1e-08, 'std': 1.6e-07, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.04523059 0.35261972 0.31158743 0.03051796 0.25187509 0.8350843 ], val=1.112593978784768e-05, best=0.0000111259
# 	Local search 2/96, x=[0.         0.31686258 0.30848664 0.10695596 0.30883905 0.89374918], val=1.3127960373337887e-05, best=0.0000131280
# 	Local search 4/96, x=[0.02420752 0.29647779 0.35075922 0.12130259 0.32285193 0.87782887], val=1.3131060327565582e-05, best=0.0000131311
# 	Local search 8/96, x=[0.         0.3459862  0.35984577 0.09701413 0.32251629 0.89550954], val=1.3234838790848535e-05, best=0.0000132348
# 	Local search 9/96, x=[0.         0.31609748 0.3440276  0.11251097 0.31799522 0.88859331], val=1.3240757467111795e-05, best=0.0000132408
# 	Local search 55/96, x=[0.         0.33405842 0.354666   0.10907744 0.31757607 0.89455099], val=1.3258816217239454e-05, best=0.0000132588
#
# 	Proposed next point to try: 0.000000-0.334058-0.354666-0.109077-0.317576-0.894551
#
# Using Expected Improvement Acquisition function with xi = 20
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.43102947 0.81436797 0.80641277 0.05345668 0.29793923 0.839878  ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.431029-0.814368-0.806413-0.053457-0.297939-0.839878
#
# Using UCB Acquisition function with Kappa = 0.1
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.00068989, 'max': 1.63544635, 'mean': 0.28635461, 'std': 0.12883922, 'q1': 0.20873012, 'median': 0.26473149, 'q3': 0.3272103}
# 	Local search 1/96, x=[0.01175189 0.41263554 0.30096883 0.1419544  0.33365266 0.73574805], val=1.6811493545064586, best=1.6811493545
# 	Local search 2/96, x=[0.01175214 0.41263557 0.30096862 0.14195442 0.33365244 0.73574822], val=1.6811493545083176, best=1.6811493545
# 	Local search 8/96, x=[0.01175212 0.41263555 0.30096862 0.14195443 0.33365242 0.73574824], val=1.6811493545083198, best=1.6811493545
# 	Local search 12/96, x=[0.01175211 0.41263555 0.30096864 0.14195445 0.33365247 0.73574824], val=1.6811493545083234, best=1.6811493545
# 	Local search 23/96, x=[0.01175212 0.41263556 0.30096862 0.14195444 0.33365246 0.73574825], val=1.6811493545083347, best=1.6811493545
#
# 	Proposed next point to try: 0.011752-0.412636-0.300969-0.141954-0.333652-0.735748
#
# Using UCB Acquisition function with Kappa = 5
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.42271741, 'max': 2.47577832, 'mean': 1.78259427, 'std': 0.18425371, 'q1': 1.68540906, 'median': 1.80992996, 'q3': 1.8960863}
# 	Local search 1/96, x=[0.         0.30382689 0.3840486  0.1151815  0.31700372 0.93476275], val=2.4845507207200415, best=2.4845507207
# 	Local search 2/96, x=[0.         0.30377129 0.38406673 0.11525814 0.31699891 0.9347343 ], val=2.4845507219047436, best=2.4845507219
# 	Local search 3/96, x=[0.         0.30381985 0.38417509 0.11525309 0.31701989 0.93471493], val=2.4845507238299627, best=2.4845507238
# 	Local search 4/96, x=[0.         0.30383321 0.38417089 0.11524511 0.31701772 0.9347245 ], val=2.4845507239130793, best=2.4845507239
# 	Local search 6/96, x=[0.         0.30382547 0.38416694 0.11524406 0.31702001 0.9347232 ], val=2.484550723953165, best=2.4845507240
# 	Local search 13/96, x=[0.         0.30382585 0.38416681 0.11524356 0.3170198  0.93472367], val=2.4845507239544187, best=2.4845507240
# 	Local search 18/96, x=[0.         0.30382722 0.3841658  0.11524195 0.31701994 0.93472454], val=2.484550723955633, best=2.4845507240
#
# 	Proposed next point to try: 0.000000-0.303827-0.384166-0.115242-0.317020-0.934725
#
# Using UCB Acquisition function with Kappa = 10
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.83515749, 'max': 3.92178867, 'mean': 3.30936953, 'std': 0.29044164, 'q1': 3.16811917, 'median': 3.37538949, 'q3': 3.51486418}
# 	Local search 1/96, x=[5.66488575e-04 1.32635816e-01 3.47022855e-01 1.25174194e-01
#  2.82554310e-01 1.00000000e+00], val=3.930170636619179, best=3.9301706366
# 	Local search 2/96, x=[0.         0.13423226 0.35074065 0.12466509 0.28410883 1.        ], val=3.930174907727446, best=3.9301749077
# 	Local search 4/96, x=[0.         0.30173728 0.54701903 0.04238965 0.32948362 1.        ], val=3.9304455131904836, best=3.9304455132
# 	Local search 11/96, x=[0.         0.30171    0.54701343 0.04240595 0.32949324 1.        ], val=3.9304455132226916, best=3.9304455132
# 	Local search 13/96, x=[0.         0.30172512 0.54701857 0.04240093 0.3294901  1.        ], val=3.930445513226142, best=3.9304455132
# 	Local search 32/96, x=[0.         0.3017197  0.54701683 0.04240014 0.32949088 1.        ], val=3.9304455132320752, best=3.9304455132
#
# 	Proposed next point to try: 0.000000-0.301720-0.547017-0.042400-0.329491-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	98304 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 1.66003762, 'max': 7.143289, 'mean': 6.36291975, 'std': 0.53316972, 'q1': 6.1159579, 'median': 6.49749618, 'q3': 6.75113568}
# 	Local search 1/96, x=[0.         0.08703846 0.03540116 0.         0.15045767 1.        ], val=7.1571561590601185, best=7.1571561591
# 	Local search 2/96, x=[0.         0.08703392 0.0353919  0.         0.1504595  1.        ], val=7.15715615916539, best=7.1571561592
# 	Local search 5/96, x=[0.         0.08702755 0.03539694 0.         0.15046787 1.        ], val=7.157156159175111, best=7.1571561592
# 	Local search 47/96, x=[0.         0.08702603 0.03539892 0.         0.15046585 1.        ], val=7.157156159175801, best=7.1571561592
# 	Local search 62/96, x=[0.         0.08702772 0.03539777 0.         0.15046603 1.        ], val=7.157156159176147, best=7.1571561592
#
# 	Proposed next point to try: 0.000000-0.087028-0.035398-0.000000-0.150466-1.000000

# %%
f8_Inputs, f8_Outputs = combineInitialDataAndSubmissionsToDate(8)
findNextGuess('F8', f8_Inputs, f8_Outputs)
# Out:
# ********************
# F8  -  8 D
# ********************
#  Inputs -   Min: [0.00907698 0.0034195  0.02292868 0.         0.00964888 0.02211341
#  0.03590888 0.04195607] , Max:  [0.98594539 0.97397979 0.9988855  0.90298577 0.986902   0.99024381
#  0.99291449 0.9887551 ]
#  Output -   Min: 5.5921933895401965 , Max (Best):  9.838102201175
# Starting 8D Bayes Optimisation from 42 known samples
#
# Using Expected Improvement Acquisition function with xi = 0
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.18968206, 'mean': 0.00118948, 'std': 0.00779029, 'q1': 0.0, 'median': 0.0, 'q3': 1e-08}
# 	Local search 1/128, x=[0.02435693 0.29448964 0.02852134 0.25498941 0.62167214 0.56570594
#  0.12959998 0.52210154], val=0.22975902676624735, best=0.2297590268
# 	Local search 7/128, x=[0.02435792 0.29448922 0.02852229 0.254998   0.62166198 0.56570987
#  0.12960255 0.52209477], val=0.2297590267750508, best=0.2297590268
# 	Local search 10/128, x=[0.02435422 0.29448538 0.02852125 0.25498427 0.62166179 0.56570441
#  0.12959328 0.52210238], val=0.22975902678003998, best=0.2297590268
# 	Local search 42/128, x=[0.0243551  0.29448473 0.02852105 0.25499463 0.62166149 0.56571789
#  0.12959769 0.52210381], val=0.2297590267904765, best=0.2297590268
# 	Local search 59/128, x=[0.02435971 0.29449308 0.0285202  0.25499301 0.62166139 0.56570042
#  0.12960072 0.52210372], val=0.22975902680373936, best=0.2297590268
# 	Local search 63/128, x=[0.0243561  0.29449149 0.02852295 0.25498927 0.62165708 0.56570777
#  0.12959784 0.5221105 ], val=0.22975902682287314, best=0.2297590268
# 	Local search 116/128, x=[0.02435499 0.29449186 0.02851882 0.25499364 0.62166189 0.56570742
#  0.12959682 0.52209534], val=0.2297590268363834, best=0.2297590268
#
# 	Proposed next point to try: 0.024355-0.294492-0.028519-0.254994-0.621662-0.565707-0.129597-0.522095
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.11914675, 'mean': 0.00055987, 'std': 0.00410284, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.         0.31578661 0.         0.27842214 0.61052813 0.60948917
#  0.09217261 0.48971603], val=0.14881777109643898, best=0.1488177711
# 	Local search 2/128, x=[0.         0.31579959 0.         0.27844993 0.61053214 0.60949062
#  0.09217428 0.48968211], val=0.14881777148351472, best=0.1488177715
# 	Local search 8/128, x=[0.         0.31578927 0.         0.27843774 0.61051724 0.60950316
#  0.09216196 0.48967927], val=0.1488177715042153, best=0.1488177715
# 	Local search 9/128, x=[0.         0.31579096 0.         0.2784534  0.61053175 0.60950781
#  0.09217093 0.48967869], val=0.1488177715744105, best=0.1488177716
# 	Local search 22/128, x=[0.         0.31579339 0.         0.27843832 0.61052442 0.60950437
#  0.09217339 0.48969249], val=0.14881777160050852, best=0.1488177716
# 	Local search 31/128, x=[0.         0.31578976 0.         0.27844582 0.61052669 0.60949751
#  0.09217284 0.48968584], val=0.14881777160551307, best=0.1488177716
# 	Local search 48/128, x=[0.         0.31579572 0.         0.27844242 0.61053303 0.60951187
#  0.09216815 0.48967743], val=0.14881777161893792, best=0.1488177716
# 	Local search 86/128, x=[0.         0.31579571 0.         0.27844386 0.61053408 0.60950921
#  0.09216731 0.48968369], val=0.14881777163321452, best=0.1488177716
# 	Local search 91/128, x=[0.         0.31579509 0.         0.27844034 0.61052725 0.60950556
#  0.09217042 0.48968382], val=0.1488177716441307, best=0.1488177716
#
# 	Proposed next point to try: 0.000000-0.315795-0.000000-0.278440-0.610527-0.609506-0.092170-0.489684
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01223163, 'mean': 1.578e-05, 'std': 0.00019415, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.        0.        0.        0.4911408 1.        1.        0.
#  0.       ], val=0.030249706420253736, best=0.0302497064
# 	Local search 2/128, x=[0.         0.         0.         0.49134252 1.         1.
#  0.         0.        ], val=0.03024970721746774, best=0.0302497072
# 	Local search 85/128, x=[0.         0.         0.         0.49134078 1.         1.
#  0.         0.        ], val=0.03024970721757736, best=0.0302497072
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-0.491341-1.000000-1.000000-0.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.19949833 0.00288211 0.2253193  0.95836484 0.98913612 0.99347802
#  0.14137753 0.02728993], val=1.1070724851697313e-275, best=0.0000000000
#
# 	Proposed next point to try: 0.199498-0.002882-0.225319-0.958365-0.989136-0.993478-0.141378-0.027290
#
# Using UCB Acquisition function with Kappa = 0.1
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.30225785, 'max': 10.02286168, 'mean': 7.98442712, 'std': 0.95922061, 'q1': 7.33136247, 'median': 8.06337202, 'q3': 8.71527834}
# 	Local search 1/128, x=[0.03106882 0.28712369 0.03784201 0.24742827 0.6262513  0.55413031
#  0.13934189 0.53099523], val=10.076971645827383, best=10.0769716458
# 	Local search 2/128, x=[0.03105399 0.2871239  0.03783933 0.24744584 0.62627731 0.55419065
#  0.13933147 0.53100769], val=10.076971647624202, best=10.0769716476
# 	Local search 18/128, x=[0.03105658 0.28712119 0.03784439 0.24743327 0.62627751 0.55418663
#  0.13933525 0.53102209], val=10.076971647738016, best=10.0769716477
# 	Local search 24/128, x=[0.03105668 0.28712404 0.03784044 0.24743297 0.6262791  0.55418261
#  0.13933336 0.53101653], val=10.076971647838787, best=10.0769716478
#
# 	Proposed next point to try: 0.031057-0.287124-0.037840-0.247433-0.626279-0.554183-0.139333-0.531017
#
# Using UCB Acquisition function with Kappa = 5
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.69785848, 'max': 12.05550831, 'mean': 9.05226874, 'std': 1.00134378, 'q1': 8.34463294, 'median': 9.09969783, 'q3': 9.80159725}
# 	Local search 1/128, x=[0. 0. 0. 1. 1. 1. 0. 0.], val=13.013935159192906, best=13.0139351592
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-1.000000-1.000000-1.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.31881999, 'max': 14.98588174, 'mean': 10.14190304, 'std': 1.16837948, 'q1': 9.30118133, 'median': 10.13158277, 'q3': 10.95975849}
# 	Local search 1/128, x=[0. 0. 0. 1. 1. 1. 0. 0.], val=16.71914722960389, best=16.7191472296
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-1.000000-1.000000-1.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	131072 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 7.27658578, 'max': 20.84662859, 'mean': 12.32117166, 'std': 1.71255183, 'q1': 11.06989211, 'median': 12.1850387, 'q3': 13.4121507}
# 	Local search 1/128, x=[0. 0. 0. 1. 1. 1. 0. 0.], val=24.129571370425865, best=24.1295713704
# 	Local search 2/128, x=[0. 1. 0. 1. 1. 1. 0. 1.], val=24.33580490821125, best=24.3358049082
#
# 	Proposed next point to try: 0.000000-1.000000-0.000000-1.000000-1.000000-1.000000-0.000000-1.000000

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')

for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1:
# 0: 0.431029-0.814368
# 1: 0.431029-0.814368
# 2: 0.431029-0.814368
# 3: 0.431029-0.814368
# 4: 0.410574-0.147438
# 5: 0.774176-0.811360
# 6: 0.793740-0.817773
# 7: 0.885607-0.579488
#
# F2:
# 0: 0.685034-0.917118
# 1: 0.674744-0.914386
# 2: 0.431029-0.814368
# 3: 0.431029-0.814368
# 4: 0.431029-0.814368
# 5: 0.644053-0.932286
# 6: 0.685793-0.919272
# 7: 0.431029-0.814368
#
# F3:
# 0: 0.431029-0.814368-0.806413
# 1: 0.754344-1.000000-0.000000
# 2: 0.994571-0.993175-0.003964
# 3: 0.431029-0.814368-0.806413
# 4: 0.431029-0.814368-0.806413
# 5: 0.431029-0.814368-0.806413
# 6: 1.000000-1.000000-0.000000
# 7: 1.000000-0.000000-0.756420
#
# F4:
# 0: 0.407603-0.411492-0.350202-0.437970
# 1: 0.415792-0.412454-0.321259-0.438842
# 2: 0.428170-0.416473-0.274938-0.438868
# 3: 0.006332-0.146355-0.995860-0.934832
# 4: 0.408086-0.411314-0.368519-0.433981
# 5: 0.000000-0.000000-1.000000-1.000000
# 6: 0.000000-0.000000-1.000000-1.000000
# 7: 0.000000-0.000000-1.000000-1.000000
#
# F5:
# 0: 0.323628-0.839068-1.000000-0.933238
# 1: 0.323658-0.839066-1.000000-0.933255
# 2: 0.323778-0.839059-1.000000-0.933326
# 3: 0.329293-0.838717-1.000000-0.936594
# 4: 0.310308-0.839953-0.995000-0.925547
# 5: 0.413442-0.847962-0.980111-1.000000
# 6: 0.495250-0.882406-0.953507-1.000000
# 7: 0.555619-0.970722-0.952280-1.000000
#
# F6:
# 0: 0.193915-0.252079-0.390729-0.981756-0.000000
# 1: 0.149885-0.225875-0.372271-1.000000-0.000000
# 2: 0.000000-0.000000-0.405086-1.000000-0.000000
# 3: 0.431029-0.814368-0.806413-0.053457-0.297939
# 4: 0.296419-0.300205-0.434337-0.837932-0.024083
# 5: 0.000000-0.000000-0.000000-1.000000-0.000000
# 6: 0.000000-1.000000-0.000000-1.000000-0.000000
# 7: 0.000000-0.000000-0.000000-0.000000-0.000000
#
# F7:
# 0: 0.007688-0.407404-0.304170-0.136707-0.329577-0.737755
# 1: 0.000000-0.378124-0.322118-0.114821-0.321817-0.778034
# 2: 0.000000-0.334058-0.354666-0.109077-0.317576-0.894551
# 3: 0.431029-0.814368-0.806413-0.053457-0.297939-0.839878
# 4: 0.011752-0.412636-0.300969-0.141954-0.333652-0.735748
# 5: 0.000000-0.303827-0.384166-0.115242-0.317020-0.934725
# 6: 0.000000-0.301720-0.547017-0.042400-0.329491-1.000000
# 7: 0.000000-0.087028-0.035398-0.000000-0.150466-1.000000
#
# F8:
# 0: 0.024355-0.294492-0.028519-0.254994-0.621662-0.565707-0.129597-0.522095
# 1: 0.000000-0.315795-0.000000-0.278440-0.610527-0.609506-0.092170-0.489684
# 2: 0.000000-0.000000-0.000000-0.491341-1.000000-1.000000-0.000000-0.000000
# 3: 0.199498-0.002882-0.225319-0.958365-0.989136-0.993478-0.141378-0.027290
# 4: 0.031057-0.287124-0.037840-0.247433-0.626279-0.554183-0.139333-0.531017
# 5: 0.000000-0.000000-0.000000-1.000000-1.000000-1.000000-0.000000-0.000000
# 6: 0.000000-0.000000-0.000000-1.000000-1.000000-1.000000-0.000000-0.000000
# 7: 0.000000-1.000000-0.000000-1.000000-1.000000-1.000000-0.000000-1.000000
