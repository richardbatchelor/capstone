# %% [markdown]
# ## Setup

# %%
import os

from numpy import ndarray
from sklearn.gaussian_process.kernels import Matern, RationalQuadratic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats._qmc import Sobol
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats import norm
from scipy.optimize import minimize
import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma

#
def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }


from sklearn.model_selection import GridSearchCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

def findTunedGaussianProcessRegressor(X_samples, y_samples):
    #Use grid search to work out which GP hyper params are best to fit to this problem
    param_grid = {
        'kernel': [RBF(length_scale=0.5), RBF(length_scale=1.0), RBF(length_scale=2.0),
                   Matern(nu=0.5, length_scale=1.0), Matern(nu=1.5,length_scale=1.0 ), Matern(nu=2.5, length_scale=1.0),
                   Matern(nu=0.5, length_scale=2.0), Matern(nu=1.5,length_scale=2.0 ), Matern(nu=2.5, length_scale=2.0),
                   RationalQuadratic(alpha=1.0, length_scale=1.0), RationalQuadratic(alpha=1.0, length_scale=2.0)],
        'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
        'n_restarts_optimizer': [5, 10, 20]
    }
    gp = GaussianProcessRegressor()
    grid_search = GridSearchCV(gp, param_grid, cv=3)
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_



def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims
    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]


    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )

    gp.fit(X_samples, y_samples)


    # -----------------------------
    # 2. Acquisition function
    # -----------------------------
    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        return val

    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{len(X_candidates)} Sobol candidates, best {len(X_start)} to be minimised in local search")
    print(f"\tInitial acquisition function stats {summary_stats(acq_vals)}")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition
    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun
        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
def sortByLargestOutputDescending(arr):
    return  arr[np.argsort(arr[:, 2])[::-1]]

def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')



def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)


    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem is ${bestParams}")
    gpKernels[functionName] = bestParams


    functionProposedPoints = {}
    count = -1
    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
def collatePreviousSubmissions(functionNo):
    functionIndex = functionNo -1
    assert(functionIndex >= 0)
    assert(functionIndex <= 7)

    #Search for subfolders and find last submission week and results
    week_folders = [d for d in os.listdir("submission_results") if d.startswith("week") ]
    week_folders.sort(key=lambda w: int(w.replace("week", "")))
    last_week = week_folders[-1]
    week_dir = os.path.join("submission_results", last_week)


    def load_file(file_name):
        file_path = os.path.join(week_dir, file_name)
        all_lines = []
        with open(file_path, "r") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                # Parse the trusted Python literals
                parsedData = eval(line, {"array": np.array, "np": np})
                all_lines.append(parsedData)
        return all_lines
    allSubmissions = load_file("inputs.txt")
    allResults = load_file("outputs.txt")

    #Extract the functionNo inputs and outputs only and return those arrays only
    functionSubmissions = np.array([line[functionIndex] for line in allSubmissions])
    functionResults = np.array([line[functionIndex] for line in allResults])

    return functionSubmissions, functionResults

# %%
def combineInitialDataAndSubmissionsToDate(functionNo):
    assert(functionNo >= 1)
    assert(functionNo <= 8)

    initialInputs = np.load(f'initial_data/function_{functionNo}/initial_inputs.npy')
    initialOutputs = np.load(f'initial_data/function_{functionNo}/initial_outputs.npy')

    submissions, results = collatePreviousSubmissions(functionNo)

    combined_Inputs = np.vstack((initialInputs, submissions))
    combined_Outputs = np.concatenate((initialOutputs, results))

    assert combined_Inputs.shape[1] == initialInputs.shape[1]
    assert combined_Outputs.shape[0] == combined_Inputs.shape[0]

    return combined_Inputs, combined_Outputs

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.029245 0.037348] , Max:  [0.88388983 0.8798981 ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  7.710875114502849e-16
#
# [[ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 13 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 1e-08, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 10}
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0014906, 'mean': 0.00049563, 'std': 0.00030864, 'q1': 0.00028351, 'median': 0.00043709, 'q3': 0.00069051}
# 	Local search 1/64, x=[1. 1.], val=0.0014974344111283377, best=0.0014974344
#
# 	Proposed next point to try: 1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.00504014 0.99874309], val=2.66277e-319, best=0.0000000000
#
# 	Proposed next point to try: 0.005040-0.998743
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00350205, 'max': 0.00117211, 'mean': -0.00010249, 'std': 0.00071044, 'q1': -0.00035938, 'median': 6.991e-05, 'q3': 0.0003333}
# 	Local search 1/64, x=[1. 1.], val=0.001176543777923162, best=0.0011765438
#
# 	Proposed next point to try: 1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00218428, 'max': 0.01363341, 'mean': 0.00654917, 'std': 0.00212663, 'q1': 0.00527471, 'median': 0.00645747, 'q3': 0.00756288}
# 	Local search 1/64, x=[0. 1.], val=0.013709624023826444, best=0.0137096240
#
# 	Proposed next point to try: 0.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00089895, 'max': 0.02667071, 'mean': 0.01333659, 'std': 0.00390059, 'q1': 0.01094266, 'median': 0.01326376, 'q3': 0.01499704}
# 	Local search 1/64, x=[0. 1.], val=0.026821597213955772, best=0.0268215972
#
# 	Proposed next point to try: 0.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.00167172, 'max': 0.05274531, 'mean': 0.02691142, 'std': 0.00752163, 'q1': 0.02220861, 'median': 0.02687929, 'q3': 0.03050559}
# 	Local search 1/64, x=[0. 1.], val=0.05304554359421443, best=0.0530455436
#
# 	Proposed next point to try: 0.000000-1.000000

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.14269907 0.02869772] , Max:  [0.87779099 0.970764  ]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
#
# [[ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 13 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': Matern(length_scale=2, nu=0.5), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.05466023, 'mean': 0.00523536, 'std': 0.01031632, 'q1': 4.521e-05, 'median': 0.00057625, 'q3': 0.00425715}
# 	Local search 1/64, x=[1. 0.], val=0.05473070622191181, best=0.0547307062
#
# 	Proposed next point to try: 1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03066675, 'mean': 0.00208041, 'std': 0.00487656, 'q1': 2.91e-06, 'median': 8.78e-05, 'q3': 0.00119602}
# 	Local search 1/64, x=[1. 0.], val=0.030736503871352863, best=0.0307365039
#
# 	Proposed next point to try: 1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0012865, 'mean': 2.383e-05, 'std': 0.00010026, 'q1': 0.0, 'median': 0.0, 'q3': 1e-06}
# 	Local search 1/64, x=[1. 0.], val=0.001298398528511097, best=0.0012983985
#
# 	Proposed next point to try: 1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.04159213, 'max': 0.49230578, 'mean': 0.22662825, 'std': 0.15481094, 'q1': 0.10770283, 'median': 0.21419139, 'q3': 0.35446681}
# 	Local search 1/64, x=[0.72181292 0.12187483], val=0.49230691230379464, best=0.4923069123
# 	Local search 21/64, x=[0.72181354 0.12187467], val=0.4923069123039811, best=0.4923069123
#
# 	Proposed next point to try: 0.721814-0.121875
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.41341064, 'max': 1.92377456, 'mean': 1.10204442, 'std': 0.2888458, 'q1': 0.8878489, 'median': 1.06638249, 'q3': 1.29846203}
# 	Local search 1/64, x=[1. 0.], val=1.9259179357164482, best=1.9259179357
#
# 	Proposed next point to try: 1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.83769581, 'max': 3.41437186, 'mean': 1.99532625, 'std': 0.51197648, 'q1': 1.60863501, 'median': 1.92644011, 'q3': 2.33765848}
# 	Local search 1/64, x=[0. 1.], val=3.427082458102779, best=3.4270824581
#
# 	Proposed next point to try: 0.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 1.65440847, 'max': 6.74288738, 'mean': 3.78188983, 'std': 0.98848309, 'q1': 3.03486819, 'median': 3.64652809, 'q3': 4.43400639}
# 	Local search 1/64, x=[0. 1.], val=6.769288943283989, best=6.7692889433
#
# 	Proposed next point to try: 0.000000-1.000000

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.151837  0.439991  0.990882 -0.398926]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.600097  0.725136  0.066089 -0.036378]]
#
# Starting 3D Bayes Optimisation from 18 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': Matern(length_scale=2, nu=0.5), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.06e-06, 'max': 0.00052612, 'mean': 7.298e-05, 'std': 6.453e-05, 'q1': 2.433e-05, 'median': 5.357e-05, 'q3': 0.00010172}
# 	Local search 1/96, x=[1.00000000e+00 1.00000000e+00 8.06338464e-19], val=0.0005668599579215857, best=0.0005668600
#
# 	Proposed next point to try: 1.000000e+00-1.000000e+00-8.063385e-19
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 9e-08, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.99542833 0.99922136 0.03765249], val=9.302161153295794e-08, best=0.0000000930
#
# 	Proposed next point to try: 0.995428-0.999221-0.037652
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[9.89468763e-01 1.06479041e-04 2.75666872e-02], val=3.6512649311715554e-45, best=0.0000000000
#
# 	Proposed next point to try: 9.894688e-01-1.064790e-04-2.756669e-02
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.12582588, 'max': -0.08898165, 'mean': -0.10170094, 'std': 0.00768985, 'q1': -0.10673703, 'median': -0.10033609, 'q3': -0.09570176}
# 	Local search 1/96, x=[0.91126791 0.97172944 0.        ], val=-0.0889691009676611, best=-0.0889691010
# 	Local search 2/96, x=[0.90899128 0.97046374 0.        ], val=-0.08896909737307007, best=-0.0889690974
# 	Local search 4/96, x=[0.90943405 0.97087643 0.        ], val=-0.0889690972945273, best=-0.0889690973
# 	Local search 7/96, x=[0.90917617 0.97058891 0.        ], val=-0.08896909726010785, best=-0.0889690973
# 	Local search 12/96, x=[0.90933329 0.97072692 0.        ], val=-0.08896909722131584, best=-0.0889690972
# 	Local search 34/96, x=[0.90936047 0.9707227  0.        ], val=-0.08896909721496984, best=-0.0889690972
#
# 	Proposed next point to try: 0.909360-0.970723-0.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0401746, 'max': 0.11427382, 'mean': 0.06633189, 'std': 0.0146279, 'q1': 0.05447526, 'median': 0.06542275, 'q3': 0.07703523}
# 	Local search 1/96, x=[1. 1. 0.], val=0.11677448801326767, best=0.1167744880
#
# 	Proposed next point to try: 1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.18337742, 'max': 0.32770308, 'mean': 0.23779412, 'std': 0.02755988, 'q1': 0.21648177, 'median': 0.23585632, 'q3': 0.25753278}
# 	Local search 1/96, x=[1. 0. 0.], val=0.33206383947228946, best=0.3320638395
#
# 	Proposed next point to try: 1.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.46752245, 'max': 0.76012208, 'mean': 0.58071804, 'std': 0.0550012, 'q1': 0.53927062, 'median': 0.57784543, 'q3': 0.61949219}
# 	Local search 1/96, x=[1. 0. 1.], val=0.7709234905669403, best=0.7709234906
#
# 	Proposed next point to try: 1.000000-0.000000-1.000000

# %%
f4_Inputs, f4_Outputs = combineInitialDataAndSubmissionsToDate(4)
findNextGuess('F4', f4_Inputs, f4_Outputs)
# Out:
# ********************
# F4  -  4 D
# ********************
#  Inputs -   Min: [0.006332   0.0062504  0.04218635 0.08151656] , Max:  [0.98562189 0.91959232 0.99586    0.99948256]
#  Output -   Min: -34.63184372743062 , Max (Best):  0.5348195285562913
#
# [[ 6.332000e-03  1.463550e-01  9.958600e-01  9.348320e-01 -3.463184e+01]
#  [ 4.885942e-01  2.119651e-01  9.391779e-01  3.761917e-01 -1.781800e+01]
#  [ 4.006650e-01  7.257425e-02  8.867683e-01  2.438423e-01 -1.704923e+01]
#  [ 9.483894e-01  8.945130e-01  8.516378e-01  5.521963e-01 -3.262566e+01]
#  [ 9.571353e-01  5.976444e-01  7.661139e-01  7.762099e-01 -2.731640e+01]
#  [ 3.469621e-01  6.250400e-03  7.605636e-01  6.130236e-01 -1.605377e+01]
#  [ 3.874878e-01  8.045323e-01  7.517955e-01  7.238274e-01 -1.944156e+01]
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 5e-08, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.41865405 0.43305146 0.41035896 0.40070237], val=5.047301540176597e-08, best=0.0000000505
#
# 	Proposed next point to try: 0.418654-0.433051-0.410359-0.400702
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.01373737 0.85363166 0.25268549 0.25083647], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.013737-0.853632-0.252685-0.250836
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -32.82324153, 'max': -0.36834654, 'mean': -16.36546345, 'std': 3.80953502, 'q1': -18.87096776, 'median': -16.30320383, 'q3': -13.82220235}
# 	Local search 1/128, x=[0.43398359 0.41115141 0.38104752 0.40243042], val=0.6126891257489422, best=0.6126891257
# 	Local search 3/128, x=[0.43398359 0.41115142 0.38104752 0.40243041], val=0.6126891257489457, best=0.6126891257
# 	Local search 8/128, x=[0.43398359 0.41115142 0.38104752 0.40243042], val=0.6126891257489595, best=0.6126891257
# 	Local search 23/128, x=[0.43398359 0.41115142 0.38104752 0.40243042], val=0.612689125748972, best=0.6126891257
#
# 	Proposed next point to try: 0.433984-0.411151-0.381048-0.402430
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -31.1290907, 'max': 1.10020513, 'mean': -12.82043485, 'std': 3.77890872, 'q1': -15.22805198, 'median': -12.70148136, 'q3': -10.30417725}
# 	Local search 1/128, x=[0.44112741 0.41020136 0.38494424 0.37388835], val=1.5456208607682302, best=1.5456208608
# 	Local search 13/128, x=[0.44112741 0.41020138 0.38494426 0.37388836], val=1.545620860768389, best=1.5456208608
# 	Local search 22/128, x=[0.44112742 0.41020138 0.38494425 0.37388835], val=1.5456208607684006, best=1.5456208608
# 	Local search 47/128, x=[0.44112743 0.41020138 0.38494425 0.37388835], val=1.5456208607684045, best=1.5456208608
# 	Local search 99/128, x=[0.44112742 0.41020138 0.38494425 0.37388835], val=1.5456208607684063, best=1.5456208608
# 	Local search 109/128, x=[0.44112743 0.41020138 0.38494425 0.37388836], val=1.5456208607684103, best=1.5456208608
#
# 	Proposed next point to try: 0.441127-0.410201-0.384944-0.373888
#
# Using UCB Acquisition function with Kappa = 10
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -29.59020276, 'max': 3.13544303, 'mean': -9.20305876, 'std': 3.77063362, 'q1': -11.530599, 'median': -9.02262665, 'q3': -6.67744181}
# 	Local search 1/128, x=[0.44304762 0.40801272 0.38737544 0.34645937], val=3.330342039951244, best=3.3303420400
# 	Local search 2/128, x=[0.44304746 0.40801378 0.38737565 0.34645917], val=3.3303420400780865, best=3.3303420401
# 	Local search 4/128, x=[0.44304743 0.40801373 0.38737577 0.34645917], val=3.3303420400788433, best=3.3303420401
# 	Local search 10/128, x=[0.44304742 0.40801376 0.38737574 0.34645919], val=3.330342040078957, best=3.3303420401
# 	Local search 13/128, x=[0.44304746 0.40801375 0.38737573 0.3464592 ], val=3.3303420400791763, best=3.3303420401
# 	Local search 15/128, x=[0.44304747 0.40801371 0.38737572 0.34645919], val=3.3303420400792128, best=3.3303420401
# 	Local search 61/128, x=[0.44304745 0.40801373 0.38737573 0.34645919], val=3.330342040079236, best=3.3303420401
#
# 	Proposed next point to try: 0.443047-0.408014-0.387376-0.346459
#
# Using UCB Acquisition function with Kappa = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min
known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.01373737 0.85363166 0.25268549 0.25083647], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.013737-0.853632-0.252685-0.250836
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.01373737 0.85363166 0.25268549 0.25083647], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.013737-0.853632-0.252685-0.250836
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.01373737 0.85363166 0.25268549 0.25083647], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.013737-0.853632-0.252685-0.250836
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.01373737 0.85363166 0.25268549 0.25083647], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.013737-0.853632-0.252685-0.250836
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 1.72843736, 'max': 1961.51639084, 'mean': 111.57660124, 'std': 137.25627775, 'q1': 36.86128709, 'median': 66.29282765, 'q3': 129.05460027}
# 	Local search 1/128, x=[0.32510999 0.838974   1.         0.934109  ], val=2242.4116885715566, best=2242.4116885716
# 	Local search 8/128, x=[0.32510999 0.838974   1.         0.934109  ], val=2242.411703886741, best=2242.4117038867
# 	Local search 11/128, x=[0.32511  0.838974 1.       0.934109], val=2242.4117234929477, best=2242.4117234929
# 	Local search 12/128, x=[0.32511  0.838974 1.       0.934109], val=2242.4117298361825, best=2242.4117298362
# 	Local search 50/128, x=[0.32511  0.838974 1.       0.934109], val=2242.411739679043, best=2242.4117396790
# 	Local search 82/128, x=[0.32511  0.838974 1.       0.934109], val=2242.411745458557, best=2242.4117454586
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.46473235, 'max': 1963.82325783, 'mean': 116.06362213, 'std': 137.24243593, 'q1': 41.31823936, 'median': 70.71402849, 'q3': 133.61451196}
# 	Local search 1/128, x=[0.32510999 0.83897399 0.99999999 0.934109  ], val=2242.8925902202113, best=2242.8925902202
# 	Local search 2/128, x=[0.32510999 0.838974   1.         0.934109  ], val=2242.892672538592, best=2242.8926725386
# 	Local search 3/128, x=[0.32511  0.838974 1.       0.934109], val=2242.892722069079, best=2242.8927220691
# 	Local search 30/128, x=[0.32511  0.838974 1.       0.934109], val=2242.8927228611497, best=2242.8927228611
# 	Local search 53/128, x=[0.32511  0.838974 1.       0.934109], val=2242.8927327406554, best=2242.8927327407
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109
#
# Using UCB Acquisition function with Kappa = 10
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.26481315, 'max': 1966.17720416, 'mean': 120.64221519, 'std': 137.22891786, 'q1': 45.88478364, 'median': 75.24722776, 'q3': 138.25805886}
# 	Local search 1/128, x=[0.32511  0.838974 1.       0.934109], val=2243.3835057611996, best=2243.3835057612
# 	Local search 3/128, x=[0.32511  0.838974 1.       0.934109], val=2243.383517264648, best=2243.3835172646
# 	Local search 4/128, x=[0.32511  0.838974 1.       0.934109], val=2243.3835276630944, best=2243.3835276631
# 	Local search 26/128, x=[0.32511  0.838974 1.       0.934109], val=2243.383542571115, best=2243.3835425711
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109
#
# Using UCB Acquisition function with Kappa = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 9.77205525, 'max': 1970.88509638, 'mean': 129.79940097, 'std': 137.20371832, 'q1': 54.95641844, 'median': 84.23092469, 'q3': 147.47498175}
# 	Local search 1/128, x=[0.32511    0.83897399 1.         0.934109  ], val=2244.365093453914, best=2244.3650934539
# 	Local search 3/128, x=[0.32511  0.838974 1.       0.934109], val=2244.3651099024023, best=2244.3651099024
# 	Local search 4/128, x=[0.32511  0.838974 1.       0.934109], val=2244.3651301360496, best=2244.3651301360
# 	Local search 13/128, x=[0.32511  0.838974 1.       0.934109], val=2244.365134409677, best=2244.3651344097
# 	Local search 30/128, x=[0.32511  0.838974 1.       0.934109], val=2244.365135458011, best=2244.3651354580
# 	Local search 50/128, x=[0.32511  0.838974 1.       0.934109], val=2244.3651469986166, best=2244.3651469986
#
# 	Proposed next point to try: 0.325110-0.838974-1.000000-0.934109

# %%
f6_Inputs, f6_Outputs = combineInitialDataAndSubmissionsToDate(6)
findNextGuess('F6', f6_Inputs, f6_Outputs)
# Out:
# ********************
# F6  -  5 D
# ********************
#  Inputs -   Min: [0.021081  0.076503  0.0165229 0.042143  0.003667 ] , Max:  [0.95773967 0.93187122 0.989507   0.96165559 0.89281919]
#  Output -   Min: -2.5711696316081234 , Max (Best):  -0.2776577094327388
#
# [[ 0.585939  0.538496  0.989507  0.863517  0.003667 -0.897936]
#  [ 0.945069  0.288459  0.978806  0.961656  0.598016 -1.694343]
#  [ 0.145111  0.896685  0.896322  0.726272  0.236272 -1.233786]
#  [ 0.021735  0.428084  0.835939  0.489489  0.511082 -1.356682]
#  [ 0.629308  0.803484  0.811408  0.045613  0.110624 -1.622839]
#  [ 0.728186  0.154693  0.732552  0.693997  0.056401 -0.714265]
#  [ 0.784958  0.910682  0.708120  0.959225  0.004911 -1.247049]
#  [ 0.729523  0.748106  0.679775  0.356552  0.671054 -1.672200]
#  [ 0.258906  0.793678  0.642114  0.196673  0.593103 -1.702558]
#  [ 0.242384  0.844100  0.577809  0.679021  0.501953 -1.209955]
#  [ 0.400740  0.365117  0.465329  0.765461  0.143118 -0.277658]
#  [ 0.782880  0.536336  0.443284  0.859700  0.010326 -0.935757]
#  [ 0.439344  0.698924  0.426820  0.109476  0.877888 -2.018425]
#  [ 0.921776  0.931871  0.414876  0.595057  0.735626 -2.155768]
#  [ 0.536797  0.308781  0.411879  0.388225  0.522528 -1.144785]
#  [ 0.432166  0.715618  0.341819  0.705000  0.614962 -1.294247]
#  [ 0.618812  0.331802  0.187288  0.756238  0.328835 -0.829237]
#  [ 0.957740  0.235669  0.099146  0.156806  0.071317 -1.912677]
#  [ 0.126679  0.291470  0.064528  0.680515  0.892819 -1.746882]
#  [ 0.770620  0.114404  0.046780  0.648324  0.273549 -1.536058]
#  [ 0.021081  0.076503  0.031369  0.042143  0.045773 -1.990901]
#  [ 0.125720  0.862725  0.028544  0.246605  0.751206 -2.571170]
#  [ 0.757594  0.355831  0.016523  0.434207  0.112433 -1.309116]]
#
# Starting 5D Bayes Optimisation from 23 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.0001, 'kernel': RationalQuadratic(alpha=1, length_scale=2), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.04540215, 'mean': 0.00035992, 'std': 0.00211326, 'q1': 0.0, 'median': 1e-08, 'q3': 2.07e-06}
# 	Local search 1/160, x=[0.28770993 0.25122266 0.50876353 0.95567886 0.00453336], val=0.04638866179350288, best=0.0463886618
# 	Local search 2/160, x=[0.2877162  0.25122252 0.50876396 0.95568577 0.00453459], val=0.04638866182872219, best=0.0463886618
# 	Local search 14/160, x=[0.2877145  0.25122297 0.50876352 0.9556851  0.00452999], val=0.046388661834325204, best=0.0463886618
# 	Local search 26/160, x=[0.28771479 0.25122125 0.50876567 0.95568395 0.0045306 ], val=0.046388661834571396, best=0.0463886618
# 	Local search 31/160, x=[0.28771449 0.25122226 0.50876547 0.95568523 0.00453022], val=0.0463886618349374, best=0.0463886618
# 	Local search 76/160, x=[0.28771491 0.25122226 0.50876439 0.95568452 0.00452969], val=0.04638866183510649, best=0.0463886618
# 	Local search 134/160, x=[0.28771486 0.25122235 0.50876508 0.95568438 0.00452968], val=0.0463886618351728, best=0.0463886618
# 	Local search 143/160, x=[0.28771493 0.25122174 0.50876507 0.9556849  0.00452986], val=0.04638866183526235, best=0.0463886618
# 	Local search 152/160, x=[0.28771503 0.2512218  0.50876518 0.95568445 0.00452979], val=0.04638866183526329, best=0.0463886618
#
# 	Proposed next point to try: 0.287715-0.251222-0.508765-0.955684-0.004530
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.02231873, 'mean': 0.00012693, 'std': 0.00085026, 'q1': 0.0, 'median': 0.0, 'q3': 3.4e-07}
# 	Local search 1/160, x=[0.24959057 0.21136414 0.51969779 1.         0.        ], val=0.02337222893265238, best=0.0233722289
# 	Local search 2/160, x=[0.24958999 0.21136845 0.51968917 1.         0.        ], val=0.023372228944098468, best=0.0233722289
# 	Local search 42/160, x=[0.24959012 0.21136848 0.51968911 1.         0.        ], val=0.023372228944103006, best=0.0233722289
#
# 	Proposed next point to try: 0.249590-0.211368-0.519689-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00089637, 'mean': 1.43e-06, 'std': 1.691e-05, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.11210344 0.         0.63397051 1.         0.        ], val=0.0011377691673984478, best=0.0011377692
# 	Local search 7/160, x=[0.11197167 0.         0.633952   1.         0.        ], val=0.0011377691681279476, best=0.0011377692
# 	Local search 8/160, x=[0.1120318  0.         0.63390323 1.         0.        ], val=0.001137769230978431, best=0.0011377692
# 	Local search 43/160, x=[0.11206204 0.         0.63388454 1.         0.        ], val=0.0011377692314925823, best=0.0011377692
# 	Local search 79/160, x=[0.1120589  0.         0.63388863 1.         0.        ], val=0.0011377692323494611, best=0.0011377692
#
# 	Proposed next point to try: 0.112059-0.000000-0.633889-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.7274954  0.49434228 0.16094692 0.34788336 0.27622286], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.727495-0.494342-0.160947-0.347883-0.276223
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.68243649, 'max': -0.27455947, 'mean': -1.45464366, 'std': 0.40790003, 'q1': -1.74247961, 'median': -1.49047446, 'q3': -1.18020898}
# 	Local search 1/160, x=[0.37206275 0.32902066 0.48862    0.8064892  0.10422494], val=-0.26374440077333516, best=-0.2637444008
# 	Local search 3/160, x=[0.37206299 0.32902096 0.48862066 0.80648915 0.10422521], val=-0.2637444007733281, best=-0.2637444008
# 	Local search 4/160, x=[0.37206228 0.32902024 0.48862178 0.80648949 0.10422422], val=-0.2637444007727302, best=-0.2637444008
# 	Local search 5/160, x=[0.37206287 0.32902012 0.48862104 0.80648922 0.10422474], val=-0.263744400771045, best=-0.2637444008
# 	Local search 19/160, x=[0.37206242 0.32902007 0.48862103 0.80648962 0.10422496], val=-0.26374440077067135, best=-0.2637444008
# 	Local search 23/160, x=[0.37206259 0.32902004 0.48862118 0.80648949 0.10422481], val=-0.26374440077063704, best=-0.2637444008
# 	Local search 26/160, x=[0.37206245 0.32902026 0.48862098 0.80648936 0.1042247 ], val=-0.2637444007705041, best=-0.2637444008
# 	Local search 50/160, x=[0.3720625  0.32902029 0.48862099 0.80648941 0.10422471], val=-0.263744400770492, best=-0.2637444008
# 	Local search 64/160, x=[0.37206247 0.3290202  0.48862102 0.80648947 0.10422487], val=-0.26374440077046823, best=-0.2637444008
# 	Local search 75/160, x=[0.37206246 0.32902023 0.48862096 0.80648941 0.10422479], val=-0.2637444007704628, best=-0.2637444008
# 	Local search 82/160, x=[0.37206248 0.32902023 0.488621   0.80648942 0.10422478], val=-0.26374440077045946, best=-0.2637444008
#
# 	Proposed next point to try: 0.372062-0.329020-0.488621-0.806489-0.104225
#
# Using UCB Acquisition function with Kappa = 5
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.21357471, 'max': 1.27704476, 'mean': -0.31433641, 'std': 0.44021821, 'q1': -0.59485315, 'median': -0.30978014, 'q3': -0.01842882}
# 	Local search 1/160, x=[0. 0. 1. 1. 0.], val=1.3117754984887804, best=1.3117754985
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	81920 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.77285473, 'max': 3.46025855, 'mean': 0.8492424, 'std': 0.66398289, 'q1': 0.42587227, 'median': 0.83656834, 'q3': 1.28393566}
# 	Local search 1/160, x=[0. 0. 1. 1. 0.], val=3.5609421544424973, best=3.5609421544
#
# 	Proposed next point to try: 0.000000-0.000000-1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00059619, 'mean': 4.6e-07, 'std': 4.43e-06, 'q1': 0.0, 'median': 2e-08, 'q3': 1.5e-07}
# 	Local search 1/192, x=[0.         0.48141406 0.33454312 0.12872291 0.34347073 0.73616372], val=0.0009173063929054847, best=0.0009173064
# 	Local search 36/192, x=[0.         0.48141255 0.33454266 0.12872061 0.34347959 0.73614478], val=0.0009173063936027091, best=0.0009173064
# 	Local search 145/192, x=[0.         0.48141325 0.33454315 0.12873333 0.34347481 0.73616633], val=0.0009173063977244225, best=0.0009173064
#
# 	Proposed next point to try: 0.000000-0.481413-0.334543-0.128733-0.343475-0.736166
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 3.2e-07, 'mean': 0.0, 'std': 1e-08, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.0595129  0.50583572 0.35074071 0.00732919 0.41849532 0.72044843], val=3.2237931391387857e-07, best=0.0000003224
#
# 	Proposed next point to try: 0.059513-0.505836-0.350741-0.007329-0.418495-0.720448
#
# Using Expected Improvement Acquisition function with xi = 20
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.66561429 0.93280087 0.56137188 0.17030624 0.86089115 0.75977909], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.665614-0.932801-0.561372-0.170306-0.860891-0.759779
#
# Using UCB Acquisition function with Kappa = 0.1
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0170174, 'max': 1.42934568, 'mean': 0.26494022, 'std': 0.13178831, 'q1': 0.16970412, 'median': 0.24262727, 'q3': 0.33526514}
# 	Local search 1/192, x=[0.02886925 0.44916681 0.2819055  0.17375748 0.36664179 0.73222759], val=1.5092080484913488, best=1.5092080485
# 	Local search 2/192, x=[0.02886925 0.44916682 0.28190551 0.17375749 0.36664178 0.73222759], val=1.5092080484913617, best=1.5092080485
# 	Local search 15/192, x=[0.02886925 0.44916683 0.2819055  0.17375749 0.36664179 0.7322276 ], val=1.5092080484913633, best=1.5092080485
#
# 	Proposed next point to try: 0.028869-0.449167-0.281906-0.173757-0.366642-0.732228
#
# Using UCB Acquisition function with Kappa = 5
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.75987254, 'max': 2.28985063, 'mean': 1.74187114, 'std': 0.1673884, 'q1': 1.62567167, 'median': 1.74538363, 'q3': 1.85823663}
# 	Local search 1/192, x=[0.         0.54607409 0.40085869 0.02205315 0.32227679 0.75615984], val=2.324568819061473, best=2.3245688191
# 	Local search 33/192, x=[0.         0.54607437 0.40085834 0.02205299 0.32227721 0.75615999], val=2.324568819061522, best=2.3245688191
# 	Local search 72/192, x=[0.         0.54607444 0.40085836 0.0220531  0.32227684 0.75615977], val=2.3245688190616733, best=2.3245688191
# 	Local search 75/192, x=[0.         0.54607419 0.40085866 0.02205338 0.32227707 0.75616007], val=2.3245688190616765, best=2.3245688191
#
# 	Proposed next point to try: 0.000000-0.546074-0.400859-0.022053-0.322277-0.756160
#
# Using UCB Acquisition function with Kappa = 10
# 	98304 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min':
Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.41416934, 'mean': 0.0008429, 'std': 0.01064887, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.0660456  0.26841176 0.         0.29575778 0.56322417 0.52332394
#  0.1369295  0.44094625], val=0.4954619238711702, best=0.4954619239
# 	Local search 2/256, x=[0.07083458 0.27596293 0.         0.31155268 0.57066477 0.53120401
#  0.14270072 0.44163971], val=0.49636018043729146, best=0.4963601804
# 	Local search 74/256, x=[0.06998202 0.27589749 0.         0.31397882 0.57181148 0.53359477
#  0.14093482 0.44436286], val=0.49636029446609825, best=0.4963602945
# 	Local search 81/256, x=[0.06832469 0.27715325 0.         0.31326942 0.57006585 0.52978756
#  0.14201807 0.44438177], val=0.4963712591426961, best=0.4963712591
#
# 	Proposed next point to try: 0.068325-0.277153-0.000000-0.313269-0.570066-0.529788-0.142018-0.444382
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0456444, 'mean': 7.53e-06, 'std': 0.0003399, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.06254009 0.28362027 0.         0.32161103 0.57041192 0.5444529
#  0.13248351 0.43753392], val=0.10754284322619632, best=0.1075428432
# 	Local search 3/256, x=[0.06645433 0.28234771 0.         0.31370752 0.56359549 0.53861278
#  0.13193457 0.43756214], val=0.10767416714823003, best=0.1076741671
# 	Local search 5/256, x=[0.0636326  0.28358411 0.         0.31668753 0.56524912 0.53162375
#  0.13349824 0.43704995], val=0.10767722727539264, best=0.1076772273
# 	Local search 10/256, x=[0.06388468 0.28053574 0.         0.31726942 0.56611909 0.5353865
#  0.1320456  0.43780055], val=0.10770037935339649, best=0.1077003794
#
# 	Proposed next point to try: 0.063885-0.280536-0.000000-0.317269-0.566119-0.535387-0.132046-0.437801
#
# Using Expected Improvement Acquisition function with xi = 20
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.91903619 0.54813345 0.36738787 0.57781993 0.41296089 0.2554097
#  0.89534858 0.11399819], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.919036-0.548133-0.367388-0.577820-0.412961-0.255410-0.895349-0.113998
#
# Using UCB Acquisition function with Kappa = 0.1
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 4.48247909, 'max': 10.36183166, 'mean': 7.94873984, 'std': 0.97906264, 'q1': 7.26563213, 'median': 7.99813139, 'q3': 8.68089542}
# 	Local search 1/256, x=[0.06384245 0.28082486 0.         0.30970031 0.56904608 0.53257683
#  0.13814695 0.44306192], val=10.44524821283769, best=10.4452482128
# 	Local search 6/256, x=[0.06976843 0.2755717  0.         0.31490741 0.57106959 0.53172286
#  0.13672105 0.44054257], val=10.445269187633375, best=10.4452691876
# 	Local search 23/256, x=[0.06622197 0.28049982 0.         0.30922195 0.56835809 0.53267856
#  0.13805742 0.44288574], val=10.44527266818093, best=10.4452726682
# 	Local search 28/256, x=[0.06946935 0.27676349 0.         0.31372559 0.56997552 0.53479865
#  0.13648086 0.44449716], val=10.445276695203246, best=10.4452766952
# 	Local search 41/256, x=[0.06920443 0.2785813  0.         0.31331035 0.56798516 0.53125845
#  0.13871771 0.4397807 ], val=10.445308238383713, best=10.4453082384
# 	Local search 64/256, x=[0.06846564 0.28131221 0.         0.31443113 0.56727262 0.5325002
#  0.13903128 0.44187978], val=10.445312011600588, best=10.4453120116
#
# 	Proposed next point to try: 0.068466-0.281312-0.000000-0.314431-0.567273-0.532500-0.139031-0.441880
#
# Using UCB Acquisition function with Kappa = 5
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.44881789, 'max': 10.95628844, 'mean': 8.57512044, 'std': 0.95962304, 'q1': 7.89128949, 'median': 8.61103033, 'q3': 9.2970332}
# 	Local search 1/256, x=[0.         0.30130283 0.         0.30099367 0.44020086 0.62659017
#  0.         0.27044245], val=11.101518366542967, best=11.1015183665
# 	Local search 4/256, x=[0.         0.30470789 0.         0.3015713  0.43117536 0.61659536
#  0.         0.27421187], val=11.101519521727726, best=11.1015195217
# 	Local search 5/256, x=[0.         0.3106714  0.         0.30131387 0.43434621 0.61964394
#  0.         0.27212389], val=11.101542348844148, best=11.1015423488
# 	Local search 32/256, x=[0.         0.30709942 0.         0.30157124 0.43246747 0.61857949
#  0.         0.27001213], val=11.101556366360875, best=11.1015563664
# 	Local search 57/256, x=[0.         0.30729178 0.         0.30118664 0.43468957 0.62464505
#  0.         0.27136426], val=11.101580332494336, best=11.1015803325
# 	Local search 192/256, x=[0.         0.30654234 0.         0.30684453 0.43246149 0.6233152
#  0.         0.27293997], val=11.10160310124178, best=11.1016031012
#
# 	Proposed next point to try: 0.000000-0.306542-0.000000-0.306845-0.432461-0.623315-0.000000-0.272940
#
# Using UCB Acquisition function with Kappa = 10
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.26706765, 'max': 11.93247457, 'mean': 9.21428466, 'std': 0.9721733, 'q1': 8.50931184, 'median': 9.23073291, 'q3': 9.94023997}
# 	Local search 1/256, x=[0.         0.         0.         0.         0.32429954 1.
#  0.         0.        ], val=12.238221820085013, best=12.2382218201
# 	Local search 13/256, x=[0.         0.         0.         0.         0.32275634 1.
#  0.         0.        ], val=12.238224875120398, best=12.2382248751
# 	Local search 16/256, x=[0.         0.         0.         0.         0.32209178 0.99999999
#  0.         0.        ], val=12.238225062949443, best=12.2382250629
# 	Local search 47/256, x=[0.         0.         0.         0.         0.32216093 1.
#  0.         0.        ], val=12.23822507557717, best=12.2382250756
# 	Local search 49/256, x=[0.         0.         0.         0.         0.32222539 1.
#  0.         0.        ], val=12.238225079821873, best=12.2382250798
# 	Local search 83/256, x=[0.         0.         0.         0.         0.32224506 1.
#  0.         0.        ], val=12.238225080063202, best=12.2382250801
# 	Local search 119/256, x=[0.         0.         0.         0.         0.32223919 1.
#  0.         0.        ], val=12.2382250800645, best=12.2382250801
#
# 	Proposed next point to try: 0.000000-0.000000-0.000000-0.000000-0.322239-1.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	131072 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 7.2658303, 'max': 14.94216587, 'mean': 10.49261227, 'std': 1.08793993, 'q1': 9.69365367, 'median': 10.47067246, 'q3': 11.26422746}
# 	Local search 1/256, x=[0. 1. 0. 1. 1. 1. 0. 1.], val=15.583127628548997, best=15.5831276285
#
# 	Proposed next point to try: 0.000000-1.000000-0.000000-1.000000-1.000000-1.000000-0.000000-1.000000

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: {'alpha': 1e-08, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 10}
# F2: {'alpha': 0.01, 'kernel': Matern(length_scale=2, nu=0.5), 'n_restarts_optimizer': 5}
# F3: {'alpha': 0.01, 'kernel': Matern(length_scale=2, nu=0.5), 'n_restarts_optimizer': 5}
# F4: {'alpha': 1e-08, 'kernel': RationalQuadratic(alpha=1, length_scale=2), 'n_restarts_optimizer': 10}
# F5: {'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=0.5), 'n_restarts_optimizer': 20}
# F6: {'alpha': 0.0001, 'kernel': RationalQuadratic(alpha=1, length_scale=2), 'n_restarts_optimizer': 20}
# F7: {'alpha': 0.01, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 5}
# F8: {'alpha': 0.01, 'kernel': RationalQuadratic(alpha=1, length_scale=1), 'n_restarts_optimizer': 5}
#
#
# F1:
# 0: 1.000000-1.000000
# 1: 0.005040-0.998743
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 1.000000-1.000000
# 5: 0.000000-1.000000
# 6: 0.000000-1.000000
# 7: 0.000000-1.000000
#
# F2:
# 0: 1.000000-0.000000
# 1: 1.000000-0.000000
# 2: 1.000000-0.000000
# 3: 0.016199-0.328627
# 4: 0.721814-0.121875
# 5: 1.000000-0.000000
# 6: 0.000000-1.000000
