# %% [markdown]
# ## Setup

# %%
import os

from numpy import ndarray
from sklearn.gaussian_process.kernels import Matern, RationalQuadratic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats._qmc import Sobol
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats import norm
from scipy.optimize import minimize
import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'


def penaltyWeightAndScaleForDimension(d):
    #Curse of dimensionality means this needs to be much tighter at higher dimensions
    #This is intended to reduce the acquisition function's information gain by 10% if the point has a Euclidean distance of 1/20th or 1/50th of a boundary.
    if d <= 5:
        return 0.1, 0.05
    else:
        return 0.1, 0.02

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma

#
def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }


from sklearn.model_selection import GridSearchCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

def findTunedGaussianProcessRegressorWithoutAutomaticRelevanceDetermination(X_samples, y_samples):
    #Use grid search to work out which GP hyper params are best to fit to this problem
    param_grid = {
        'kernel': [RBF(length_scale=0.5), RBF(length_scale=1.0), RBF(length_scale=2.0),
                   Matern(nu=0.5, length_scale=1.0), Matern(nu=1.5,length_scale=1.0 ), Matern(nu=2.5, length_scale=1.0),
                   Matern(nu=0.5, length_scale=2.0), Matern(nu=1.5,length_scale=2.0 ), Matern(nu=2.5, length_scale=2.0),
                   RationalQuadratic(alpha=1.0, length_scale=1.0), RationalQuadratic(alpha=1.0, length_scale=2.0)],
        'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
        'n_restarts_optimizer': [5, 10, 20]
    }
    gp = GaussianProcessRegressor()
    grid_search = GridSearchCV(gp, param_grid, cv=3)
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_

def findTunedGaussianProcessRegressor(X_samples, y_samples):
    import numpy as np
    from sklearn.gaussian_process import GaussianProcessRegressor
    from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic
    from sklearn.model_selection import GridSearchCV

    n_dims = X_samples.shape[1]

    # ARD kernels (vector length_scale)
    rbf_ard = RBF(length_scale=np.ones(n_dims),
                  length_scale_bounds=(1e-2, 1e2))

    matern_05 = Matern(length_scale=np.ones(n_dims), nu=0.5,
                       length_scale_bounds=(1e-2, 1e2))
    matern_15 = Matern(length_scale=np.ones(n_dims), nu=1.5,
                       length_scale_bounds=(1e-2, 1e2))
    matern_25 = Matern(length_scale=np.ones(n_dims), nu=2.5,
                       length_scale_bounds=(1e-2, 1e2))

    param_grid = {
        'kernel': [
            rbf_ard,
            matern_05, matern_15, matern_25,
        ],
        'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
        'n_restarts_optimizer': [5, 10, 20]
    }

    gp = GaussianProcessRegressor(normalize_y=True)

    grid_search = GridSearchCV(gp, param_grid, cv=3)
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_



def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims
    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]
    penaltyWeight, penalityScale = penaltyWeightAndScaleForDimension(n_dims)

    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )

    gp.fit(X_samples, y_samples)

    lengthscales = gp.kernel_.length_scale
    print(f"\tFitted GP - {lengthscales} ")




    # -----------------------------
    # 2. Acquisition function
    # -----------------------------

    # -----------------------------
    # 2.1 Boundary Penalty.
    # GP tends to hug the boundary, so add a penalty if a suggested point is close to boundary.
    # Scale controls how far from the boundary the penalty reaches. At scale=0.05, a point at x=0.05 gets a penalty of exp(-1) ≈ 0.37, meaning the penalty is significant only within the last ~5% of the search space.
    # Weight controls how strongly that penalty suppresses the acquisition value. At weight=0.1, the maximum possible suppression is 10% of the acquisition value.
    #
    # -----------------------------
    def boundary_penalty(X, weight=0.1, scale=0.05):
        X = np.atleast_2d(X)
        d = np.minimum(X, 1.0 - X)    #Find point closest to boundary at 0 or 1 in any dimension.
        penalty = np.mean(np.exp(-d / scale), axis=1)   #exp(-small) tends towards 1, exp(-large) tends towards 0. Mean takes into account other dimensions.
        return weight * penalty


    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        penalty = boundary_penalty(X, weight=penaltyWeight, scale=penalityScale)
        return val * (1 - penalty)


    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Filter out duplicate candidates - because acquisition functions can suggest previous points.
    def is_duplicate(x, X_samples, tol=1e-5):
        return np.any(np.linalg.norm(X_samples - x, axis=1) < tol)
    mask = np.array([not is_duplicate(x, X_samples) for x in X_candidates])
    X_candidates = X_candidates[mask]
    acq_vals = acq_vals[mask]


    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{len(X_candidates)} Sobol candidates, best {len(X_start)} to be minimised in local search")
    print(f"\tInitial acquisition function stats {summary_stats(acq_vals)}")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition


    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun
        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
def sortByLargestOutputDescending(arr):
    return  arr[np.argsort(arr[:, 2])[::-1]]

def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')



def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)


    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem is ${bestParams}")
    gpKernels[functionName] = bestParams


    functionProposedPoints = {}
    count = -1
    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
def collatePreviousSubmissions(functionNo):
    functionIndex = functionNo -1
    assert(functionIndex >= 0)
    assert(functionIndex <= 7)

    #Search for subfolders and find last submission week and results
    week_folders = [d for d in os.listdir("submission_results") if d.startswith("week") ]
    week_folders.sort(key=lambda w: int(w.replace("week", "")))
    last_week = week_folders[-1]
    week_dir = os.path.join("submission_results", last_week)


    def load_file(file_name):
        file_path = os.path.join(week_dir, file_name)
        all_lines = []
        with open(file_path, "r") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                # Parse the trusted Python literals
                parsedData = eval(line, {"array": np.array, "np": np})
                all_lines.append(parsedData)
        return all_lines
    allSubmissions = load_file("inputs.txt")
    allResults = load_file("outputs.txt")

    #Extract the functionNo inputs and outputs only and return those arrays only
    functionSubmissions = np.array([line[functionIndex] for line in allSubmissions])
    functionResults = np.array([line[functionIndex] for line in allResults])

    return functionSubmissions, functionResults

# %%
def combineInitialDataAndSubmissionsToDate(functionNo):
    assert(functionNo >= 1)
    assert(functionNo <= 8)

    initialInputs = np.load(f'initial_data/function_{functionNo}/initial_inputs.npy')
    initialOutputs = np.load(f'initial_data/function_{functionNo}/initial_outputs.npy')

    submissions, results = collatePreviousSubmissions(functionNo)

    combined_Inputs = np.vstack((initialInputs, submissions))
    combined_Outputs = np.concatenate((initialOutputs, results))

    assert combined_Inputs.shape[1] == initialInputs.shape[1]
    assert combined_Outputs.shape[0] == combined_Inputs.shape[0]

    return combined_Inputs, combined_Outputs

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.00787  0.037348] , Max:  [0.88388983 0.990426  ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  2.6752879910742468e-09
#
# [[ 5.000000e-001  5.000000e-001  2.675288e-009]
#  [ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 7.870000e-003  9.904260e-001  0.000000e+000]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 15 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.01, 'kernel': Matern(length_scale=[1, 1], nu=0.5), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	Fitted GP - [1.91878039e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00027597, 'mean': 0.00022229, 'std': 6.836e-05, 'q1': 0.00021433, 'median': 0.00025182, 'q3': 0.00026222}
# 	Local search 1/64, x=[0.70732102 0.50736293], val=0.0002759663693496, best=0.0002759664
# 	Local search 8/64, x=[0.70744196 0.4965256 ], val=0.0002759678402513723, best=0.0002759678
#
# 	Proposed next point to try: 0.707442-0.496526
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	Fitted GP - [1.91878062e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [1.91878041e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [1.91878037e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [1.91878058e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00355542, 'max': 3.294e-05, 'mean': -0.00017632, 'std': 0.00044806, 'q1': -0.00013938, 'median': -7.963e-05, 'q3': -1.849e-05}
# 	Local search 1/64, x=[0.31604888 0.36225993], val=3.294399175282267e-05, best=0.0000329440
# 	Local search 2/64, x=[0.31604836 0.57835673], val=3.2944378386488444e-05, best=0.0000329444
# 	Local search 3/64, x=[0.31604857 0.49384943], val=3.29450065155048e-05, best=0.0000329450
# 	Local search 60/64, x=[0.31604919 0.47727757], val=3.294501430126312e-05, best=0.0000329450
#
# 	Proposed next point to try: 0.316049-0.477278
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [1.91878049e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00305314, 'max': 0.0042668, 'mean': 0.00354654, 'std': 0.00097787, 'q1': 0.00320477, 'median': 0.00398072, 'q3': 0.00419848}
# 	Local search 1/64, x=[0.78475961 0.51056525], val=0.004266804648268699, best=0.0042668046
# 	Local search 6/64, x=[0.78502548 0.48551993], val=0.004266807001307509, best=0.0042668070
# 	Local search 19/64, x=[0.78503705 0.50253272], val=0.004266809754521126, best=0.0042668098
# 	Local search 56/64, x=[0.78502834 0.49983869], val=0.004266810227119175, best=0.0042668102
#
# 	Proposed next point to try: 0.785028-0.499839
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [1.91878102e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0025406, 'max': 0.00875465, 'mean': 0.00734538, 'std': 0.00178849, 'q1': 0.00660624, 'median': 0.00814204, 'q3': 0.0085936}
# 	Local search 1/64, x=[0.24623017 0.50967756], val=0.008754654491078708, best=0.0087546545
# 	Local search 17/64, x=[0.24631518 0.50689529], val=0.008754655345410488, best=0.0087546553
# 	Local search 24/64, x=[0.24614004 0.49703627], val=0.008754657776772453, best=0.0087546578
# 	Local search 51/64, x=[0.24603128 0.49979272], val=0.008754658914246831, best=0.0087546589
#
# 	Proposed next point to try: 0.246031-0.499793
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [1.91877986e-02 1.00000000e+02]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00151553, 'max': 0.0177434, 'mean': 0.01494305, 'std': 0.00348469, 'q1': 0.01357055, 'median': 0.016482, 'q3': 0.01738957}
# 	Local search 1/64, x=[0.23817861 0.50288809], val=0.017743396471246894, best=0.0177433965
# 	Local search 23/64, x=[0.23858334 0.50409433], val=0.01774339731832255, best=0.0177433973
# 	Local search 33/64, x=[0.23862007 0.49978892], val=0.0177434005021357, best=0.0177434005
#
# 	Proposed next point to try: 0.238620-0.499789

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.092501   0.02869772] , Max:  [0.87779099 0.970764  ]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
#
# [[ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.600000  0.500000  0.144121]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.092501  0.897042 -0.043957]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 15 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.0001, 'kernel': RBF(length_scale=[1, 1]), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	Fitted GP - [0.05833819 1.42374165]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03261457, 'mean': 0.00062371, 'std': 0.00294539, 'q1': 0.0, 'median': 0.0, 'q3': 1.154e-05}
# 	Local search 1/64, x=[0.68508845 0.91650093], val=0.03262155664048049, best=0.0326215566
# 	Local search 3/64, x=[0.68508852 0.91650175], val=0.03262155664070361, best=0.0326215566
# 	Local search 4/64, x=[0.68508849 0.91650236], val=0.03262155664092044, best=0.0326215566
# 	Local search 21/64, x=[0.68508849 0.9165027 ], val=0.0326215566409238, best=0.0326215566
# 	Local search 34/64, x=[0.68508849 0.91650239], val=0.03262155664092992, best=0.0326215566
# 	Local search 43/64, x=[0.68508847 0.91650248], val=0.03262155664093936, best=0.0326215566
# 	Local search 49/64, x=[0.68508848 0.91650257], val=0.03262155664094155, best=0.0326215566
#
# 	Proposed next point to try: 0.685088-0.916503
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	Fitted GP - [0.05833819 1.4237415 ]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00045328, 'mean': 2.78e-05, 'std': 9.417e-05, 'q1': 0.0, 'median': 0.0, 'q3': 8e-08}
# 	Local search 1/64, x=[0.67020844 1.        ], val=0.0004639591746068158, best=0.0004639592
#
# 	Proposed next point to try: 0.670208-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [0.05833819 1.42374139]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 1.4e-07, 'mean': 0.0, 'std': 2e-08, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.99614093 0.16354457], val=1.3510260427521504e-07, best=0.0000001351
#
# 	Proposed next point to try: 0.996141-0.163545
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [0.05833819 1.42374155]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [0.05833819 1.42374205]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.1465814, 'max': 0.64323796, 'mean': 0.16466922, 'std': 0.18752668, 'q1': 0.01336643, 'median': 0.12419392, 'q3': 0.28299662}
# 	Local search 1/64, x=[0.68558451 0.8322581 ], val=0.6432524096484413, best=0.6432524096
# 	Local search 2/64, x=[0.68558449 0.83227083], val=0.6432524096827442, best=0.6432524097
# 	Local search 4/64, x=[0.6855846  0.83226883], val=0.6432524096852233, best=0.6432524097
# 	Local search 9/64, x=[0.68558457 0.83226861], val=0.6432524096852746, best=0.6432524097
# 	Local search 11/64, x=[0.68558457 0.83226847], val=0.6432524096852803, best=0.6432524097
# 	Local search 13/64, x=[0.68558458 0.83226859], val=0.6432524096852872, best=0.6432524097
# 	Local search 20/64, x=[0.68558458 0.83226855], val=0.6432524096852882, best=0.6432524097
#
# 	Proposed next point to try: 0.685585-0.832269
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [0.05833819 1.42374159]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.05228643, 'max': 1.16180045, 'mean': 0.53376728, 'std': 0.2942211, 'q1': 0.31535553, 'median': 0.51361033, 'q3': 0.74554531}
# 	Local search 1/64, x=[0.98265126 0.2272332 ], val=1.1618053741680983, best=1.1618053742
# 	Local search 2/64, x=[0.98265124 0.22721966], val=1.161805374170089, best=1.1618053742
# 	Local search 4/64, x=[0.98265114 0.22722738], val=1.1618053741740566, best=1.1618053742
# 	Local search 9/64, x=[0.98265119 0.22722587], val=1.1618053741747567, best=1.1618053742
# 	Local search 15/64, x=[0.98265122 0.22722588], val=1.161805374174777, best=1.1618053742
# 	Local search 26/64, x=[0.98265121 0.22722553], val=1.16180537417478, best=1.1618053742
# 	Local search 30/64, x=[0.98265121 0.22722574], val=1.1618053741747831, best=1.1618053742
# 	Local search 34/64, x=[0.98265121 0.22722567], val=1.1618053741747845, best=1.1618053742
#
# 	Proposed next point to try: 0.982651-0.227226
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [0.05833819 1.4237416 ]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.03978847, 'max': 2.10209352, 'mean': 0.91039794, 'std': 0.53089467, 'q1': 0.50846571, 'median': 0.82095, 'q3': 1.19523502}
# 	Local search 1/64, x=[0.99185893 0.23503588], val=2.102104509672669, best=2.1021045097
# 	Local search 4/64, x=[0.99185893 0.23503518], val=2.102104509672679, best=2.1021045097
# 	Local search 13/64, x=[0.99185893 0.23503523], val=2.102104509672686, best=2.1021045097
# 	Local search 14/64, x=[0.99185895 0.23503551], val=2.1021045096727007, best=2.1021045097
# 	Local search 16/64, x=[0.99185894 0.23503546], val=2.102104509672704, best=2.1021045097
# 	Local search 45/64, x=[0.99185893 0.23503557], val=2.1021045096727042, best=2.1021045097
# 	Local search 52/64, x=[0.99185894 0.23503545], val=2.1021045096727047, best=2.1021045097
#
# 	Proposed next point to try: 0.991859-0.235035
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [0.05833819 1.42374117]
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.01479257, 'max': 3.99227763, 'mean': 1.66365945, 'std': 1.05130711, 'q1': 0.83867285, 'median': 1.39753296, 'q3': 2.27031741}
# 	Local search 1/64, x=[0.99607534 0.23929319], val=3.992322673384159, best=3.9923226734
# 	Local search 2/64, x=[0.99605493 0.23683626], val=3.9923246688404466, best=3.9923246688
# 	Local search 4/64, x=[0.99605495 0.2368358 ], val=3.99232466884063, best=3.9923246688
# 	Local search 16/64, x=[0.99605495 0.23683582], val=3.992324668840632, best=3.9923246688
# 	Local search 43/64, x=[0.99605495 0.23683594], val=3.9923246688406366, best=3.9923246688
# 	Local search 44/64, x=[0.99605495 0.23683589], val=3.992324668840637, best=3.9923246688
#
# 	Proposed next point to try: 0.996055-0.236836

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.151837  0.439991  0.990882 -0.398926]
#  [ 0.965337  0.047492  0.944587 -0.273443]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.431029  0.814368  0.806413 -0.098068]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.600097  0.725136  0.066089 -0.036378]]
#
# Starting 3D Bayes Optimisation from 20 known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 1e-06, 'kernel': RBF(length_scale=[1, 1, 1]), 'n_restarts_optimizer': 5}
# Using Expected Improvement Acquisition function with xi = 0
# 	Fitted GP - [1.00000000e+02 7.17864389e-01 4.80274329e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03361119, 'mean': 0.00476534, 'std': 0.00674091, 'q1': 9.2e-07, 'median': 0.00178219, 'q3': 0.00718937}
# 	Local search 1/96, x=[0.67238882 0.87363433 0.47637679], val=0.033615639148371304, best=0.0336156391
# 	Local search 2/96, x=[0.61319923 0.87364806 0.47637534], val=0.033616654394870264, best=0.0336166544
# 	Local search 3/96, x=[0.48188664 0.87365358 0.47637557], val=0.033616790936829566, best=0.0336167909
# 	Local search 4/96, x=[0.53458089 0.87364827 0.47637562], val=0.03361688589406373, best=0.0336168859
# 	Local search 6/96, x=[0.5393306  0.87366771 0.47638029], val=0.03361688595201278, best=0.0336168860
# 	Local search 11/96, x=[0.53829201 0.87364372 0.47637738], val=0.03361688617543117, best=0.0336168862
# 	Local search 28/96, x=[0.53803155 0.87364948 0.47637558], val=0.033616886201584026, best=0.0336168862
# 	Local search 90/96, x=[0.53806761 0.87365046 0.47637549], val=0.033616886201889955, best=0.0336168862
#
# 	Proposed next point to try: 0.538068-0.873650-0.476375
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	Fitted GP - [5.13011604e+01 7.17724254e-01 4.80141609e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00164153, 'mean': 0.00012744, 'std': 0.0002454, 'q1': 0.0, 'median': 7.7e-07, 'q3': 0.00016123}
# 	Local search 1/96, x=[0.33997986 0.99817553 0.42065556], val=0.0016439520046886836, best=0.0016439520
# 	Local search 2/96, x=[0.3868162  0.99821368 0.42065608], val=0.0016440066826551008, best=0.0016440067
# 	Local search 4/96, x=[0.68834378 0.99815126 0.42065463], val=0.0016440183548400297, best=0.0016440184
# 	Local search 5/96, x=[0.50605794 0.99796568 0.42065126], val=0.0016440678764074734, best=0.0016440679
# 	Local search 7/96, x=[0.57162906 0.99812624 0.42065384], val=0.0016440821224076214, best=0.0016440821
# 	Local search 9/96, x=[0.58931736 0.99818725 0.42065607], val=0.0016440832819456606, best=0.0016440833
#
# 	Proposed next point to try: 0.589317-0.998187-0.420656
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [1.00000000e+02 7.17933669e-01 4.80293311e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.5466633  0.00208129 0.00081679], val=2.9577952157555675e-14, best=0.0000000000
#
# 	Proposed next point to try: 0.546663-0.002081-0.000817
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [  0.14631263 100.           0.13411164]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [2.35046842 0.06609055 0.05322003]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.38825039, 'max': -0.01557286, 'mean': -0.09986527, 'std': 0.03134774, 'q1': -0.10372914, 'median': -0.10126585, 'q3': -0.09230486}
# 	Local search 1/96, x=[0.35825338 0.40351186 0.45664795], val=-0.0155059948154682, best=-0.0155059948
# 	Local search 10/96, x=[0.3582578  0.40351191 0.45664794], val=-0.015505994815418717, best=-0.0155059948
# 	Local search 13/96, x=[0.35825503 0.40351194 0.45664791], val=-0.015505994815413739, best=-0.0155059948
# 	Local search 25/96, x=[0.35825597 0.40351192 0.45664795], val=-0.015505994815408273, best=-0.0155059948
#
# 	Proposed next point to try: 0.358256-0.403512-0.456648
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [1.00000000e-02 1.08151849e+01 1.00000000e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.19566972, 'max': 0.32999763, 'mean': 0.3147489, 'std': 0.01729965, 'q1': 0.31411289, 'median': 0.31773594, 'q3': 0.31913137}
# 	Local search 1/96, x=[0.38876603 0.38730158 0.45905031], val=0.32999763595630144, best=0.3299976360
# 	Local search 2/96, x=[0.38100477 0.49939705 0.44683911], val=0.33000079842492724, best=0.3300007984
# 	Local search 3/96, x=[0.38642623 0.48159157 0.45245739], val=0.3300012904036433, best=0.3300012904
# 	Local search 5/96, x=[0.38607279 0.49997581 0.47107462], val=0.3300018779986116, best=0.3300018780
# 	Local search 11/96, x=[0.38877662 0.50000555 0.46386488], val=0.33000199377957545, best=0.3300019938
# 	Local search 54/96, x=[0.38855481 0.49963337 0.46512492], val=0.3300019979871259, best=0.3300019980
#
# 	Proposed next point to try: 0.388555-0.499633-0.465125
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [1.00000000e+02 1.00000000e+02 1.52672203e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.38574238, 'max': 0.76758316, 'mean': 0.46969024, 'std': 0.31244294, 'q1': 0.18760653, 'median': 0.63013215, 'q3': 0.74127998}
# 	Local search 1/96, x=[0.50173079 0.42900107 0.49450496], val=0.7676071294404575, best=0.7676071294
# 	Local search 4/96, x=[0.49128122 0.49265469 0.4945049 ], val=0.7676104072803548, best=0.7676104073
# 	Local search 6/96, x=[0.4999416  0.49987915 0.49450566], val=0.7676108074022582, best=0.7676108074
# 	Local search 13/96, x=[0.49998975 0.5000006  0.49450495], val=0.7676108114328265, best=0.7676108114
# 	Local search 32/96, x=[0.50000367 0.49999313 0.49450507], val=0.7676108114374794, best=0.7676108114
# 	Local search 79/96, x=[0.50000064 0.49999999 0.49450435], val=0.7676108115737379, best=0.7676108116
# 	Local search 88/96, x=[0.49999801 0.49999777 0.49450496], val=0.7676108115866147, best=0.7676108116
#
# 	Proposed next point to try: 0.499998-0.499998-0.494505
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [6.71002151e+01 7.18004075e-01 4.80180072e-02]
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0
 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.42753022 0.48118788 0.31836504 0.43100155], val=0.018412218223394495, best=0.0184122182
# 	Local search 2/128, x=[0.42753011 0.48118748 0.31836445 0.43100167], val=0.018412218225691918, best=0.0184122182
# 	Local search 30/128, x=[0.42753013 0.48118739 0.31836446 0.43100175], val=0.018412218225735147, best=0.0184122182
#
# 	Proposed next point to try: 0.427530-0.481187-0.318364-0.431002
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [0.78972482 0.75361416 0.79829753 0.74481219]
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.02433108 0.97459509 0.994277   0.00941195], val=2.554900737375052e-16, best=0.0000000000
#
# 	Proposed next point to try: 0.024331-0.974595-0.994277-0.009412
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [0.78972458 0.75361407 0.79829745 0.74481202]
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -34.24805511, 'max': 0.49794594, 'mean': -16.68362422, 'std': 6.37971073, 'q1': -21.11756481, 'median': -16.77946127, 'q3': -12.09401619}
# 	Local search 1/128, x=[0.42216248 0.42979067 0.36999285 0.43643161], val=0.6260792116799739, best=0.6260792117
# 	Local search 4/128, x=[0.42216249 0.42979067 0.36999283 0.43643161], val=0.6260792116800465, best=0.6260792117
# 	Local search 5/128, x=[0.42216248 0.42979066 0.36999284 0.43643159], val=0.6260792116800551, best=0.6260792117
# 	Local search 15/128, x=[0.42216247 0.42979066 0.36999282 0.43643159], val=0.6260792116800556, best=0.6260792117
# 	Local search 19/128, x=[0.42216249 0.42979066 0.36999282 0.43643157], val=0.6260792116800818, best=0.6260792117
# 	Local search 21/128, x=[0.42216248 0.42979064 0.36999283 0.43643158], val=0.626079211680083, best=0.6260792117
# 	Local search 26/128, x=[0.42216251 0.42979066 0.36999284 0.43643158], val=0.62607921168012, best=0.6260792117
#
# 	Proposed next point to try: 0.422163-0.429791-0.369993-0.436432
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [0.78972467 0.75361418 0.79829761 0.74481218]
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -31.32656206, 'max': 4.63591126, 'mean': -7.43958016, 'std': 5.83052677, 'q1': -11.19844234, 'median': -6.76600739, 'q3': -3.03833141}
# 	Local search 1/128, x=[0.46895565 0.51926047 0.08089643 0.42679147], val=4.7018390873528855, best=4.7018390874
# 	Local search 6/128, x=[0. 1. 1. 0.], val=4.73460687658499, best=4.7346068766
# 	Local search 11/128, x=[1. 0. 0. 0.], val=5.251150099153093, best=5.2511500992
#
# 	Proposed next point to try: 1.000000-0.000000-0.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [0.78972458 0.75361407 0.79829745 0.74481202]
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -29.81674807, 'max': 28.61696414, 'mean': 1.99312331, 'std': 7.37853897, 'q1': -2.69977592, 'median': 2.64405047, 'q3': 6.97892472}
# 	Local search 1/128, x=[0. 1. 1. 0.], val=29.49179171598097, best=29.4917917160
#
# 	Proposed next point to try: 0.000000-1.000000-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [0.78972458 0.75361407 0.79829745 0.74481202]
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min':
known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 0.0001, 'kernel': Matern(length_scale=[1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	Fitted GP - [100.          45.07104215   0.84730043   0.18509769]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.95213388, 'mean': 1.96582454, 'std': 24.42080347, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44492455 0.6669104  1.         1.        ], val=554.5280904216995, best=554.5280904217
# 	Local search 2/128, x=[0.44495641 0.66694554 1.         1.        ], val=554.5280904382731, best=554.5280904383
# 	Local search 3/128, x=[0.4450676  0.66697558 1.         1.        ], val=554.5280904520864, best=554.5280904521
# 	Local search 20/128, x=[0.44518127 0.66697048 1.         1.        ], val=554.5280904526032, best=554.5280904526
# 	Local search 26/128, x=[0.44510618 0.66695857 1.         1.        ], val=554.5280904558981, best=554.5280904559
# 	Local search 66/128, x=[0.44512393 0.66696071 1.         1.        ], val=554.5280904559428, best=554.5280904559
# 	Local search 83/128, x=[0.44511565 0.66695642 1.         1.        ], val=554.5280904560865, best=554.5280904561
#
# 	Proposed next point to try: 0.445116-0.666956-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	Fitted GP - [100.          45.07104468   0.84730031   0.18509765]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.85809244, 'mean': 1.96503659, 'std': 24.41360224, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44514981 0.66695989 1.         1.        ], val=554.4329781128922, best=554.4329781129
# 	Local search 35/128, x=[0.4451443  0.66695751 1.         1.        ], val=554.4329781130542, best=554.4329781131
#
# 	Proposed next point to try: 0.445144-0.666958-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [100.          45.07107008   0.84730028   0.18509764]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.48239367, 'mean': 1.96188738, 'std': 24.38481944, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44541006 0.66699456 1.         1.        ], val=554.0530090440722, best=554.0530090441
# 	Local search 2/128, x=[0.44520442 0.66704628 1.         1.        ], val=554.0530090825622, best=554.0530090826
# 	Local search 6/128, x=[0.44522794 0.66696956 1.         1.        ], val=554.0530090949233, best=554.0530090949
# 	Local search 7/128, x=[0.44501888 0.66698345 1.         1.        ], val=554.0530091038744, best=554.0530091039
# 	Local search 8/128, x=[0.44510072 0.66701072 1.         1.        ], val=554.053009104793, best=554.0530091048
# 	Local search 19/128, x=[0.44504151 0.66698813 1.         1.        ], val=554.0530091057968, best=554.0530091058
# 	Local search 25/128, x=[0.44509974 0.66698727 1.         1.        ], val=554.0530091076289, best=554.0530091076
#
# 	Proposed next point to try: 0.445100-0.666987-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [100.          45.0710583    0.84730029   0.18509764]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 528.16883815, 'mean': 1.81200269, 'std': 22.99944748, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44379493 0.66825883 1.         1.        ], val=535.5313928644997, best=535.5313928645
# 	Local search 2/128, x=[0.44391208 0.66821702 1.         1.        ], val=535.5313928827007, best=535.5313928827
# 	Local search 3/128, x=[0.44394614 0.66827646 1.         1.        ], val=535.5313928973615, best=535.5313928974
# 	Local search 5/128, x=[0.44401757 0.66822908 1.         1.        ], val=535.5313928982727, best=535.5313928983
# 	Local search 10/128, x=[0.44400453 0.66825951 1.         1.        ], val=535.531392903355, best=535.5313929034
# 	Local search 21/128, x=[0.44406281 0.66827243 1.         1.        ], val=535.531392903913, best=535.5313929039
# 	Local search 40/128, x=[0.44404998 0.66826524 1.         1.        ], val=535.5313929044751, best=535.5313929045
#
# 	Proposed next point to try: 0.444050-0.668265-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [100.          45.07105578   0.84730028   0.18509765]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -83.50313214, 'max': 2713.57166218, 'mean': 181.19120331, 'std': 387.70648552, 'q1': 12.41518063, 'median': 63.92159973, 'q3': 139.05536677}
# 	Local search 1/128, x=[0.49988187 0.60014384 1.         1.        ], val=2720.256303558568, best=2720.2563035586
# 	Local search 4/128, x=[0.49999708 0.60042744 1.         1.        ], val=2720.2563037756827, best=2720.2563037757
# 	Local search 13/128, x=[0.49995498 0.60035143 1.         1.        ], val=2720.256303783585, best=2720.2563037836
# 	Local search 25/128, x=[0.49999969 0.60013708 1.         1.        ], val=2720.2563038623525, best=2720.2563038624
# 	Local search 70/128, x=[0.49999895 0.60026569 1.         1.        ], val=2720.2563039479555, best=2720.2563039480
#
# 	Proposed next point to try: 0.499999-0.600266-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [100.          45.07132495   0.84730017   0.1850976 ]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 37.86827871, 'max': 3446.16608038, 'mean': 747.31781532, 'std': 516.7516988, 'q1': 381.27906442, 'median': 602.09053826, 'q3': 1050.53798701}
# 	Local search 1/128, x=[0.50343448 0.29892569 0.99639818 1.        ], val=3457.2676313763927, best=3457.2676313764
# 	Local search 2/128, x=[0.54522856 0.29923606 0.99640693 1.        ], val=3457.2688040977214, best=3457.2688040977
# 	Local search 3/128, x=[0.54485374 0.29928416 0.99640539 1.        ], val=3457.2688042373597, best=3457.2688042374
# 	Local search 22/128, x=[0.54480435 0.29924691 0.99640544 1.        ], val=3457.2688042459313, best=3457.2688042459
# 	Local search 25/128, x=[0.54487053 0.29925322 0.9964053  1.        ], val=3457.268804259445, best=3457.2688042594
# 	Local search 74/128, x=[0.54488229 0.29926032 0.99640572 1.        ], val=3457.268804264822, best=3457.2688042648
#
# 	Proposed next point to try: 0.544882-0.299260-0.996406-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [100.          45.07092337   0.8473003    0.18509764]
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 80.90220681, 'max': 4234.9304059, 'mean': 1324.99776998, 'std': 808.57690862, 'q1': 683.03264153, 'median': 1113.20084972, 'q3': 1904.9613475}
# 	Local search 1/128, x=[0.51653855 0.27423067 0.90029137 1.        ], val=4246.1872017634705, best=4246.1872017635
# 	Local search 2/128, x=[0.57867372 0.27349002 0.90030521 1.        ], val=4246.193550161034, best=4246.1935501610
# 	Local search 3/128, x=[0.57932668 0.27347895 0.90028637 1.        ], val=4246.193550227288, best=4246.1935502273
# 	Local search 4/128, x=[0.57940649 0.27350954 0.90030401 1.        ], val=4246.193551309079, best=4246.1935513091
# 	Local search 8/128, x=[0.57943691 0.27346969 0.90030331 1.        ], val=4246.193551439074, best=4246.1935514391
# 	Local search 23/128, x=[0.57923358 0.27347884 0.90030502 1.        ], val=4246.193551454866, best=4246.1935514549
# 	Local search 29/128, x=[0.5792294  0.27346863 0.90030368 1.        ], val=4246.193551464938, best=4246.1935514649
# 	Local search 54/128, x=[0.57934561 0.27347737 0.90030464 1.        ], val=4246.193551477543, best=4246.1935514775
# 	Local search 103/128, x=[0.57928513 0.27346106 0.90030505 1.        ], val=4246.193551483709, best=4246.1935514837
#
# 	Proposed next point to try: 0.579285-0.273461-0.900305-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [1.52210353 0.63357197 0.60287173 0.15237487 0.81904393]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00061521, 'mean': 1.66e-06, 'std': 1.131e-05, 'q1': 0.0, 'median': 0.0, 'q3': 9e-08}
# 	Local search 1/160, x=[0.         0.04572456 0.563202   0.79694818 0.        ], val=0.0007874999763022151, best=0.0007875000
# 	Local search 8/160, x=[0.         0.04571669 0.5632051  0.79694112 0.        ], val=0.0007874999814023727, best=0.0007875000
# 	Local search 11/160, x=[0.         0.04572239 0.56323311 0.79694413 0.        ], val=0.0007874999889053457, best=0.0007875000
# 	Local search 42/160, x=[0.         0.04572526 0.56323148 0.79694351 0.        ], val=0.0007874999890582241, best=0.0007875000
# 	Local search 93/160, x=[0.         0.04572492 0.56323063 0.79694346 0.        ], val=0.0007874999890584483, best=0.0007875000
#
# 	Proposed next point to try: 0.000000-0.045725-0.563231-0.796943-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [100.           0.27581337   0.87614894   0.46897799   0.29115179]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.23475196 0.22543532 0.47382277 0.01451689 0.9914135 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.234752-0.225435-0.473823-0.014517-0.991413
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [2.03574884e+00 1.43753153e+00 1.00000000e+02 3.25824802e-01
#  8.23145634e-02]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.58022244, 'max': -0.23652746, 'mean': -1.42225054, 'std': 0.41387261, 'q1': -1.65269142, 'median': -1.43922026, 'q3': -1.18519577}
# 	Local search 1/160, x=[0.27677873 0.325016   0.         0.80317032 0.13137346], val=-0.22898837282038123, best=-0.2289883728
# 	Local search 3/160, x=[0.27679231 0.3250169  1.         0.8031675  0.13137067], val=-0.22894162468566934, best=-0.2289416247
# 	Local search 19/160, x=[0.27679373 0.32501646 1.         0.80316713 0.13137067], val=-0.22894162468384666, best=-0.2289416247
# 	Local search 58/160, x=[0.2767927  0.3250163  1.         0.80316721 0.13137067], val=-0.22894162468383897, best=-0.2289416247
# 	Local search 69/160, x=[0.27679288 0.32501601 1.         0.80316702 0.13137066], val=-0.22894162468379067, best=-0.2289416247
# 	Local search 81/160, x=[0.27679264 0.32501598 1.         0.80316712 0.13137066], val=-0.22894162468373758, best=-0.2289416247
# 	Local search 101/160, x=[0.27679305 0.32501599 1.         0.80316712 0.13137066], val=-0.2289416246836893, best=-0.2289416247
# 	Local search 111/160, x=[0.27679303 0.3250161  1.         0.80316712 0.13137066], val=-0.22894162468368656, best=-0.2289416247
# 	Local search 150/160, x=[0.276793   0.32501606 1.         0.80316712 0.13137066], val=-0.2289416246836838, best=-0.2289416247
#
# 	Proposed next point to try: 0.276793-0.325016-1.000000-0.803167-0.131371
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [1.00000000e+02 1.03732030e+00 1.82495461e+00 4.19703440e-01
#  8.22165064e-02]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.45973929, 'max': 1.15321575, 'mean': 0.04136645, 'std': 0.5603429, 'q1': -0.34609855, 'median': 0.06099039, 'q3': 0.46204847}
# 	Local search 1/160, x=[0.5000019  0.92588422 0.91408138 1.         0.12584104], val=1.1619467888372506, best=1.1619467888
# 	Local search 3/160, x=[0.57757411 0.03024019 0.93045987 1.         0.1141916 ], val=1.1719131707711188, best=1.1719131708
# 	Local search 5/160, x=[0.49999943 0.03025381 0.93041761 1.         0.11418672], val=1.1719177379569878, best=1.1719177380
# 	Local search 34/160, x=[0.49999801 0.03024036 0.93046175 1.         0.11419179], val=1.1719177414506725, best=1.1719177415
#
# 	Proposed next point to try: 0.499998-0.030240-0.930462-1.000000-0.114192
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [100.           0.27581487   0.87614176   0.46897665   0.29115036]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.19994268, 'max': 3.27205056, 'mean': 1.48316648, 'std': 0.79022572, 'q1': 1.00949284, 'median': 1.5442671, 'q3': 2.04271016}
# 	Local search 1/160, x=[0.50000001 0.03526708 0.88921968 0.05289624 0.91535791], val=3.2774182755271366, best=3.2774182755
# 	Local search 5/160, x=[0.49999961 0.0352767  0.88922244 0.05289619 0.91536674], val=3.2774182762954496, best=3.2774182763
# 	Local search 108/160, x=[0.49999896 0.03527654 0.88921728 0.05289577 0.91536787], val=3.2774182763357804, best=3.2774182763
#
# 	Proposed next point to try: 0.499999-0.035277-0.889217-0.052896-0.915368
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [  0.29599161   1.25372415 100.           0.53265293   0.22614333]
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.6459253, 'max': 7.55920299, 'mean': 4.1247856, 'std': 1.47122418, 'q1': 3.12760528, 'median': 4.21085894, 'q3': 5.19897921}
# 	Local search 1/160, x=[0.96071623 0.10782941 0.52447882 0.05931667 0.99983418], val=7.575897626149373, best=7.5758976261
# 	Local search 2/160, x=[0.70239141 0.10230801 0.50366054 0.94498906 1.        ], val=7.584205807353148, best=7.5842058074
# 	Local search 4/160, x=[0.70241372 0.10225291 0.49999977 0.94494918 1.        ], val=7.584206291323907, best=7.5842062913
# 	Local search 7/160, x=[0.70239685 0.1023004  0.49999998 0.94500632 1.        ], val=7.584206317598946, best=7.5842063176
# 	Local search 12/160, x=[0.70239888 0.10229694 0.49999634 0.94498717 1.        ], val=7.584206320013209, best=7.5842063200
# 	Local search 28/160, x=[0.7023934  0.10231191 0.49999997 0.94498775 1.        ], val=7.584206321462033, best=7.5842063215
#
# 	Proposed next point to try: 0.702393-0.102312-0.500000-0.944988-1.000000

# %%
f7_Inputs, f7_Outputs = combineInitialDataAndSubmissionsToDate(7)
findNextGuess('F7', f7_Inputs, f7_Outputs)
# Out:
# ********************
# F7  -  6 D
# ********************
#  Inputs -   Min: [0.011684   0.01181284 0.00363456 0.001006   0.01494418 0.05109986] , Max:  [0.94245084 0.932801   0.92457051 0.96101714 0.9986547  0.95101392]
#  Output -   Min: 0.0027014650245082332 , Max (Best):  1.627092775388822
#
# [[7.262857e-01 4.648958e-01 9.245705e-01 8.072454e-01 6.354384e-01
#   1.434179e-01 6.676325e-02]
#  [1.188670e-01 6.150549e-01 9.058164e-01 8.553003e-01 4.136314e-01
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 1.518e-05, 'mean': 2e-08, 'std': 2.9e-07, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.         0.10730206 0.96789606 0.         0.35296886 0.88146636], val=1.8176110890670924e-05, best=0.0000181761
# 	Local search 10/192, x=[0.         0.59671544 0.93077349 0.         0.35295392 0.88399978], val=1.8197122324649954e-05, best=0.0000181971
# 	Local search 49/192, x=[0.         0.88957503 0.95211106 0.         0.35307827 0.88356831], val=1.8200190384646848e-05, best=0.0000182002
# 	Local search 67/192, x=[0.         0.28204315 0.94856788 0.         0.35303307 0.8839381 ], val=1.820373458121018e-05, best=0.0000182037
#
# 	Proposed next point to try: 0.000000-0.282043-0.948568-0.000000-0.353033-0.883938
#
# Using Expected Improvement Acquisition function with xi = 20
# 	Fitted GP - [  1.17872324 100.           6.02553701   0.4707217    0.18554387
#    0.3028992 ]
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/192, x=[0.29057198 0.5709922  0.98213733 0.2706801  0.08180116 0.27041811], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.290572-0.570992-0.982137-0.270680-0.081801-0.270418
#
# Using UCB Acquisition function with Kappa = 0.1
# 	Fitted GP - [ 1.17869722 69.67443098  6.02817618  0.47072859  0.18555155  0.30287591]
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0724044, 'max': 1.63333652, 'mean': 0.29707942, 'std': 0.25779427, 'q1': 0.11583219, 'median': 0.22298685, 'q3': 0.40778269}
# 	Local search 1/192, x=[0.04213125 0.32551308 0.33066795 0.13065585 0.34720764 0.73841769], val=1.6543717470957153, best=1.6543717471
# 	Local search 8/192, x=[0.04213701 0.37465198 0.33065858 0.13065407 0.34720519 0.73841938], val=1.6543722864735129, best=1.6543722865
# 	Local search 13/192, x=[0.04213508 0.37481024 0.33067092 0.13065223 0.34720509 0.73842052], val=1.6543722864968162, best=1.6543722865
# 	Local search 23/192, x=[0.04213523 0.37460497 0.33066935 0.13065273 0.34720534 0.73841987], val=1.6543722865085755, best=1.6543722865
#
# 	Proposed next point to try: 0.042135-0.374605-0.330669-0.130653-0.347205-0.738420
#
# Using UCB Acquisition function with Kappa = 5
# 	Fitted GP - [  0.39497574 100.         100.           0.1847687    0.22578831
#   93.42622751]
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.05895772, 'max': 2.48195737, 'mean': 1.32448324, 'std': 0.39373873, 'q1': 1.07261963, 'median': 1.34124972, 'q3': 1.59973535}
# 	Local search 1/192, x=[0.02670367 0.2713063  0.21690334 0.04240014 0.45216472 0.40119878], val=2.4885497608239766, best=2.4885497608
# 	Local search 2/192, x=[0.02671075 0.23490304 0.75806966 0.04240076 0.45215892 0.66989637], val=2.4885543469307754, best=2.4885543469
# 	Local search 19/192, x=[0.02670522 0.74456373 0.73924276 0.04240028 0.45216173 0.752892  ], val=2.488554546036119, best=2.4885545460
# 	Local search 33/192, x=[0.02663338 0.32290697 0.7648549  0.04240239 0.45213536 0.74953905], val=2.488554663615542, best=2.4885546636
# 	Local search 102/192, x=[0.02670826 0.25756967 0.74390743 0.04240479 0.45216533 0.75193348], val=2.4885549171571153, best=2.4885549172
#
# 	Proposed next point to try: 0.026708-0.257570-0.743907-0.042405-0.452165-0.751933
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [  1.17872268 100.           6.02574723   0.47072471   0.18554263
#    0.30290176]
# 	98302 Sobol candidates, best 192 to be minimised in local search
# 	Initial acquisition function stats {'min': 0
known samples
#
# Best GP kernel and hyperparams for problem is ${'alpha': 1e-08, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 20}
# Using Expected Improvement Acquisition function with xi = 0
# 	Fitted GP - [  1.19158642   1.85840737   0.92033433   1.6534115    4.69513198
#  100.           1.30652543 100.        ]
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0920112, 'mean': 0.00022632, 'std': 0.00233967, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.23727318 0.16370497 0.1699115  0.1513758  1.         0.09740115
#  0.24472748 0.89992173], val=0.11782401808239629, best=0.1178240181
# 	Local search 2/256, x=[0.23727053 0.16370355 0.16991357 0.15137717 1.         0.09738807
#  0.24472281 0.8999714 ], val=0.11782401811790665, best=0.1178240181
# 	Local search 4/256, x=[0.23727099 0.16370413 0.16991405 0.15137851 1.         0.09743258
#  0.24472515 0.89993702], val=0.1178240181685813, best=0.1178240182
# 	Local search 49/256, x=[0.23727142 0.1637036  0.169915   0.15137939 1.         0.09743683
#  0.24472546 0.89995008], val=0.11782401816870973, best=0.1178240182
# 	Local search 139/256, x=[0.23727019 0.16370469 0.16991465 0.15137853 1.         0.0974349
#  0.24472514 0.89993824], val=0.1178240181703417, best=0.1178240182
#
# 	Proposed next point to try: 0.237270-0.163705-0.169915-0.151379-1.000000-0.097435-0.244725-0.899938
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	Fitted GP - [  1.19158629   1.85840732   0.92033422   1.65341134   4.69513165
#  100.           1.30652533 100.        ]
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03261182, 'mean': 5.339e-05, 'std': 0.00065665, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.25538453 0.1459244  0.17528578 0.15168495 1.         0.08240832
#  0.25207664 0.91140672], val=0.049312401353298584, best=0.0493124014
# 	Local search 3/256, x=[0.25538499 0.14592198 0.17529147 0.15168239 1.         0.0824194
#  0.25207168 0.91138171], val=0.04931240136783826, best=0.0493124014
# 	Local search 19/256, x=[0.25538435 0.14592185 0.17528972 0.15168324 1.         0.08241395
#  0.25207382 0.91138425], val=0.04931240137726554, best=0.0493124014
# 	Local search 24/256, x=[0.25538525 0.14592251 0.17528913 0.15168234 1.         0.08239652
#  0.25207356 0.91142155], val=0.0493124013774651, best=0.0493124014
# 	Local search 102/256, x=[0.25538415 0.14592142 0.17529009 0.15168216 1.         0.08241794
#  0.25207386 0.91140428], val=0.04931240137784417, best=0.0493124014
# 	Local search 110/256, x=[0.25538449 0.14592189 0.17529009 0.15168276 1.         0.08239158
#  0.25207334 0.91140579], val=0.04931240138048172, best=0.0493124014
# 	Local search 228/256, x=[0.25538409 0.14592178 0.1752898  0.15168336 1.         0.08240377
#  0.25207308 0.91140071], val=0.04931240138093572, best=0.0493124014
#
# 	Proposed next point to try: 0.255384-0.145922-0.175290-0.151683-1.000000-0.082404-0.252073-0.911401
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	Fitted GP - [  1.19158632   1.8584072    0.92033418   1.65341135   4.69513181
#  100.           1.30652533 100.        ]
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 5.463e-05, 'mean': 3e-08, 'std': 6e-07, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.64968928, 'max': 10.75133558, 'mean': 8.62313461, 'std': 0.96029193, 'q1': 7.9146596, 'median': 8.67122514, 'q3': 9.37874662}
# 	Local search 1/256, x=[0.04018139 0.9336756  0.01941879 0.48608561 0.92944646 0.79703183
#  0.04387332 0.83952823], val=10.82003796602347, best=10.8200379660
# 	Local search 2/256, x=[0.04020857 0.93363489 0.01941683 0.48633696 0.92947577 0.18240736
#  0.04387996 0.83975094], val=10.820203135667771, best=10.8202031357
# 	Local search 3/256, x=[0.04020241 0.93362678 0.01941306 0.48654898 0.9294819  0.18261125
#  0.04390739 0.83934482], val=10.82020316942668, best=10.8202031694
# 	Local search 4/256, x=[0.04019924 0.93364433 0.01941681 0.48658215 0.9294645  0.18220822
#  0.04389393 0.83947891], val=10.820203179167523, best=10.8202031792
# 	Local search 5/256, x=[0.04019731 0.93364354 0.01941599 0.48660422 0.92948286 0.18213076
#  0.04389666 0.83950716], val=10.820203180224832, best=10.8202031802
# 	Local search 36/256, x=[0.04019738 0.93363906 0.01941681 0.48658382 0.92947618 0.18208317
#  0.04389541 0.83949975], val=10.820203180392014, best=10.8202031804
# 	Local search 77/256, x=[0.04019798 0.93364196 0.01941658 0.48657881 0.92948124 0.18213917
#  0.0438961  0.839511  ], val=10.820203180452655, best=10.8202031805
# 	Local search 180/256, x=[0.04019751 0.93364206 0.01941603 0.48658313 0.92947983 0.18217156
#  0.0438953  0.83949251], val=10.82020318049989, best=10.8202031805
# 	Local search 183/256, x=[0.04019764 0.93364073 0.01941628 0.48658409 0.92947946 0.18212248
#  0.04389565 0.83948723], val=10.820203180538227, best=10.8202031805
#
# 	Proposed next point to try: 0.040198-0.933641-0.019416-0.486584-0.929479-0.182122-0.043896-0.839487
#
# Using UCB Acquisition function with Kappa = 10
# 	Fitted GP - [  1.19158642   1.85840718   0.92033433   1.65341124   4.69513199
#  100.           1.30652535 100.        ]
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 5.97682951, 'max': 12.75345145, 'mean': 9.3078169, 'std': 1.04203774, 'q1': 8.5306701, 'median': 9.29022088, 'q3': 10.07643179}
# 	Local search 1/256, x=[0.02522321 0.96500416 0.01052215 0.95132389 0.06970964 0.40994034
#  0.02972352 0.84053648], val=12.864093329679053, best=12.8640933297
# 	Local search 3/256, x=[0.02522225 0.96500432 0.01052713 0.95131835 0.0696931  0.81605274
#  0.0297271  0.84008631], val=12.864238329789796, best=12.8642383298
# 	Local search 33/256, x=[0.02522597 0.96500606 0.01052797 0.95131335 0.06969068 0.81614878
#  0.02972283 0.84006473], val=12.864238330334107, best=12.8642383303
# 	Local search 38/256, x=[0.02522456 0.965005   0.01052837 0.95131739 0.06968865 0.81612874
#  0.02972654 0.84006106], val=12.864238330633004, best=12.8642383306
# 	Local search 199/256, x=[0.02522534 0.96500507 0.0105277  0.9513132  0.0696889  0.81613471
#  0.02972535 0.84006481], val=12.86423833079078, best=12.8642383308
#
# 	Proposed next point to try: 0.025225-0.965005-0.010528-0.951313-0.069689-0.816135-0.029725-0.840065
#
# Using UCB Acquisition function with Kappa = 20
# 	Fitted GP - [  1.19158629   1.85840727   0.92033418   1.65341136   4.69513185
#  100.           1.30652533 100.        ]
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.44252369, 'max': 17.00957294, 'mean': 10.67718185, 'std': 1.35779556, 'q1': 9.71079105, 'median': 10.52694963, 'q3': 11.54658949}
# 	Local search 1/256, x=[0.01825349 0.9762511  0.00379281 0.97024591 0.05559204 0.82847567
#  0.02098097 0.84509638], val=17.341364681855296, best=17.3413646819
# 	Local search 3/256, x=[0.01825446 0.97624735 0.00379232 0.97024789 0.05559399 0.82841287
#  0.02097797 0.84508449], val=17.341364683735904, best=17.3413646837
# 	Local search 39/256, x=[0.01825432 0.97624865 0.0037922  0.97024839 0.05559456 0.828398
#  0.0209782  0.84510174], val=17.341364683912868, best=17.3413646839
# 	Local search 198/256, x=[0.01825434 0.97624851 0.00379222 0.97024836 0.05559426 0.82841957
#  0.02097808 0.84509503], val=17.341364683934195, best=17.3413646839
#
# 	Proposed next point to try: 0.018254-0.976249-0.003792-0.970248-0.055594-0.828420-0.020978-0.845095

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: {'alpha': 0.01, 'kernel': Matern(length_scale=[1, 1], nu=0.5), 'n_restarts_optimizer': 5}
# F2: {'alpha': 0.0001, 'kernel': RBF(length_scale=[1, 1]), 'n_restarts_optimizer': 20}
# F3: {'alpha': 1e-06, 'kernel': RBF(length_scale=[1, 1, 1]), 'n_restarts_optimizer': 5}
# F4: {'alpha': 1e-08, 'kernel': Matern(length_scale=[1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 5}
# F5: {'alpha': 0.0001, 'kernel': Matern(length_scale=[1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 20}
# F6: {'alpha': 1e-08, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 5}
# F7: {'alpha': 1e-08, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 5}
# F8: {'alpha': 1e-08, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 20}
#
#
# F1:
# 0: 0.707442-0.496526
# 1: 0.016199-0.328627
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 0.316049-0.477278
# 5: 0.785028-0.499839
# 6: 0.246031-0.499793
# 7: 0.238620-0.499789
#
# F2:
# 0: 0.685088-0.916503
# 1: 0.670208-1.000000
# 2: 0.996141-0.163545
# 3: 0.016199-0.328627
# 4: 0.685585-0.832269
# 5: 0.982651-0.227226
