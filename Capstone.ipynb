# %% [markdown]
# ## Setup

# %%
import numpy as np
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from scipy.stats._qmc import Sobol
from scipy.stats import norm
from scipy.optimize import minimize
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern
from sklearn.model_selection import GridSearchCV

from dataloading_utils import (combineInitialDataAndSubmissionsToDate, sortByLargestOutputDescending)


import warnings
warnings.filterwarnings('ignore')

# A nod to Hitchhikers guide to the Galaxy
random_seed=42
np.random.seed(random_seed)

#UCB -  Kappa
# 0.1-1 Exploitation
# 2-5 Balance
# 5-10 Exploratory
KAPPA_BALANCED = 5
KAPPA_EXPLOIT = 0.1
KAPPA_EXPLORE = 10
KAPPA_EXTREME_EXPLORE = 20

KAPPAS = [KAPPA_EXPLOIT, KAPPA_BALANCED, KAPPA_EXPLORE,KAPPA_EXTREME_EXPLORE]


#EI
#0 - Exploitation
#0.01-0.1 - Small Explore
#0.1-0.5 - Moderate Explore
# 0.5+ - Higher explore
XI_EXPLOIT=0
XI_SMALL = 0.1
XI_MODERATE = 0.5
XI_HIGH=20


XIS = [XI_EXPLOIT,XI_SMALL, XI_MODERATE, XI_HIGH]

ACQUISTION_EI = 'ei'
ACQUISTION_UCB = 'ucb'

# %%
def upper_confidence_bound(mu, sigma, kappa):
    """
    Upper Confidence Bound (UCB) acquisition function.
    
    UCB = mean + kappa * std
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation
    kappa : exploration parameter (higher = more exploration)
    """
    return mu + kappa * sigma


def expected_improvement(mu, sigma, y_best, xi):
    """
    Expected Improvement (EI) acquisition function.
    
    EI = E[max(f(x) - f(x_best), 0)]
    
    Parameters:
    -----------
    mu : predicted mean
    sigma : predicted standard deviation  
    y_best : best observed value so far
    xi : exploration parameter
    """
    # To avoid division by zero, clamp sigma to a very small non-zero - we also add exit clause later for same value.
    sigma = np.maximum(sigma, 1e-16)

    with np.errstate(divide='warn'):
        improvement = mu - y_best - xi
        Z = improvement / sigma
        ei = improvement * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 1e-16] = 0.0
    return ei

# %%
def fmt(v):
        return float(f"{v:.8f}")


def summary_stats(x):
    return {
        "min": fmt(np.min(x)),
        "max": fmt(np.max(x)),
        "mean": fmt(np.mean(x)),
        "std": fmt(np.std(x)),
        "q1": fmt(np.percentile(x, 25)),
        "median": fmt(np.percentile(x, 50)),
        "q3": fmt(np.percentile(x, 75)),
    }


def findTunedGaussianProcessRegressor(X_samples, y_samples):
    n_dims = X_samples.shape[1]

    # ARD kernels (vector length_scale)
    rbf_ard = RBF(length_scale=np.ones(n_dims),
                  length_scale_bounds=(1e-2, 1e2))

    matern_05 = Matern(length_scale=np.ones(n_dims), nu=0.5,
                       length_scale_bounds=(1e-2, 1e2))
    matern_15 = Matern(length_scale=np.ones(n_dims), nu=1.5,
                       length_scale_bounds=(1e-2, 1e2))
    matern_25 = Matern(length_scale=np.ones(n_dims), nu=2.5,
                       length_scale_bounds=(1e-2, 1e2))

    param_grid = {
        'kernel': [
            rbf_ard,
            matern_05, matern_15, matern_25,
        ],
        'alpha': [1e-8, 1e-6, 1e-4, 1e-2],
        'n_restarts_optimizer': [5, 10, 20]
    }

    gp = GaussianProcessRegressor(normalize_y=True)

    grid_search = GridSearchCV(gp, param_grid, cv=3)
    grid_search.fit(X_samples, y_samples)

    return grid_search.best_estimator_, grid_search.best_params_


def penaltyWeightAndScaleForDimension(d):
    #Curse of dimensionality means this needs to be much tighter at higher dimensions
    #This is intended to reduce the acquisition function's information gain by 10% if the point has a Euclidean distance of 1/20th or 1/50th of a boundary.
    if d <= 5:
        return 0.1, 0.05
    else:
        return 0.1, 0.02

def bayesian_optimization_next_point(
        n_dims,
        X_samples,
        y_samples,
        acquisition,
        kappa = KAPPA_BALANCED,
        xi = XI_SMALL,
        n_sobol=None,
        n_local=None,
        gp=None,
        excludeDuplicates = True):

    """
    Bayesian Optimization acquisition optimizer - after research about search spaces.
    Parameters
    ----------
    n_dims : int
        Number of dimensions
    X_samples : array (N, D)
        Existing sample inputs
    y_samples : array (N,)
        Existing sample outputs
    acquisition : str
        'ei' or 'ucb'
    n_sobol : int
        Number of Sobol candidate points
    n_local : int
        Number of local optimizations
    kappa: int
        Exploration parameter (higher = more exploration)
    gp: GaussianProcessor
        Gaussian Processor to use on fitting≥
    """

    if n_sobol is None:
        n_sobol = 16384 * n_dims

    if n_local is None:
        n_local = 32 * n_dims

    bounds = [(0.0, 1.0) for _ in range(n_dims)]
    penaltyWeight, penalityScale = penaltyWeightAndScaleForDimension(n_dims)

    if acquisition == ACQUISTION_EI:
        print(f"Using Expected Improvement Acquisition function with xi = {xi}")
    else:
        print(f"Using UCB Acquisition function with Kappa = {kappa}")


    # -----------------------------
    # 1. Fit Gaussian Process - or assume one has been fitted
    #
    #  alpha is the noise level
    #  n_restarts_optimizer is a hyper-parameter
    #  normalize_y improves stability
    # -----------------------------
    if gp is None:
        kernel = ConstantKernel(1.0) * Matern(nu=2.5)
        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            n_restarts_optimizer=10,
            normalize_y=True
        )
        gp.fit(X_samples, y_samples)
        print(f"Fitted default GaussianProcessRegressor since one not provided")

    # -----------------------------
    # 2. Acquisition function
    # -----------------------------

    # -----------------------------
    # 2.1 Boundary Penalty.
    # GP tends to hug the boundary, so add a penalty if a suggested point is close to boundary.
    # Scale controls how far from the boundary the penalty reaches. At scale=0.05, a point at x=0.05 gets a penalty of exp(-1) ≈ 0.37, meaning the penalty is significant only within the last ~5% of the search space.
    # Weight controls how strongly that penalty suppresses the acquisition value. At weight=0.1, the maximum possible suppression is 10% of the acquisition value.
    #
    # -----------------------------
    def boundary_penalty(X, weight=0.1, scale=0.05):
        X = np.atleast_2d(X)
        d = np.minimum(X, 1.0 - X)    #Find point closest to boundary at 0 or 1 in any dimension.
        penalty = np.mean(np.exp(-d / scale), axis=1)   #exp(-small) tends towards 1, exp(-large) tends towards 0. Mean takes into account other dimensions.
        return weight * penalty


    def acq(X):
        X = np.atleast_2d(X)
        mu, sigma = gp.predict(X, return_std=True)

        if acquisition == ACQUISTION_EI:
            val = expected_improvement(mu, sigma, y_samples.max(), xi)
        else:
            val = upper_confidence_bound(mu, sigma, kappa)

        penalty = boundary_penalty(X, weight=penaltyWeight, scale=penalityScale)
        return val * (1 - penalty)


    # -----------------------------
    # 3. Sobol global search
    #
    # Provides a better search than random of the space, but we then run a vectorized evaluation loop and pick the top results to focus optimizing
    # i.e. maximising in local optimization (actually we minimise the -value)
    # -----------------------------
    sobol = Sobol(d=n_dims, scramble=True, seed=random_seed*n_dims) #Stop the same points for each function.

    X_candidates = sobol.random(n_sobol)
    acq_vals = acq(X_candidates)

    # Filter out duplicate candidates, based on Eucledian distance because acquisition functions can suggest previous points.
    def is_duplicate(x, X_samples, tol=1e-5):
        return np.any(np.linalg.norm(X_samples - x, axis=1) < tol)

    if (excludeDuplicates):
        mask = np.array([not is_duplicate(x, X_samples) for x in X_candidates])
        X_candidates = X_candidates[mask]
        acq_vals = acq_vals[mask]


    # Pick best Sobol points
    best_idx = np.argsort(-acq_vals)[:n_local]
    X_start = X_candidates[best_idx]

    print(f"\t{ len(X_candidates) } Sobol candidates, best { len(X_start) } to be minimised in local search")
    print(f"\tInitial acquisition function stats { summary_stats(acq_vals) }")

    # -----------------------------
    # 4. Local optimization
    # -----------------------------
    def objective(x):
        return -acq(x)  # minimize negative acquisition

    best_x = None
    best_val = -np.inf

    for i, x0 in enumerate(X_start):
        result = minimize(
            objective,
            x0,
            bounds=bounds,
            method="L-BFGS-B"
        )

        val = -result.fun

        if val > best_val:
            best_val = val
            best_x = result.x
            print(f"\tLocal search {i+1}/{n_local}, x={result.x}, val={val}, best={best_val:.10f}")

    return best_x, best_val, X_start

# %%
def formatOutputForSubmission( nextInputToTest: ndarray):
    return np.array2string(nextInputToTest, separator='-', precision=6, floatmode='fixed').strip('[]')


def findNextGuess(functionName, f_Inputs, f_Outputs, showKnown=True):

    f_maxInput = np.max(f_Inputs, axis=0) #Output per dimension
    f_minInput = np.min(f_Inputs, axis=0)
    f_maxOutput = np.max(f_Outputs)
    f_minOutput = np.min(f_Outputs)
    numDimensions = len(f_maxInput)

    f_inputOutput = np.column_stack((f_Inputs, f_Outputs))
    f_inputOutputSorted = sortByLargestOutputDescending(f_inputOutput)

    print('********************')
    print(functionName, ' - ', numDimensions, 'D')
    print('********************')
    print(' Inputs -   Min:',  f_minInput, ', Max: ', f_maxInput )
    print(' Output -   Min:',  f_minOutput, ', Max (Best): ', f_maxOutput)

    if (showKnown):
        print()
        print(np.array2string(f_inputOutputSorted, floatmode='fixed', precision=6))
        print()

    print(f"Starting {numDimensions}D Bayes Optimisation from {len(f_Inputs)} known samples")
    print()


    #Solve the GaussianProcessor hyper parameters and record the best fit.
    gpr, bestParams = findTunedGaussianProcessRegressor(f_Inputs, f_Outputs)
    print(f"Best GP kernel and hyperparams for problem initially is ${bestParams}")
    print()

    #Fit GaussianProcesses to samples provided
    gpr.fit(f_Inputs, f_Outputs)
    gpKernels[functionName] = gpr.kernel_   #Get the kernel after it has been fitted.

    print(f"Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is {gpr.kernel_.length_scale}")


    functionProposedPoints = {}
    count = -1

    # EI
    for xi in XIS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_EI,
            xi=xi,
            gp=gpr
        )

        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    for k in KAPPAS:
        nextInputToTest, acqFunctionValue, acqCandidatePoints  = bayesian_optimization_next_point(
            n_dims=numDimensions,
            X_samples=f_Inputs,
            y_samples=f_Outputs,
            acquisition=ACQUISTION_UCB,
            kappa=k,
            gp=gpr
        )
        count += 1
        functionProposedPoints[count] = formatOutputForSubmission(nextInputToTest)
        print()
        print(f'\tProposed next point to try: {functionProposedPoints[count]}')
        print()

    runResults[functionName] = functionProposedPoints

# %%
#Store Results from runs
runResults = {}
gpKernels = {}

# %%
f1_Inputs, f1_Outputs = combineInitialDataAndSubmissionsToDate(1)
findNextGuess('F1', f1_Inputs, f1_Outputs)
# Out:
# ********************
# F1  -  2 D
# ********************
#  Inputs -   Min: [0.00787  0.037348] , Max:  [0.88388983 0.990426  ]
#  Output -   Min: -0.0036060626443634764 , Max (Best):  2.6752879910742468e-09
#
# [[ 5.000000e-001  5.000000e-001  2.675288e-009]
#  [ 7.310236e-001  7.329999e-001  7.710875e-016]
#  [ 6.834182e-001  8.610575e-001  2.535001e-040]
#  [ 5.743292e-001  8.798981e-001  1.033078e-046]
#  [ 8.838898e-001  5.822540e-001  6.229856e-048]
#  [ 3.194039e-001  7.629594e-001  1.322677e-079]
#  [ 8.250725e-002  4.034875e-001  3.606771e-081]
#  [ 8.403534e-001  2.647316e-001  3.341771e-124]
#  [ 3.050000e-002  3.734800e-002  1.733985e-209]
#  [ 7.870000e-003  9.904260e-001  0.000000e+000]
#  [ 2.924500e-002  7.675600e-002 -1.187622e-190]
#  [ 3.126912e-001  7.872278e-002 -2.089093e-091]
#  [ 4.104371e-001  1.475543e-001 -2.159249e-054]
#  [ 4.310290e-001  8.143680e-001 -2.995340e-053]
#  [ 6.501141e-001  6.815264e-001 -3.606063e-003]]
#
# Starting 2D Bayes Optimisation from 15 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 0.01, 'kernel': Matern(length_scale=[1, 1], nu=0.5), 'n_restarts_optimizer': 5}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [1.91878039e-02 1.00000000e+02]
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00027597, 'mean': 0.00022229, 'std': 6.836e-05, 'q1': 0.00021433, 'median': 0.00025182, 'q3': 0.00026222}
# 	Local search 1/64, x=[0.70732102 0.50736293], val=0.0002759663693496, best=0.0002759664
# 	Local search 8/64, x=[0.70744196 0.4965256 ], val=0.0002759678402513723, best=0.0002759678
#
# 	Proposed next point to try: 0.707442-0.496526
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00355542, 'max': 3.294e-05, 'mean': -0.00017632, 'std': 0.00044806, 'q1': -0.00013938, 'median': -7.963e-05, 'q3': -1.849e-05}
# 	Local search 1/64, x=[0.31604888 0.36225993], val=3.294399280158991e-05, best=0.0000329440
# 	Local search 2/64, x=[0.31604836 0.57835673], val=3.294437943528689e-05, best=0.0000329444
# 	Local search 3/64, x=[0.31604857 0.49384943], val=3.29450075643292e-05, best=0.0000329450
# 	Local search 60/64, x=[0.31604919 0.47727757], val=3.2945015350086054e-05, best=0.0000329450
#
# 	Proposed next point to try: 0.316049-0.477278
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00305314, 'max': 0.0042668, 'mean': 0.00354654, 'std': 0.00097787, 'q1': 0.00320477, 'median': 0.00398072, 'q3': 0.00419848}
# 	Local search 1/64, x=[0.78475961 0.51056525], val=0.004266804648606013, best=0.0042668046
# 	Local search 6/64, x=[0.7850255  0.48551993], val=0.004266807001656771, best=0.0042668070
# 	Local search 19/64, x=[0.78503706 0.50253273], val=0.004266809754848277, best=0.0042668098
# 	Local search 56/64, x=[0.78502834 0.49983868], val=0.004266810227453313, best=0.0042668102
#
# 	Proposed next point to try: 0.785028-0.499839
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.0025406, 'max': 0.00875465, 'mean': 0.00734538, 'std': 0.00178849, 'q1': 0.00660624, 'median': 0.00814204, 'q3': 0.0085936}
# 	Local search 1/64, x=[0.24623017 0.50967756], val=0.008754654492366678, best=0.0087546545
# 	Local search 17/64, x=[0.24631536 0.50689568], val=0.008754655345407461, best=0.0087546553
# 	Local search 24/64, x=[0.24614006 0.49703628], val=0.00875465777798099, best=0.0087546578
# 	Local search 51/64, x=[0.24603134 0.49979167], val=0.008754658915087282, best=0.0087546589
#
# 	Proposed next point to try: 0.246031-0.499792
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.00151553, 'max': 0.0177434, 'mean': 0.01494305, 'std': 0.00348469, 'q1': 0.01357055, 'median': 0.016482, 'q3': 0.01738957}
# 	Local search 1/64, x=[0.23817861 0.50288809], val=0.017743396468555616, best=0.0177433965
# 	Local search 23/64, x=[0.23858333 0.50409472], val=0.017743397315099156, best=0.0177433973
# 	Local search 33/64, x=[0.23862004 0.49978853], val=0.017743400498966937, best=0.0177434005
#
# 	Proposed next point to try: 0.238620-0.499789

# %%
f2_Inputs, f2_Outputs = combineInitialDataAndSubmissionsToDate(2)
findNextGuess('F2', f2_Inputs, f2_Outputs)
# Out:
# ********************
# F2  -  2 D
# ********************
#  Inputs -   Min: [0.092501   0.02869772] , Max:  [0.87779099 0.970764  ]
#  Output -   Min: -0.06562362443733738 , Max (Best):  0.6112052157614438
#
# [[ 0.702637  0.926564  0.611205]
#  [ 0.665800  0.123969  0.538996]
#  [ 0.877791  0.778628  0.420586]
#  [ 0.845275  0.711120  0.293993]
#  [ 0.750921  0.829565  0.259756]
#  [ 0.438166  0.685018  0.244619]
#  [ 0.454647  0.290455  0.214965]
#  [ 0.600000  0.500000  0.144121]
#  [ 0.778688  0.970764  0.093698]
#  [ 0.350915  0.117067  0.048338]
#  [ 0.341750  0.028698  0.038749]
#  [ 0.577713  0.771973  0.023106]
#  [ 0.338648  0.213867 -0.013858]
#  [ 0.092501  0.897042 -0.043957]
#  [ 0.142699  0.349005 -0.065624]]
#
# Starting 2D Bayes Optimisation from 15 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 0.0001, 'kernel': RBF(length_scale=[1, 1]), 'n_restarts_optimizer': 20}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [0.05833819 1.42374175]
# Using Expected Improvement Acquisition function with xi = 0
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03261457, 'mean': 0.00062371, 'std': 0.00294539, 'q1': 0.0, 'median': 0.0, 'q3': 1.154e-05}
# 	Local search 1/64, x=[0.68508845 0.91650096], val=0.03262155675559751, best=0.0326215568
# 	Local search 3/64, x=[0.68508852 0.91650177], val=0.032621556755815906, best=0.0326215568
# 	Local search 4/64, x=[0.68508849 0.91650246], val=0.032621556756038374, best=0.0326215568
# 	Local search 32/64, x=[0.68508846 0.91650268], val=0.03262155675603859, best=0.0326215568
# 	Local search 34/64, x=[0.68508849 0.91650242], val=0.03262155675604546, best=0.0326215568
# 	Local search 43/64, x=[0.68508847 0.91650259], val=0.032621556756055506, best=0.0326215568
# 	Local search 49/64, x=[0.68508848 0.9165026 ], val=0.03262155675605705, best=0.0326215568
#
# 	Proposed next point to try: 0.685088-0.916503
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00045328, 'mean': 2.78e-05, 'std': 9.417e-05, 'q1': 0.0, 'median': 0.0, 'q3': 8e-08}
# 	Local search 1/64, x=[0.67020845 1.        ], val=0.00046395886843453, best=0.0004639589
#
# 	Proposed next point to try: 0.670208-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 1.4e-07, 'mean': 0.0, 'std': 2e-08, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.99614093 0.16354457], val=1.3510259967653238e-07, best=0.0000001351
#
# 	Proposed next point to try: 0.996141-0.163545
#
# Using Expected Improvement Acquisition function with xi = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/64, x=[0.01619935 0.32862672], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.016199-0.328627
#
# Using UCB Acquisition function with Kappa = 0.1
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.14658137, 'max': 0.64323797, 'mean': 0.16466923, 'std': 0.18752668, 'q1': 0.01336643, 'median': 0.12419393, 'q3': 0.28299662}
# 	Local search 1/64, x=[0.68558451 0.83225809], val=0.6432524138513923, best=0.6432524139
# 	Local search 2/64, x=[0.68558449 0.83227079], val=0.6432524138856084, best=0.6432524139
# 	Local search 4/64, x=[0.6855846  0.83226882], val=0.6432524138880746, best=0.6432524139
# 	Local search 9/64, x=[0.68558457 0.83226857], val=0.6432524138881308, best=0.6432524139
# 	Local search 11/64, x=[0.68558457 0.83226841], val=0.6432524138881343, best=0.6432524139
# 	Local search 13/64, x=[0.68558458 0.83226858], val=0.6432524138881419, best=0.6432524139
# 	Local search 17/64, x=[0.68558457 0.83226849], val=0.6432524138881428, best=0.6432524139
# 	Local search 20/64, x=[0.68558458 0.83226855], val=0.6432524138881435, best=0.6432524139
#
# 	Proposed next point to try: 0.685585-0.832269
#
# Using UCB Acquisition function with Kappa = 5
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.05228643, 'max': 1.16180044, 'mean': 0.53376726, 'std': 0.2942211, 'q1': 0.31535552, 'median': 0.5136103, 'q3': 0.74554528}
# 	Local search 1/64, x=[0.98265127 0.22723328], val=1.1618053712717475, best=1.1618053713
# 	Local search 2/64, x=[0.98265124 0.22721979], val=1.1618053712740106, best=1.1618053713
# 	Local search 4/64, x=[0.98265114 0.22722741], val=1.1618053712778205, best=1.1618053713
# 	Local search 9/64, x=[0.98265119 0.22722581], val=1.1618053712785301, best=1.1618053713
# 	Local search 15/64, x=[0.98265122 0.22722576], val=1.1618053712785505, best=1.1618053713
# 	Local search 26/64, x=[0.98265121 0.22722561], val=1.1618053712785525, best=1.1618053713
# 	Local search 33/64, x=[0.98265121 0.22722576], val=1.161805371278553, best=1.1618053713
# 	Local search 34/64, x=[0.98265121 0.22722577], val=1.1618053712785545, best=1.1618053713
#
# 	Proposed next point to try: 0.982651-0.227226
#
# Using UCB Acquisition function with Kappa = 10
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.03978847, 'max': 2.10209351, 'mean': 0.91039791, 'std': 0.53089467, 'q1': 0.50846568, 'median': 0.82094996, 'q3': 1.19523499}
# 	Local search 1/64, x=[0.99185893 0.23503595], val=2.1021045064949275, best=2.1021045065
# 	Local search 4/64, x=[0.99185893 0.2350351 ], val=2.1021045064949306, best=2.1021045065
# 	Local search 13/64, x=[0.99185894 0.23503539], val=2.102104506494965, best=2.1021045065
# 	Local search 21/64, x=[0.99185893 0.23503559], val=2.1021045064949657, best=2.1021045065
# 	Local search 39/64, x=[0.99185893 0.23503551], val=2.1021045064949684, best=2.1021045065
# 	Local search 52/64, x=[0.99185894 0.23503552], val=2.1021045064949706, best=2.1021045065
#
# 	Proposed next point to try: 0.991859-0.235036
#
# Using UCB Acquisition function with Kappa = 20
# 	32768 Sobol candidates, best 64 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.01479257, 'max': 3.9922776, 'mean': 1.6636592, 'std': 1.05130709, 'q1': 0.83867263, 'median': 1.39753263, 'q3': 2.27031695}
# 	Local search 1/64, x=[0.99607535 0.23929319], val=3.9923226391701583, best=3.9923226392
# 	Local search 2/64, x=[0.99605493 0.23683631], val=3.9923246345678454, best=3.9923246346
# 	Local search 4/64, x=[0.99605496 0.23683596], val=3.9923246345680448, best=3.9923246346
#
# 	Proposed next point to try: 0.996055-0.236836

# %%
f3_Inputs, f3_Outputs = combineInitialDataAndSubmissionsToDate(3)
findNextGuess('F3', f3_Inputs, f3_Outputs)
# Out:
# ********************
# F3  -  3 D
# ********************
#  Inputs -   Min: [0.04680895 0.028783   0.06608864] , Max:  [0.96599485 0.94135983 0.99088187]
#  Output -   Min: -0.3989255131463011 , Max (Best):  -0.016667499870921285
#
# [[ 0.371452  0.413066  0.461483 -0.016667]
#  [ 0.492581  0.611593  0.340176 -0.034835]
#  [ 0.600097  0.725136  0.066089 -0.036378]
#  [ 0.220549  0.297825  0.343555 -0.046947]
#  [ 0.134622  0.219917  0.458206 -0.048008]
#  [ 0.965995  0.861120  0.566829 -0.056758]
#  [ 0.431029  0.814368  0.806413 -0.070739]
#  [ 0.242114  0.644074  0.272433 -0.087963]
#  [ 0.170477  0.697032  0.149169 -0.094190]
#  [ 0.431029  0.814368  0.806413 -0.098068]
#  [ 0.666014  0.671985  0.246295 -0.105965]
#  [ 0.345523  0.941360  0.269363 -0.110621]
#  [ 0.534906  0.398501  0.173389 -0.111415]
#  [ 0.171525  0.343917  0.248737 -0.112122]
#  [ 0.645503  0.397143  0.919771 -0.113869]
#  [ 0.046809  0.231360  0.770618 -0.118048]
#  [ 0.746912  0.284196  0.226300 -0.131461]
#  [ 0.134015  0.028783  0.755137 -0.187030]
#  [ 0.965337  0.047492  0.944587 -0.273443]
#  [ 0.151837  0.439991  0.990882 -0.398926]]
#
# Starting 3D Bayes Optimisation from 20 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 0.01, 'kernel': Matern(length_scale=[1, 1, 1], nu=0.5), 'n_restarts_optimizer': 10}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [1.00000000e+02 1.00000000e+02 8.69600647e-02]
# Using Expected Improvement Acquisition function with xi = 0
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01314008, 'mean': 0.00359855, 'std': 0.00384502, 'q1': 4.535e-05, 'median': 0.00247974, 'q3': 0.00582858}
# 	Local search 1/96, x=[0.67071193 0.63578585 0.49311603], val=0.013140259887306271, best=0.0131402599
# 	Local search 2/96, x=[0.60698979 0.62444938 0.49311824], val=0.013140458764560594, best=0.0131404588
# 	Local search 3/96, x=[0.6255245  0.60429676 0.49311346], val=0.013140470133950762, best=0.0131404701
# 	Local search 14/96, x=[0.61638355 0.60713991 0.49311899], val=0.01314047398507257, best=0.0131404740
#
# 	Proposed next point to try: 0.616384-0.607140-0.493119
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00047724, 'mean': 7.331e-05, 'std': 0.00012016, 'q1': 0.0, 'median': 8.58e-06, 'q3': 8.983e-05}
# 	Local search 1/96, x=[0.73099088 0.24050337 0.        ], val=0.00047728387986189954, best=0.0004772839
# 	Local search 2/96, x=[0.58749558 0.5335439  0.        ], val=0.0004774847506423123, best=0.0004774848
# 	Local search 18/96, x=[0.471401   0.46695518 0.        ], val=0.00047748842569645826, best=0.0004774884
# 	Local search 59/96, x=[0.50464417 0.52744076 0.        ], val=0.0004774885661925564, best=0.0004774886
#
# 	Proposed next point to try: 0.504644-0.527441-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[7.30992394e-01 2.40500702e-01 1.51982531e-05], val=1.124023367269006e-15, best=0.0000000000
#
# 	Proposed next point to try: 7.309924e-01-2.405007e-01-1.519825e-05
#
# Using Expected Improvement Acquisition function with xi = 20
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/96, x=[0.00341436 0.17699872 0.0697784 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.003414-0.176999-0.069778
#
# Using UCB Acquisition function with Kappa = 0.1
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.38355393, 'max': -0.01904507, 'mean': -0.09698378, 'std': 0.06737642, 'q1': -0.11104531, 'median': -0.0850972, 'q3': -0.05057734}
# 	Local search 1/96, x=[0.         1.         0.46269033], val=-0.018732536935355842, best=-0.0187325369
# 	Local search 57/96, x=[0.         1.         0.46269033], val=-0.01873253693535507, best=-0.0187325369
# 	Local search 60/96, x=[0.        0.        0.4625486], val=-0.018705274558636444, best=-0.0187052746
# 	Local search 90/96, x=[0.         0.         0.46254858], val=-0.018705274558624554, best=-0.0187052746
#
# 	Proposed next point to try: 0.000000-0.000000-0.462549
#
# Using UCB Acquisition function with Kappa = 5
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0.33878572, 'max': 0.29490054, 'mean': 0.13478676, 'std': 0.12089341, 'q1': 0.05624972, 'median': 0.17099451, 'q3': 0.22939179}
# 	Local search 1/96, x=[0.49982583 0.50007536 0.        ], val=0.29496289595264746, best=0.2949628960
# 	Local search 10/96, x=[0.50006136 0.49998243 0.        ], val=0.2949628975048306, best=0.2949628975
# 	Local search 17/96, x=[0.49998634 0.500035   0.        ], val=0.2949628977492993, best=0.2949628977
# 	Local search 50/96, x=[0.49997759 0.49995799 0.        ], val=0.29496289775736656, best=0.2949628978
#
# 	Proposed next point to try: 0.499978-0.499958-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	49152 Sobol candidates, best 96 to be minimised in local search
# 	Initial acquisition function stats {'min': -0
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.06510364, 'mean': 2.792e-05, 'std': 0.00067893, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.4209676  0.46002811 0.34387839 0.43420944], val=0.08448716187212671, best=0.0844871619
# 	Local search 21/128, x=[0.42096773 0.46002819 0.34387833 0.43420947], val=0.08448716187216969, best=0.0844871619
# 	Local search 28/128, x=[0.4209677  0.4600281  0.34387834 0.43420945], val=0.0844871618723057, best=0.0844871619
#
# 	Proposed next point to try: 0.420968-0.460028-0.343878-0.434209
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.01464101, 'mean': 6.01e-06, 'std': 0.00014257, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.42753009 0.48118777 0.31836485 0.4310015 ], val=0.018412153843560576, best=0.0184121538
# 	Local search 2/128, x=[0.42753025 0.48118754 0.31836465 0.43100168], val=0.01841215384462497, best=0.0184121538
# 	Local search 13/128, x=[0.42753006 0.4811873  0.31836452 0.43100177], val=0.01841215384482716, best=0.0184121538
# 	Local search 30/128, x=[0.42753018 0.48118737 0.31836453 0.43100175], val=0.018412153844844306, best=0.0184121538
# 	Local search 68/128, x=[0.42753014 0.48118739 0.31836457 0.43100172], val=0.018412153844859495, best=0.0184121538
#
# 	Proposed next point to try: 0.427530-0.481187-0.318365-0.431002
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.02433108 0.97459509 0.994277   0.00941195], val=2.554896812570286e-16, best=0.0000000000
#
# 	Proposed next point to try: 0.024331-0.974595-0.994277-0.009412
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -34.24805615, 'max': 0.49794592, 'mean': -16.68362448, 'std': 6.37971088, 'q1': -21.11756549, 'median': -16.77946235, 'q3': -12.09401592}
# 	Local search 1/128, x=[0.42216247 0.42979067 0.36999286 0.43643159], val=0.6260792106120784, best=0.6260792106
# 	Local search 5/128, x=[0.42216247 0.42979068 0.36999285 0.43643157], val=0.6260792106121046, best=0.6260792106
# 	Local search 9/128, x=[0.42216246 0.42979067 0.36999286 0.43643157], val=0.6260792106121251, best=0.6260792106
# 	Local search 15/128, x=[0.42216247 0.42979066 0.36999283 0.43643156], val=0.6260792106121319, best=0.6260792106
# 	Local search 28/128, x=[0.42216244 0.42979064 0.36999283 0.43643158], val=0.6260792106121503, best=0.6260792106
# 	Local search 31/128, x=[0.42216245 0.42979065 0.36999285 0.43643159], val=0.6260792106121624, best=0.6260792106
# 	Local search 76/128, x=[0.42216247 0.42979065 0.36999285 0.43643158], val=0.6260792106121775, best=0.6260792106
# 	Local search 120/128, x=[0.42216246 0.42979065 0.36999285 0.43643159], val=0.6260792106122051, best=0.6260792106
#
# 	Proposed next point to try: 0.422162-0.429791-0.369993-0.436432
#
# Using UCB Acquisition function with Kappa = 5
# 	65536 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min':
#  [3.554816e-01 6.396194e-01 4.176177e-01 1.226038e-01 4.518157e+01]
#  [7.252617e-01 4.798705e-01 8.894684e-02 7.597602e-01 2.886675e+01]
#  [6.774911e-01 3.585095e-01 4.795922e-01 7.288048e-02 2.442309e+01]
#  [7.586529e-01 5.365177e-01 6.560004e-01 3.603416e-01 1.830138e+01]
#  [1.268847e-01 1.534296e-01 7.701622e-01 1.905181e-01 9.972332e+00]
#  [1.537857e-01 7.293817e-01 4.225984e-01 4.430742e-01 8.847992e+00]
#  [7.060508e-01 5.341920e-01 2.642433e-01 4.820875e-01 4.210898e+00]
#  [1.373700e-02 8.536320e-01 2.526850e-01 2.508360e-01 3.364529e+00]
#  [4.383499e-01 8.043397e-01 2.102453e-01 1.512948e-01 1.129398e-01]]
#
# Starting 4D Bayes Optimisation from 25 known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 0.0001, 'kernel': Matern(length_scale=[1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 20}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [100.          45.07105839   0.84730028   0.18509765]
# Using Expected Improvement Acquisition function with xi = 0
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.95200597, 'mean': 1.96582436, 'std': 24.42079996, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44465503 0.66699    1.         1.        ], val=554.5279587448895, best=554.5279587449
# 	Local search 2/128, x=[0.44511359 0.66697346 1.         1.        ], val=554.5279588886405, best=554.5279588886
# 	Local search 9/128, x=[0.44514261 0.66694393 1.         1.        ], val=554.5279588896192, best=554.5279588896
# 	Local search 22/128, x=[0.4451243 0.666946  1.        1.       ], val=554.527958890086, best=554.5279588901
# 	Local search 25/128, x=[0.44511013 0.66695453 1.         1.        ], val=554.5279588903697, best=554.5279588904
#
# 	Proposed next point to try: 0.445110-0.666955-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.85808746, 'mean': 1.96503659, 'std': 24.41360215, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44521616 0.66694635 1.         1.        ], val=554.4329729849941, best=554.4329729850
# 	Local search 4/128, x=[0.44510514 0.66693755 1.         1.        ], val=554.4329729896289, best=554.4329729896
# 	Local search 17/128, x=[0.4450846  0.66697721 1.         1.        ], val=554.4329729904722, best=554.4329729905
# 	Local search 35/128, x=[0.44513097 0.66695883 1.         1.        ], val=554.4329729922528, best=554.4329729923
# 	Local search 45/128, x=[0.44512078 0.66695653 1.         1.        ], val=554.432972992308, best=554.4329729923
#
# 	Proposed next point to try: 0.445121-0.666957-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 546.48241368, 'mean': 1.96188742, 'std': 24.38482002, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44470987 0.66694884 1.         1.        ], val=554.0530295663682, best=554.0530295664
# 	Local search 3/128, x=[0.44506955 0.66698524 1.         1.        ], val=554.0530296679771, best=554.0530296680
# 	Local search 38/128, x=[0.44510601 0.66698032 1.         1.        ], val=554.0530296681278, best=554.0530296681
# 	Local search 70/128, x=[0.4450893  0.66699228 1.         1.        ], val=554.0530296682356, best=554.0530296682
#
# 	Proposed next point to try: 0.445089-0.666992-1.000000-1.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 528.1688469, 'mean': 1.81200271, 'std': 22.99944775, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/128, x=[0.44432208 0.6682849  1.         1.        ], val=535.5314018486773, best=535.5314018487
# 	Local search 2/128, x=[0.44400742 0.66829845 1.         1.        ], val=535.5314018922776, best=535.5314018923
# 	Local search 5/128, x=[0.44403818 0.66825096 1.         1.        ], val=535.5314018984836, best=535.5314018985
# 	Local search 17/128, x=[0.44404628 0.66826019 1.         1.        ], val=535.5314018992208, best=535.5314018992
#
# 	Proposed next point to try: 0.444046-0.668260-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 0.1
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': -83.50313255, 'max': 2713.57166409, 'mean': 181.19120314, 'std': 387.70648563, 'q1': 12.4151802, 'median': 63.92159982, 'q3': 139.0553669}
# 	Local search 1/128, x=[0.49786577 0.60012753 1.         1.        ], val=2720.2562965383763, best=2720.2562965384
# 	Local search 2/128, x=[0.49996389 0.60092427 1.         1.        ], val=2720.256303379209, best=2720.2563033792
# 	Local search 5/128, x=[0.49998003 0.60050111 1.         1.        ], val=2720.256305698487, best=2720.2563056985
# 	Local search 21/128, x=[0.49997644 0.60048377 1.         1.        ], val=2720.256305737103, best=2720.2563057371
# 	Local search 23/128, x=[0.49994735 0.60026461 1.         1.        ], val=2720.2563059594704, best=2720.2563059595
# 	Local search 45/128, x=[0.49994942 0.60025431 1.         1.        ], val=2720.256305965028, best=2720.2563059650
# 	Local search 66/128, x=[0.49999856 0.60025501 1.         1.        ], val=2720.256306092863, best=2720.2563060929
# 	Local search 67/128, x=[0.49999853 0.60025903 1.         1.        ], val=2720.256306092872, best=2720.2563060929
#
# 	Proposed next point to try: 0.499999-0.600259-1.000000-1.000000
#
# Using UCB Acquisition function with Kappa = 5
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 37.86830105, 'max': 3446.1659652, 'mean': 747.3176475, 'std': 516.7516009, 'q1': 381.27896596, 'median': 602.09038033, 'q3': 1050.53776626}
# 	Local search 1/128, x=[0.50371326 0.29897547 0.99640555 1.        ], val=3457.2675395575075, best=3457.2675395575
# 	Local search 2/128, x=[0.54627034 0.29945858 0.99642839 1.        ], val=3457.2686877853353, best=3457.2686877853
# 	Local search 3/128, x=[0.54504169 0.29923173 0.99640728 1.        ], val=3457.268698977422, best=3457.2686989774
# 	Local search 8/128, x=[0.54500793 0.29929424 0.99640505 1.        ], val=3457.26869899681, best=3457.2686989968
# 	Local search 12/128, x=[0.54496871 0.29926539 0.99640527 1.        ], val=3457.2686990565244, best=3457.2686990565
# 	Local search 25/128, x=[0.54491111 0.2992511  0.99640593 1.        ], val=3457.268699062689, best=3457.2686990627
# 	Local search 36/128, x=[0.54491399 0.29925597 0.99640614 1.        ], val=3457.2686990632988, best=3457.2686990633
#
# 	Proposed next point to try: 0.544914-0.299256-0.996406-1.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min': 80.90218203, 'max': 4234.9303456, 'mean': 1324.99769277, 'std': 808.57689948, 'q1': 683.03255699, 'median': 1113.200789, 'q3': 1904.96131188}
# 	Local search 1/128, x=[0.51653056 0.2741882  0.90029142 1.        ], val=4246.187142427243, best=4246.1871424272
# 	Local search 2/128, x=[0.57970025 0.27337666 0.90030696 1.        ], val=4246.193486752017, best=4246.1934867520
# 	Local search 3/128, x=[0.57938521 0.27347428 0.90030673 1.        ], val=4246.1934878726925, best=4246.1934878727
# 	Local search 16/128, x=[0.57929917 0.27346511 0.90030494 1.        ], val=4246.193487911266, best=4246.1934879113
#
# 	Proposed next point to try: 0.579299-0.273465-0.900305-1.000000
#
# Using UCB Acquisition function with Kappa = 20
# 	65535 Sobol candidates, best 128 to be minimised in local search
# 	Initial acquisition function stats {'min':
known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 0.01, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 5}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [0.44850475 1.05751446 0.81415934 0.70064856 0.72792503]
# Using Expected Improvement Acquisition function with xi = 0
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.07838545, 'mean': 0.00046618, 'std': 0.0030653, 'q1': 0.0, 'median': 0.0, 'q3': 1.12e-06}
# 	Local search 1/160, x=[0.45645741 0.13723382 0.45798889 0.82029436 0.03368632], val=0.0809991982983947, best=0.0809991983
# 	Local search 2/160, x=[0.4564571  0.13723671 0.45798791 0.82029907 0.03369283], val=0.08099919836064462, best=0.0809991984
# 	Local search 8/160, x=[0.45645731 0.13723654 0.45798777 0.8202988  0.03369194], val=0.08099919836085961, best=0.0809991984
# 	Local search 23/160, x=[0.45645723 0.13723635 0.45798799 0.82029879 0.03369243], val=0.08099919836100482, best=0.0809991984
# 	Local search 41/160, x=[0.45645737 0.13723677 0.45798817 0.82029891 0.03369245], val=0.08099919836100856, best=0.0809991984
# 	Local search 145/160, x=[0.45645735 0.13723665 0.45798782 0.82029872 0.03369227], val=0.08099919836103162, best=0.0809991984
#
# 	Proposed next point to try: 0.456457-0.137237-0.457988-0.820299-0.033692
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03586354, 'mean': 0.00015635, 'std': 0.00114453, 'q1': 0.0, 'median': 0.0, 'q3': 1.5e-07}
# 	Local search 1/160, x=[0.45124329 0.0649195  0.44956773 0.85483762 0.        ], val=0.03641304593997989, best=0.0364130459
# 	Local search 2/160, x=[0.45124357 0.06492242 0.4495656  0.85483505 0.        ], val=0.03641304594585102, best=0.0364130459
# 	Local search 40/160, x=[0.4512434  0.06492261 0.44956546 0.85483496 0.        ], val=0.036413045945931075, best=0.0364130459
#
# 	Proposed next point to try: 0.451243-0.064923-0.449565-0.854835-0.000000
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.00051188, 'mean': 7.5e-07, 'std': 8.37e-06, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.41153321 0.         0.38959368 1.         0.        ], val=0.0007774532209094949, best=0.0007774532
# 	Local search 3/160, x=[0.41156367 0.         0.38955602 1.         0.        ], val=0.0007774532625833079, best=0.0007774533
#
# 	Proposed next point to try: 0.411564-0.000000-0.389556-1.000000-0.000000
#
# Using Expected Improvement Acquisition function with xi = 20
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'std': 0.0, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/160, x=[0.23475196 0.22543532 0.47382277 0.01451689 0.9914135 ], val=0.0, best=0.0000000000
#
# 	Proposed next point to try: 0.234752-0.225435-0.473823-0.014517-0.991413
#
# Using UCB Acquisition function with Kappa = 0.1
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.54285389, 'max': -0.22719004, 'mean': -1.43799817, 'std': 0.41199906, 'q1': -1.74249998, 'median': -1.46746299, 'q3': -1.16101557}
# 	Local search 1/160, x=[0.45505343 0.20252557 0.46170906 0.80018136 0.05850189], val=-0.2096751619975866, best=-0.2096751620
# 	Local search 6/160, x=[0.45505333 0.20252549 0.46170871 0.80018184 0.05850185], val=-0.2096751619974665, best=-0.2096751620
# 	Local search 20/160, x=[0.45505341 0.20252545 0.46170901 0.80018175 0.05850194], val=-0.20967516199736333, best=-0.2096751620
# 	Local search 38/160, x=[0.45505334 0.20252549 0.46170903 0.80018168 0.05850185], val=-0.20967516199731387, best=-0.2096751620
# 	Local search 40/160, x=[0.45505333 0.20252555 0.46170894 0.80018164 0.05850183], val=-0.2096751619973116, best=-0.2096751620
#
# 	Proposed next point to try: 0.455053-0.202526-0.461709-0.800182-0.058502
#
# Using UCB Acquisition function with Kappa = 5
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -2.11944635, 'max': 0.88578024, 'mean': -0.37860877, 'std': 0.45109579, 'q1': -0.69675734, 'median': -0.38707922, 'q3': -0.06335827}
# 	Local search 1/160, x=[0.28236397 0.01896756 0.05001523 1.         0.        ], val=0.9483630950891598, best=0.9483630951
# 	Local search 5/160, x=[0.28236397 0.01896757 0.05001512 1.         0.        ], val=0.948363095089171, best=0.9483630951
# 	Local search 66/160, x=[0.282364   0.01896754 0.0500151  1.         0.        ], val=0.9483630950891712, best=0.9483630951
# 	Local search 131/160, x=[0.28236403 0.01896756 0.05001513 1.         0.        ], val=0.9483630950891765, best=0.9483630951
#
# 	Proposed next point to try: 0.282364-0.018968-0.050015-1.000000-0.000000
#
# Using UCB Acquisition function with Kappa = 10
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.75063508, 'max': 2.64712128, 'mean': 0.70240081, 'std': 0.62431732, 'q1': 0.2684851, 'median': 0.70340987, 'q3': 1.13091444}
# 	Local search 1/160, x=[0.02922529 0.05320127 0.05257307 1.         0.01136627], val=2.7371677559171603, best=2.7371677559
# 	Local search 2/160, x=[0.02922389 0.05320287 0.05257393 1.         0.0113649 ], val=2.737167755937035, best=2.7371677559
# 	Local search 3/160, x=[0.02922559 0.05320277 0.05257235 1.         0.01136449], val=2.737167755948567, best=2.7371677559
# 	Local search 4/160, x=[0.02922542 0.0532026  0.05257304 1.         0.01136447], val=2.737167755950841, best=2.7371677560
# 	Local search 21/160, x=[0.02922527 0.05320264 0.05257303 1.         0.01136455], val=2.737167755951153, best=2.7371677560
# 	Local search 25/160, x=[0.02922524 0.05320277 0.05257305 1.         0.01136456], val=2.7371677559511602, best=2.7371677560
# 	Local search 59/160, x=[0.02922522 0.05320269 0.05257309 1.         0.01136459], val=2.7371677559511873, best=2.7371677560
#
# 	Proposed next point to try: 0.029225-0.053203-0.052573-1.000000-0.011365
#
# Using UCB Acquisition function with Kappa = 20
# 	81918 Sobol candidates, best 160 to be minimised in local search
# 	Initial acquisition function stats {'min': -1.01301254, 'max': 6.44647085, 'mean': 2.86441998, 'std': 1.1056666, 'q1': 2.08830896, 'median': 2.83681445, 'q3': 3.62890577}
# 	Local search 1/160, x=[0.00879763 0.91913171 0.02187172 0.99278805 0.01683513], val=6.513236607191458, best=6.5132366072
# 	Local search 3/160, x=[0.00879964 0.91913099 0.02187647 0.99279053 0.01683446], val=6.513236607862705, best=6.5132366079
# 	Local search 30/160, x=[0.00879983 0.9191313  0.0218763  0.99279058 0.01683398], val=6.5132366078668005, best=6.5132366079
# 	Local search 54/160, x=[0.00879975 0.91913123 0.02187623 0.99279051 0.01683408], val=6.5132366078673325, best=6.5132366079
known samples
#
# Best GP kernel and hyperparams for problem initially is ${'alpha': 1e-06, 'kernel': Matern(length_scale=[1, 1, 1, 1, 1, 1, 1, 1], nu=2.5), 'n_restarts_optimizer': 10}
#
# Automatic Relevance Determination (by dimension) from GaussianProcessorRegressor model fit is [  1.19157894   1.85839941   0.92033186   1.6534021    4.69503648
#  100.           1.30651619 100.        ]
# Using Expected Improvement Acquisition function with xi = 0
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.09200727, 'mean': 0.00022633, 'std': 0.00233968, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.23727122 0.16369326 0.16992167 0.15137068 1.         0.09742272
#  0.24471963 0.89995065], val=0.11782004379858793, best=0.1178200438
# 	Local search 25/256, x=[0.23727025 0.16369491 0.16992119 0.15137208 1.         0.09743516
#  0.24471911 0.89994492], val=0.11782004380234604, best=0.1178200438
# 	Local search 51/256, x=[0.23727034 0.16369266 0.16992157 0.15137178 1.         0.09744511
#  0.24471824 0.8999337 ], val=0.11782004380415811, best=0.1178200438
# 	Local search 69/256, x=[0.23727006 0.16369288 0.16992203 0.15137126 1.         0.09744566
#  0.24471856 0.89993058], val=0.11782004380438664, best=0.1178200438
# 	Local search 93/256, x=[0.23726996 0.16369256 0.16992223 0.15137077 1.         0.0974278
#  0.2447184  0.89993286], val=0.1178200438058684, best=0.1178200438
# 	Local search 127/256, x=[0.23727029 0.16369223 0.16992147 0.15137103 1.         0.09743957
#  0.24471813 0.89994165], val=0.11782004380622023, best=0.1178200438
# 	Local search 133/256, x=[0.23726919 0.16369271 0.16992148 0.15137079 1.         0.09743543
#  0.24471874 0.8999385 ], val=0.11782004380675938, best=0.1178200438
# 	Local search 207/256, x=[0.23726993 0.16369272 0.16992145 0.15137146 1.         0.09743533
#  0.24471873 0.89995144], val=0.11782004380688241, best=0.1178200438
#
# 	Proposed next point to try: 0.237270-0.163693-0.169921-0.151371-1.000000-0.097435-0.244719-0.899951
#
# Using Expected Improvement Acquisition function with xi = 0.1
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max': 0.03261056, 'mean': 5.339e-05, 'std': 0.00065667, 'q1': 0.0, 'median': 0.0, 'q3': 0.0}
# 	Local search 1/256, x=[0.25538762 0.14590259 0.17530266 0.15166342 1.         0.08244589
#  0.25205982 0.91126261], val=0.04931096379164779, best=0.0493109638
# 	Local search 2/256, x=[0.25538439 0.145904   0.17530039 0.15167052 1.         0.08241951
#  0.25206535 0.91139696], val=0.04931096405407769, best=0.0493109641
# 	Local search 55/256, x=[0.25538521 0.14590377 0.17530111 0.15167114 1.         0.08241138
#  0.25206469 0.91138266], val=0.04931096405427476, best=0.0493109641
# 	Local search 63/256, x=[0.2553852  0.1459043  0.17529979 0.15167215 1.         0.08238668
#  0.25206551 0.91139898], val=0.049310964056348064, best=0.0493109641
# 	Local search 110/256, x=[0.25538537 0.14590302 0.17530064 0.15167195 1.         0.08240516
#  0.25206591 0.91138868], val=0.04931096405742542, best=0.0493109641
# 	Local search 132/256, x=[0.25538563 0.14590322 0.17530063 0.15167204 1.         0.08239668
#  0.25206542 0.9114015 ], val=0.049310964058382235, best=0.0493109641
# 	Local search 209/256, x=[0.25538505 0.1459036  0.1753001  0.15167126 1.         0.08239899
#  0.2520654  0.91139248], val=0.049310964058842534, best=0.0493109641
# 	Local search 246/256, x=[0.25538492 0.14590386 0.17530025 0.15167182 1.         0.08239807
#  0.25206511 0.91140195], val=0.049310964058960564, best=0.0493109641
#
# 	Proposed next point to try: 0.255385-0.145904-0.175300-0.151672-1.000000-0.082398-0.252065-0.911402
#
# Using Expected Improvement Acquisition function with xi = 0.5
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 0.0, 'max':
# 	131070 Sobol candidates, best 256 to be minimised in local search
# 	Initial acquisition function stats {'min': 6.44273202, 'max': 17.00971824, 'mean': 10.67732152, 'std': 1.35779255, 'q1': 9.71092535, 'median': 10.52712091, 'q3': 11.5467443}
# 	Local search 1/256, x=[0.01825569 0.97624861 0.00379391 0.97024893 0.05561926 0.82838157
#  0.02098074 0.84488665], val=17.341510081103447, best=17.3415100811
# 	Local search 3/256, x=[0.01825461 0.97624871 0.00379258 0.97024848 0.05559487 0.82839091
#  0.02097872 0.84511291], val=17.34151009853061, best=17.3415100985
# 	Local search 94/256, x=[0.0182543  0.97624855 0.00379275 0.97024842 0.05559441 0.82840014
#  0.02097835 0.84509041], val=17.341510098589517, best=17.3415100986
#
# 	Proposed next point to try: 0.018254-0.976249-0.003793-0.970248-0.055594-0.828400-0.020978-0.845090

# %%
formatted_data = {}

print(f'0 - Xi {XI_EXPLOIT} exploit')
print(f'1 - Xi {XI_SMALL} small explore')
print(f'2 - Xi {XI_MODERATE }medium explore')
print(f'3 - Xi {XI_HIGH} higher Explore')
print(f'4 - UCB k {KAPPA_EXPLOIT} exploit')
print(f'5 - UCB k {KAPPA_BALANCED} balanced')
print(f'6 - UCB k {KAPPA_EXPLORE} medium explore')
print(f'7 - UCB k {KAPPA_EXTREME_EXPLORE} extreme Explore')
print()

for fname, gpKernel in gpKernels.items():
    print(f"{fname}: {gpKernel}")

print()


for fname, values in runResults.items():
    formatted_data[fname] = {}
    for k, v in values.items():
        # Keep the hyphen-separated string as-is
        formatted_data[fname][k] = v

# Optional: print in a readable format
for fname, values in formatted_data.items():
    print(f"\n{fname}:")
    for k, vec_str in values.items():
        print(f"{k}: {vec_str}")
# Out:
# 0 - Xi 0 exploit
# 1 - Xi 0.1 small explore
# 2 - Xi 0.5medium explore
# 3 - Xi 20 higher Explore
# 4 - UCB k 0.1 exploit
# 5 - UCB k 5 balanced
# 6 - UCB k 10 medium explore
# 7 - UCB k 20 extreme Explore
#
# F1: Matern(length_scale=[0.0192, 100], nu=0.5)
# F2: RBF(length_scale=[0.0583, 1.42])
# F3: Matern(length_scale=[100, 100, 0.087], nu=0.5)
# F4: Matern(length_scale=[0.79, 0.754, 0.798, 0.745], nu=2.5)
# F5: Matern(length_scale=[100, 45.1, 0.847, 0.185], nu=2.5)
# F6: Matern(length_scale=[0.449, 1.06, 0.814, 0.701, 0.728], nu=2.5)
# F7: RBF(length_scale=[0.964, 2.99, 2.29, 0.443, 0.164, 0.224])
# F8: Matern(length_scale=[1.19, 1.86, 0.92, 1.65, 4.7, 100, 1.31, 100], nu=2.5)
#
#
# F1:
# 0: 0.707442-0.496526
# 1: 0.016199-0.328627
# 2: 0.016199-0.328627
# 3: 0.016199-0.328627
# 4: 0.316049-0.477278
# 5: 0.785028-0.499839
# 6: 0.246031-0.499792
# 7: 0.238620-0.499789
#
# F2:
# 0: 0.685088-0.916503
# 1: 0.670208-1.000000
# 2: 0.996141-0.163545
# 3: 0.016199-0.328627
# 4: 0.685585-0.832269
# 5: 0.982651-0.227226
